# %% [markdown]
# ## Homework 1: Advanced Track -- Harvest the Twitter API

# %% [markdown]
# **Objective:** Write a series of functions that allow you to dynamically harvest Twitter data.
#
# **Estimated Time to Complete:** 4-12 hours
#
# #### Sections
#
#  - **Section 1:** Setting up your developer account, using OAuth1 authentication (approx 45-120 minutes)
#  - **Sections 2 & 3:** Navigating the API documentation, getting your first query strings (approx 45-120 minutes)
#  - **Section 3:** Writing your API calls (approx 90 - 360 minutes)
#
# #### What You'll Turn In:
#  - A `.py` (not a Notebook!) file that contains the functions that you were prompted to create.  These should contain comments demonstrating why your code does what it does, and after it's run, the instructor should be able to make the appropriate function calls in Spyder or any other IDE.

# %% [markdown]
# ## Section 1:  Setting Up Your Developer Account

# %% [markdown]
# Most API's require you to do a little pre-work in order to be able to use them, so the first part of this homework assignment will be spent setting up your developer account so you have API Access.

# %% [markdown]
# **Step 1:  Create a Twitter Developer Account**
#
#  - Make sure you have a regular twitter account before you do this
#  - You can apply for a developer account here:  https://developer.twitter.com/en/apply-for-access
#   - Choose either a student or hobbyist/personal account
#   - **note:** these typically get approved right away, but it's possible you might have to wait a little bit......if 15 minutes pass, it might be best to take a break and come back in an hour or so.

# %% [markdown]
# **Step 2:  Create An App**
#
# You don't have to intend to build an official software program to have an app.....this is just a way for you to get authentication keys to use with the API.
#
#  - Go to the menu in the upper right hand corner and click on **Your Name** > **Apps**
#  - Choose **Create An App**
#  - You'll be prompted to enter some information about your app.  Don't worry too much about this, it can say almost anything.  You'll be prompted to list websites where it will be hosted...this can be anything for now.  Use https://generalassemb.ly if you're undecided about what to put.

# %% [markdown]
# **Step 3: Create Your API Tokens**
#
# Now that you have an app, you can use its API tokens to go ahead and make requests like we did in class 3.  Like a lot of API's, the Twitter API uses something called OAuth authentication.
#
# If you didn't wait until the night before this assignment was due and have a spare 30 minutes, you can read a little about it here: https://oauth.net/
#
# In any event, you need API tokens in order to make requests.  Do the following:
#
#  - Go to the **Apps** section of your developer portal
#  - Click on the **Details** button for the app that you just created
#  - Click on the **Keys & Tokens** tab:
#    - Two keys should already be given to you:  **API Key** & **API Secret Key**
#    - Two you have to generate:  **Access token** & **Access token secret**
#  - Generate your Access Token and Access Token Secret keys.  You'll need to write these down when you're done -- you can only see them once.
#
# Now you're ready to make requests to the Twitter api.  Everytime you make a request, you'll need to include the 4 tokens you just created.  (You can always regenerate them for whatever reason).

# %% [markdown]
# **Step 4:  Your First Request**
#
# To make requests to the Twitter API you're going to need a module which is **not** already pre-installed in Anaconda. You'll need to install it via PIP, which is python's package manager.  It's called `requests_oauthlib`.  You can install this via Anaconda Prompt or Terminal by simply typing in the command `pip install requests_oauthlib`, and then you'll be finished.
#
# The logistics of making an OAuth1 authenticated request are very similar to what was done in class 3, but with a few additional steps.  You can see how to do it here:  https://requests.readthedocs.io/en/master/user/authentication/#oauth-1-authentication.  The only thing you'll need to change is the info for your API tokens that are passed into the `OAuth1()` function.
#
# Try making a request to the following URL to confirm that you have things set up correctly: 'https://api.twitter.com/1.1/account/verify_credentials.json'

# %%
# your code here
import requests
from requests_oauthlib import OAuth1

url = 'https://api.twitter.com/1.1/search/tweets.json?q=%23datascience&src=typed_query'
auth = OAuth1('r8ZOzLMZoouq5u8iCdmNKiSMx', 'tIqgdrMHBrkMRXfBlY36cUpxDw34LygVL9hBg5A4Dl0yIQLOAb','1216043853284827136-XgLCLf15GtZZ0oIsgInUIjJT1lnPmT', 'ksKmplYg3WBqwThvTbhknJmhBYE7t43Bt0ZijmExr2Nq2')

req = requests.get(url, auth=auth)

# %%
twitter_data = req.json()

# %%
type(twitter_data)
# Out:
# dict

# %%
twitter_data.keys()
# Out:
# dict_keys(['statuses', 'search_metadata'])

# %% [markdown]
# If you get your json object back, then you're good to go.

# %% [markdown]
# ## Section 2: Searching Tweets

# %% [markdown]
# Most websites you access will have a long string attached to the end of them that look something like this:  `http://thewebsite.com/?year=2019&color=golden%20yellow&user_id=48549395959438`.
#
# Most people have no reason to pay attention to any of this, but all the special symbols at the end are basically encoded commands that say 'return a website that displays x,y,z characteristics.'
#
# When accessing api data, it basically works the same way.

# %% [markdown]
# **Step 1:  Set Up Your First Query String**

# %% [markdown]
# If you go into Twitter and search for the term `Data Science`, you should be brought to a url that looks like this:  `https://twitter.com/search?q=Data%20Science&src=typed_query`
#
# If you'd like, you can drop the `&src=typed_query` from the url and still get the same results.
#
# There are some important details to pay attention to:
#
#  - Like class 3 when we worked with GitHub, there is a **base url**.  In this case it's `https://twitter.com/search`
#  - Whenever you enter a search for something, the base url will be followed by something that looks like `?q=My%20Search%20Term`
#   - The `?` marks the beginning of the query string.  This basically says 'initiate a request with whatever parameters that follow'
#   - The `q` is a **parameter**, essentially some condition to pass into the query string that determines what results will be given back to you.  In this case, `q` encodes the text you typed in into something the API can understand.
#
# **Useful Thing To Do Right Now:** Go back to the Twitter search page, and just try searching for different things, and notice what shows up after the `q=`.  Here are some questions to ask yourself:
#
#  - How are white spaces encoded?  Ie, if you search for `Jonathan Bechtel` in the search box, what shows up to account for the space between the two words?
#  - What about hash symbols?  If you search for `#MeToo`, `#GirlsWhoCode` or `#DataScience`, what happens with that `#` symbol?
#  - Once you get the hang of this, see if you can just re-create some searches yourself by creating the url directly, and bypassing the search box altogether.  Ie, be familiar enough with how searches are formatted that you know `https://twitter.com/search?q=%23DataScience` will take you to the same page as typing in `#DataScience` into the search box.
#
# Now, let's try and make a request for a search for `Data Science`.
#
# If you look at Twitter's docs, you'll see that the base url for the search API is `'https://api.twitter.com/1.1/search/tweets.json`
#
# This means you have to add the `?q=Whatever%20Word%20%Goes%20Here` to the end to complete the search.
#
# So go ahead, and see if you can create your API call for a search for the term `Data Science`.
#
# If you did it correctly, you should have a dictionary with a key called `statuses`, and it'll be a list with all of the tweets returned by your search.

# %%
# your answer here
url = 'https://api.twitter.com/1.1/search/tweets.json?q=%23datascience&src=typed_query'
req = requests.get(url, auth=auth)
ds_data = req.text
#ds_data = req.json()
ds_data
# Out:
# '{"statuses":[{"created_at":"Sat Nov 07 02:26:13 +0000 2020","id":1324900936767082496,"id_str":"1324900936767082496","text":"RT @5stocksinto: 5 Indonesian Stocks Into Software https:\\/\\/t.co\\/XB2NBi7gDp  #Indonesia #software #Stocks #technology #erp #digital #mobilea\\u2026","truncated":false,"entities":{"hashtags":[{"text":"Indonesia","indices":[76,86]},{"text":"software","indices":[87,96]},{"text":"Stocks","indices":[97,104]},{"text":"technology","indices":[105,116]},{"text":"erp","indices":[117,121]},{"text":"digital","indices":[122,130]}],"symbols":[],"user_mentions":[{"screen_name":"5stocksinto","name":"Andrew Duff","id":760674570458140673,"id_str":"760674570458140673","indices":[3,15]}],"urls":[{"url":"https:\\/\\/t.co\\/XB2NBi7gDp","expanded_url":"http:\\/\\/www.5stocksinto.com\\/5-indonesian-stocks-into-software\\/","display_url":"5stocksinto.com\\/5-indonesian-s\\u2026","indices":[51,74]}]},"metadata":{"iso_language_code":"it","result_type":"recent"},"source":"\\u003ca href=\\"https:\\/\\/mobile.twitter.com\\" rel=\\"nofollow\\"\\u003eTwitter Web App\\u003c\\/a\\u003e","in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":760674570458140673,"id_str":"760674570458140673","name":"Andrew Duff","screen_name":"5stocksinto","location":"WorldWide","description":"https:\\/\\/t.co\\/2DGAgeKzSQ - #Author - Addicted to #BigData #IoT #AI #China #manufacturing #Stocks #Vietnam #Economics #startup #webdev #mobileapps #technology #automation","url":"https:\\/\\/t.co\\/aOqCirRCBM","entities":{"url":{"urls":[{"url":"https:\\/\\/t.co\\/aOqCirRCBM","expanded_url":"http:\\/\\/www.5stocksinto.com","display_url":"5stocksinto.com","indices":[0,23]}]},"description":{"urls":[{"url":"https:\\/\\/t.co\\/2DGAgeKzSQ","expanded_url":"http:\\/\\/5stocksinto.com","display_url":"5stocksinto.com","indices":[0,23]}]}},"protected":false,"followers_count":1051,"friends_count":1430,"listed_count":58,"created_at":"Wed Aug 03 03:12:05 +0000 2016","favourites_count":289,"utc_offset":null,"time_zone":null,"geo_enabled":true,"verified":false,"statuses_count":4412,"lang":null,"contributors_enabled":false,"is_translator":false,"is_translation_enabled":false,"profile_background_color":"000000","profile_background_image_url":"http:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_image_url_https":"https:\\/\\/abs.twimg.com\\/images\\/themes\\/theme1\\/bg.png","profile_background_tile":false,"profile_image_url":"http:\\/\\/pbs.twimg.com\\/profile_images\\/795614977696509952\\/vAmyonSb_normal.jpg","profile_image_url_https":"https:\\/\\/pbs.twimg.com\\/profile_images\\/795614977696509952\\/vAmyonSb_normal.jpg","profile_banner_url":"https:\\/\\/pbs.twimg.com\\/profile_banners\\/760674570458140673\\/1571187219","profile_link_color":"1B95E0","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"000000","profile_text_color":"000000","profile_use_background_image":false,"has_extended_profile":true,"default_profile":false,"default_profile_image":false,"following":false,"follow_request_sent":false,"notifications":false,"translator_type":"none"},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Thu Jul 30 08:21:15 +0000 2020","id":1288751499107958784,"id_str":"1288751499107958784","text":"5 Indonesian Stocks Into Software https:\\/\\/t.co\\/XB2NBi7gDp  #Indonesia #software #Stocks #technology #erp #digital\\u2026 https:\\/\\/t.co\\/clbUg4M5O9","truncated":true,"entities":{"hashtags":[{"text":"Indonesia","indices":[59,69]},{"text":"software","indices":[70,79]},{"text":"Stocks","indices":[80,87]},{"text":"technology","indices":[88,99]},{"text":"erp","indices":[100,104]},{"text":"digital","indices":[105,113]}],"symbols":[],"user_mentions":[],"urls":[{"url":"https:\\/\\/t.co\\/XB2NBi7gDp","expanded_url":"http:\\/\\/www.5stocksinto.com\\/5-indonesian-stocks-into-software\\/","disp ...

# %% [markdown]
# For good measure, try doing a search for tweets relating to `#MeToo` as well.

# %%
# your answer here
twitter_url = 'https://twitter.com/search?q=%23metoo&src=typed_query'
api_url ='https://api.twitter.com/1.1/search/tweets.json?q=%23metoo'
req = requests.get(api_url, auth=auth)
me_too_data = req.text
#me_too_data = req.json()
me_too_data
# Out:
# '{"statuses":[{"created_at":"Sat Nov 07 02:26:54 +0000 2020","id":1324901109010321408,"id_str":"1324901109010321408","text":"RT @NoStatism: The #MeToo President #CreepyJoe https:\\/\\/t.co\\/S0U6Nvu4A7","truncated":false,"entities":{"hashtags":[{"text":"MeToo","indices":[19,25]},{"text":"CreepyJoe","indices":[36,46]}],"symbols":[],"user_mentions":[{"screen_name":"NoStatism","name":"Say No to Statism \\ud83c\\udff4","id":1019131050,"id_str":"1019131050","indices":[3,13]}],"urls":[],"media":[{"id":1322903534875136000,"id_str":"1322903534875136000","indices":[47,70],"media_url":"http:\\/\\/pbs.twimg.com\\/ext_tw_video_thumb\\/1322903534875136000\\/pu\\/img\\/87iuZ90wCz3QCKm-.jpg","media_url_https":"https:\\/\\/pbs.twimg.com\\/ext_tw_video_thumb\\/1322903534875136000\\/pu\\/img\\/87iuZ90wCz3QCKm-.jpg","url":"https:\\/\\/t.co\\/S0U6Nvu4A7","display_url":"pic.twitter.com\\/S0U6Nvu4A7","expanded_url":"https:\\/\\/twitter.com\\/BreitbartNews\\/status\\/1322903928711843842\\/video\\/1","type":"photo","sizes":{"thumb":{"w":150,"h":150,"resize":"crop"},"small":{"w":680,"h":680,"resize":"fit"},"medium":{"w":720,"h":720,"resize":"fit"},"large":{"w":720,"h":720,"resize":"fit"}},"source_status_id":1322903928711843842,"source_status_id_str":"1322903928711843842","source_user_id":457984599,"source_user_id_str":"457984599"}]},"extended_entities":{"media":[{"id":1322903534875136000,"id_str":"1322903534875136000","indices":[47,70],"media_url":"http:\\/\\/pbs.twimg.com\\/ext_tw_video_thumb\\/1322903534875136000\\/pu\\/img\\/87iuZ90wCz3QCKm-.jpg","media_url_https":"https:\\/\\/pbs.twimg.com\\/ext_tw_video_thumb\\/1322903534875136000\\/pu\\/img\\/87iuZ90wCz3QCKm-.jpg","url":"https:\\/\\/t.co\\/S0U6Nvu4A7","display_url":"pic.twitter.com\\/S0U6Nvu4A7","expanded_url":"https:\\/\\/twitter.com\\/BreitbartNews\\/status\\/1322903928711843842\\/video\\/1","type":"video","sizes":{"thumb":{"w":150,"h":150,"resize":"crop"},"small":{"w":680,"h":680,"resize":"fit"},"medium":{"w":720,"h":720,"resize":"fit"},"large":{"w":720,"h":720,"resize":"fit"}},"source_status_id":1322903928711843842,"source_status_id_str":"1322903928711843842","source_user_id":457984599,"source_user_id_str":"457984599","video_info":{"aspect_ratio":[1,1],"duration_millis":122990,"variants":[{"bitrate":432000,"content_type":"video\\/mp4","url":"https:\\/\\/video.twimg.com\\/ext_tw_video\\/1322903534875136000\\/pu\\/vid\\/320x320\\/LgcrzedYl0Hpy_kV.mp4?tag=10"},{"bitrate":1280000,"content_type":"video\\/mp4","url":"https:\\/\\/video.twimg.com\\/ext_tw_video\\/1322903534875136000\\/pu\\/vid\\/720x720\\/yz_LPB2pXPwlqivZ.mp4?tag=10"},{"bitrate":832000,"content_type":"video\\/mp4","url":"https:\\/\\/video.twimg.com\\/ext_tw_video\\/1322903534875136000\\/pu\\/vid\\/480x480\\/xOHiswWBYn61qfuL.mp4?tag=10"},{"content_type":"application\\/x-mpegURL","url":"https:\\/\\/video.twimg.com\\/ext_tw_video\\/1322903534875136000\\/pu\\/pl\\/dGecVQiy4MbxZdtq.m3u8?tag=10"}]},"additional_media_info":{"monetizable":false}}]},"metadata":{"iso_language_code":"en","result_type":"recent"},"source":"\\u003ca href=\\"http:\\/\\/twitter.com\\/download\\/iphone\\" rel=\\"nofollow\\"\\u003eTwitter for iPhone\\u003c\\/a\\u003e","in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":797516322288476160,"id_str":"797516322288476160","name":"Kan","screen_name":"kstaypositive_","location":"","description":"","url":null,"entities":{"description":{"urls":[]}},"protected":false,"followers_count":3,"friends_count":41,"listed_count":0,"created_at":"Sat Nov 12 19:08:03 +0000 2016","favourites_count":498,"utc_offset":null,"time_zone":null,"geo_enabled":false,"verified":false,"statuses_count":2355,"lang":null,"contributors_enabled":false,"is_translator":false,"is_translation_enabled":false,"profile_background_color":"F5F8FA","profile_background_image_url":null,"profile_background_image_url_https":null,"profile_background_tile":false ...

# %% [markdown]
# **Step 2:  Adding Parameters to Your Query String**

# %% [markdown]
# Query strings basically have two parts:
#
#  - The `?` initiates the beginning of the API call, and basically says 'everything that follows this will encode something about the information that's going to get returned to you'.
#  - What follows that is are a bunch of symbols followed by `=` signs.  These are parameters.
#  - So when you make an api call to `'https://api.twitter.com/1.1/search/tweets.json?q=My%20Search%20Term`, the `q` is a paremeter.
#  - You can add multiple paremeters to a query string. They are separated by `&`. They dictate what kinds of results are returned.
#   - For example, a parameter you can use in Twitter's search API is `count`, which tells you how many results to return.  The default is 15, but you can return up to 100.  So if we wanted to search for tweets and return 50 results our query string would look like the following:
#     `https://api.twitter.com/1.1/search/tweets.json?q=My%20Search%20String&count=50`
#   - You can add as many of these parameters to your string as you'd like.  So for example, if we wanted to include parameters for `count` and `result_type`, we could do the following: `https://api.twitter.com/1.1/search/tweets.json?q=My%20Search%20String&count=50&result_type=mixed`
#
# To get the hang of this, try searching for tweets that mention the hashtag `#DeepLearning`, and return 75 results.

# %%
api_url ='https://api.twitter.com/1.1/search/tweets.json?q=%23metoo&count=50'
me_too_fifty_req = requests.get(api_url, auth=auth)

# %%
me_too_fifty_req.json()
# Out:
# {'statuses': [{'created_at': 'Sun Nov 01 19:23:23 +0000 2020',
#    'id': 1322982589058158595,
#    'id_str': '1322982589058158595',
#    'text': '@Kemasda23 #meToo',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'meToo', 'indices': [11, 17]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Kemasda23',
#       'name': 'KEMASDA',
#       'id': 965333013948182529,
#       'id_str': '965333013948182529',
#       'indices': [0, 10]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1322911872945893376,
#    'in_reply_to_status_id_str': '1322911872945893376',
#    'in_reply_to_user_id': 965333013948182529,
#    'in_reply_to_user_id_str': '965333013948182529',
#    'in_reply_to_screen_name': 'Kemasda23',
#    'user': {'id': 421229385,
#     'id_str': '421229385',
#     'name': 'Marian LB',
#     'screen_name': 'marialilb',
#     'location': 'con los pies en la tierra. ',
#     'description': "Teacher, mother, wife and Mateo’s grandmather. Trying to be happy. Malos tiempos para los honrados. Don't worry, nothing is eternal.💚#lutoNacional #✝️noseToca",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 8497,
#     'friends_count': 8403,
#     'listed_count': 287,
#     'created_at': 'Fri Nov 25 17:34:10 +0000 2011',
#     'favourites_count': 26285,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 446110,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1317561257231253504/J34UMlVk_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1317561257231253504/J34UMlVk_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/421229385/1602966058',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'},
#   {'created_at': 'Sun Nov 01 19:23:12 +0000 2020',
#    'id': 1322982540039331840,
#    'id_str': '1322982540039331840',
#    'text': 'RT @tasteofsanity: It is not Johnny Depp’s fault that Amber Heard abused and then lied to the world about him. He deserves justice, as do a…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'tasteofsanity',
#       'name': 'Dee',
#       'id': 194988081,
#       'id_str': '194988081',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 26799563,
#     'id_str': '26799563',
#     'name': 'Reynier the Fox',
#     'screen_name': 'LightRey',
#     'location': 'Netherlands',
#     'description': 'Generally speaking, being a philosopher means being the most annoying person in the room.\n\nI am that room.',
#     'url': 'https://t.co/7pDh2ntp8W',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/7pDh2ntp8W',
#         'expanded_url': 'http://reynierthefox.wordpress.com',
#         'display_url': 'reynierthefox.wordpress.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 529,
#     'friends_count': 205,
#     'listed_count': 1,
#     'created_at': 'Thu Mar 26 17:30:27 +0000 2009',
#     'favourites_count': 37482,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 10938,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1261654334149967882/VCA2GoxI_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261654334149967882/VCA2GoxI_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26799563/1524578903',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDFFCC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Nov 01 18:44:16 +0000 2020',
#     'id': 1322972742463983617,
#     'id_str': '1322972742463983617',
#     'text': 'It is not Johnny Depp’s fault that Amber Heard abused and then lied to the world about him. He deserves justice, as… https://t.co/MrjGDoSSoT',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/MrjGDoSSoT',
#        'expanded_url': 'https://twitter.com/i/web/status/1322972742463983617',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 194988081,
#      'id_str': '194988081',
#      'name': 'Dee',
#      'screen_name': 'tasteofsanity',
#      'location': 'New Yawk',
#      'description': "Donald Trump is bad, Johnny Depp is innocent. Let's argue.",
#      'url': 'https://t.co/SGbHj9vmzv',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/SGbHj9vmzv',
#          'expanded_url': 'https://medium.com/@d.handover',
#          'display_url': 'medium.com/@d.handover',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1882,
#      'friends_count': 283,
#      'listed_count': 12,
#      'created_at': 'Sat Sep 25 14:17:07 +0000 2010',
#      'favourites_count': 24307,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 16148,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1321512258321715200/jQ3uIGDf_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1321512258321715200/jQ3uIGDf_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/194988081/1603481777',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 43,
#     'favorite_count': 144,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 43,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Nov 01 19:22:54 +0000 2020',
#    'id': 1322982466131386373,
#    'id_str': '1322982466131386373',
#    'text': 'RT @book_tribe: • ⭐⭐⭐⭐⭐ Amazon &amp; Goodreads: "Being a victim of rape myself, this was a very emotional read for me" V. Whedbee #MeToo https:…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [130, 136]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'book_tribe',
#       'name': 'Book Promotion #ad',
#       'id': 250309546,
#       'id_str': '250309546',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2379495919,
#     'id_str': '2379495919',
#     'name': 'MeggyH',
#     'screen_name': 'meggh2020',
#     'location': '',
#     'description': '😀  Some of my favourite things --    🐶  🐱  🙉 🌲🌸 🌞 🍎 🍕 ☕️ 🎼 ❤️',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1291,
#     'friends_count': 1663,
#     'listed_count': 1,
#     'created_at': 'Sun Mar 09 00:04:59 +0000 2014',
#     'favourites_count': 75,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2297,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/972612653142097920/VOnwHEzR_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/972612653142097920/VOnwHEzR_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2379495919/1520723803',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Nov 01 14:35:22 +0000 2020',
#     'id': 1322910104916811776,
#     'id_str': '1322910104916811776',
#     'text': '• ⭐⭐⭐⭐⭐ Amazon &amp; Goodreads: "Being a victim of rape myself, this was a very emotional read for me" V. Whedbee… https://t.co/9j5r5HjWM3',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/9j5r5HjWM3',
#        'expanded_url': 'https://twitter.com/i/web/status/1322910104916811776',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [115, 138]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://askdavid.com" rel="nofollow">AskDavid.com Services</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 250309546,
#      'id_str': '250309546',
#      'name': 'Book Promotion #ad',
#      'screen_name': 'book_tribe',
#      'location': 'Here, There and Everywhere',
#      'description': 'Authors, Writers - Get Promotion For Your Books. Readers find great new books to read.\r\nhttp://t.co/ZGs4k2mupm',
#      'url': 'http://t.co/Keael1i1mV',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/Keael1i1mV',
#          'expanded_url': 'http://askDavid.com',
#          'display_url': 'askDavid.com',
#          'indices': [0, 22]}]},
#       'description': {'urls': [{'url': 'http://t.co/ZGs4k2mupm',
#          'expanded_url': 'http://askdavid.com/book-promotion',
#          'display_url': 'askdavid.com/book-promotion',
#          'indices': [88, 110]}]}},
#      'protected': False,
#      'followers_count': 57064,
#      'friends_count': 38786,
#      'listed_count': 1643,
#      'created_at': 'Thu Feb 10 21:01:39 +0000 2011',
#      'favourites_count': 305,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 391614,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '131516',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/605116406724706304/3zmRL_LG_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/605116406724706304/3zmRL_LG_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/250309546/1402513767',
#      'profile_link_color': '009999',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'EFEFEF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Nov 01 19:22:41 +0000 2020',
#    'id': 1322982412238917639,
#    'id_str': '1322982412238917639',
#    'text': '@Treptsjr @RealBrysonGray @TonyBrunoShow #MeToo   Pa , we really need every vote here. make 5 more people go #VOTE',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [41, 47]},
#      {'text': 'VOTE', 'indices': [109, 114]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Treptsjr',
#       'name': 'Hersh',
#       'id': 342755546,
#       'id_str': '342755546',
#       'indices': [0, 9]},
#      {'screen_name': 'RealBrysonGray',
#       'name': 'Bryson Gray',
#       'id': 2945287090,
#       'id_str': '2945287090',
#       'indices': [10, 25]},
#      {'screen_name': 'TonyBrunoShow',
#       'name': 'Tony Bruno',
#       'id': 22099513,
#       'id_str': '22099513',
#       'indices': [26, 40]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1322981126378606593,
#    'in_reply_to_status_id_str': '1322981126378606593',
#    'in_reply_to_user_id': 342755546,
#    'in_reply_to_user_id_str': '342755546',
#    'in_reply_to_screen_name': 'Treptsjr',
#    'user': {'id': 1079441991145062405,
#     'id_str': '1079441991145062405',
#     'name': '👠 Lucy 💕 for trump',
#     'screen_name': 'Trump_magaDeals',
#     'location': '#New York #USA',
#     'description': "#Mistress Lucy\n#MAGA  #independent\n#believer in god\nLet's do it together  😀",
#     'url': 'https://t.co/1Fe9L5BrAs',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/1Fe9L5BrAs',
#         'expanded_url': 'https://www.youtube.com/channel/UCiGi3FwiOCdvaKNXs3chzaQ?view_as=subscriber',
#         'display_url': 'youtube.com/channel/UCiGi3…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3555,
#     'friends_count': 3747,
#     'listed_count': 0,
#     'created_at': 'Sun Dec 30 18:20:00 +0000 2018',
#     'favourites_count': 7582,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2426,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1318975155192946691/JdqPP_Ua_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318975155192946691/JdqPP_Ua_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1079441991145062405/1550518081',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Nov 01 19:22:21 +0000 2020',
#    'id': 1322982327170093061,
#    'id_str': '1322982327170093061',
#    'text': '@nickles_ken @RealBrysonGray #MeToo   Pa , we really need every vote here. make 5 more people go #VOTE',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [29, 35]},
#      {'text': 'VOTE', 'indices': [97, 102]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'nickles_ken',
#       'name': 'Ken Nickles',
#       'id': 1320169914708131847,
#       'id_str': '1320169914708131847',
#       'indices': [0, 12]},
#      {'screen_name': 'RealBrysonGray',
#       'name': 'Bryson Gray',
#       'id': 2945287090,
#       'id_str': '2945287090',
#       'indices': [13, 28]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1322976479710425090,
#    'in_reply_to_status_id_str': '1322976479710425090',
#    'in_reply_to_user_id': 1320169914708131847,
#    'in_reply_to_user_id_str': '1320169914708131847',
#    'in_reply_to_screen_name': 'nickles_ken',
#    'user': {'id': 1079441991145062405,
#     'id_str': '1079441991145062405',
#     'name': '👠 Lucy 💕 for trump',
#     'screen_name': 'Trump_magaDeals',
#     'location': '#New York #USA',
#     'description': "#Mistress Lucy\n#MAGA  #independent\n#believer in god\nLet's do it together  😀",
#     'url': 'https://t.co/1Fe9L5BrAs',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/1Fe9L5BrAs',
#         'expanded_url': 'https://www.youtube.com/channel/UCiGi3FwiOCdvaKNXs3chzaQ?view_as=subscriber',
#         'display_url': 'youtube.com/channel/UCiGi3…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3555,
#     'friends_count': 3747,
#     'listed_count': 0,
#     'created_at': 'Sun Dec 30 18:20:00 +0000 2018',
#     'favourites_count': 7582,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2426,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1318975155192946691/JdqPP_Ua_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318975155192946691/JdqPP_Ua_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1079441991145062405/1550518081',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Nov 01 19:22:17 +0000 2020',
#    'id': 1322982309683961861,
#    'id_str': '1322982309683961861',
#    'text': '@kalemoll Omdat #metoo heilig is. Die gast is een schoft en, vooral, ziek. Maar deze lengte gaat iedere redelijkheid voorbij.',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'metoo', 'indices': [16, 22]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'kalemoll',
#       'name': 'hans moll',
#       'id': 206247977,
#       'id_str': '206247977',
#       'indices': [0, 9]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'nl', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1322981759332601856,
#    'in_reply_to_status_id_str': '1322981759332601856',
#    'in_reply_to_user_id': 206247977,
#    'in_reply_to_user_id_str': '206247977',
#    'in_reply_to_screen_name': 'kalemoll',
#    'user': {'id': 121374851,
#     'id_str': '121374851',
#     'name': 'Arnoud',
#     'screen_name': 'ArnoudVbrief',
#     'location': 'Ergens in de flexibele schil',
#     'description': 'Schoolfrik op een gym.\nNu zien wij nog in een spiegel, straks van aangezicht tot aangezicht. Korinthiërs 13:12',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2800,
#     'friends_count': 892,
#     'listed_count': 62,
#     'created_at': 'Tue Mar 09 09:05:44 +0000 2010',
#     'favourites_count': 26486,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 163552,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1283166562925580289/edtTEXYn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1283166562925580289/edtTEXYn_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/121374851/1601757975',
#     'profile_link_color': '02730D',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '5BB0EB',
#     'profile_text_color': '222222',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'nl'},
#   {'created_at': 'Sun Nov 01 19:22:00 +0000 2020',
#    'id': 1322982241279135753,
#    'id_str': '1322982241279135753',
#    'text': 'RT @BKantlie: Ali Zafar awarded Nishan-e-Pakistan for sending record number of defamation notices: https://t.co/bEJfqkdT0h #alizafar #MeToo…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'alizafar', 'indices': [123, 132]},
#      {'text': 'MeToo', 'indices': [133, 139]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'BKantlie',
#       'name': 'Billie Kantlie',
#       'id': 1316322766438707205,
#       'id_str': '1316322766438707205',
#       'indices': [3, 12]}],
#     'urls': [{'url': 'https://t.co/bEJfqkdT0h',
#       'expanded_url': 'https://www.bkantlie.com/post/ali-zafar-awarded-nishan-e-pakistan-for-sending-record-number-of-defamation-notices',
#       'display_url': 'bkantlie.com/post/ali-zafar…',
#       'indices': [99, 122]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1421702587,
#     'id_str': '1421702587',
#     'name': 'M',
#     'screen_name': 'persephk_',
#     'location': '',
#     'description': "i'm not your problem anymore so who am i offending now?",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 501,
#     'friends_count': 299,
#     'listed_count': 14,
#     'created_at': 'Sat May 11 22:02:49 +0000 2013',
#     'favourites_count': 10053,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2452,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1317342362495029249/JEqvYMaB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1317342362495029249/JEqvYMaB_normal.jpg',
#     'profile_link_color': '1C1C1C',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'F6F6F6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Nov 01 11:59:37 +0000 2020',
#     'id': 1322870909783465987,
#     'id_str': '1322870909783465987',
#     'text': 'Ali Zafar awarded Nishan-e-Pakistan for sending record number of defamation notices: https://t.co/bEJfqkdT0h… https://t.co/RwUGwhXeFj',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/bEJfqkdT0h',
#        'expanded_url': 'https://www.bkantlie.com/post/ali-zafar-awarded-nishan-e-pakistan-for-sending-record-number-of-defamation-notices',
#        'display_url': 'bkantlie.com/post/ali-zafar…',
#        'indices': [85, 108]},
#       {'url': 'https://t.co/RwUGwhXeFj',
#        'expanded_url': 'https://twitter.com/i/web/status/1322870909783465987',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [110, 133]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1316322766438707205,
#      'id_str': '1316322766438707205',
#      'name': 'Billie Kantlie',
#      'screen_name': 'BKantlie',
#      'location': 'London, England',
#      'description': 'trying to be a truer version of myself',
#      'url': 'https://t.co/aLGnkwow5f',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/aLGnkwow5f',
#          'expanded_url': 'http://bkantlie.com',
#          'display_url': 'bkantlie.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 147,
#      'friends_count': 474,
#      'listed_count': 0,
#      'created_at': 'Wed Oct 14 10:19:49 +0000 2020',
#      'favourites_count': 201,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 62,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1316341991404339202/hwpB8WfW_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1316341991404339202/hwpB8WfW_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1316322766438707205/1602676214',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 29,
#     'favorite_count': 94,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 29,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Nov 01 19:21:53 +0000 2020',
#    'id': 1322982209729437696,
#    'id_str': '1322982209729437696',
#    'text': 'Parents Against Child Sex Abuse @P_A_X_A  Needs your support!\n\nSupport parents making our community safer.\n\nDecembe… https://t.co/E2PB7mLV94',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'P_A_X_A',
#       'name': 'P.A.X.A.',
#       'id': 975476482700136449,
#       'id_str': '975476482700136449',
#       'indices': [32, 40]}],
#     'urls': [{'url': 'https://t.co/E2PB7mLV94',
#       'expanded_url': 'https://twitter.com/i/web/status/1322982209729437696',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 319731519,
#     'id_str': '319731519',
#     'name': 'Tim Lennon',
#     'screen_name': 'sflennon',
#     'location': 'Tucson, AZ',
#     'description': 'President, Survivors Network, survivor, advocate, activist, twin daughters, yoga \nBlog:   https://t.co/lxqK6WZ4ui \n@SNAPnetwork  #MeToo',
#     'url': 'https://t.co/QfTIvyssbw',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/QfTIvyssbw',
#         'expanded_url': 'http://www.SNAPnetwork.org',
#         'display_url': 'SNAPnetwork.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/lxqK6WZ4ui',
#         'expanded_url': 'http://standupspeakup.org',
#         'display_url': 'standupspeakup.org',
#         'indices': [90, 113]}]}},
#     'protected': False,
#     'followers_count': 1689,
#     'friends_count': 3261,
#     'listed_count': 9,
#     'created_at': 'Sat Jun 18 16:50:37 +0000 2011',
#     'favourites_count': 8630,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 1466,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '0099B9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1119413844042870784/yWR-E2g4_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1119413844042870784/yWR-E2g4_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/319731519/1602105349',
#     'profile_link_color': '0099B9',
#     'profile_sidebar_border_color': '5ED4DC',
#     'profile_sidebar_fill_color': '95E8EC',
#     'profile_text_color': '3C3940',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1317126925459116032,
#    'quoted_status_id_str': '1317126925459116032',
#    'quoted_status': {'created_at': 'Fri Oct 16 15:35:04 +0000 2020',
#     'id': 1317126925459116032,
#     'id_str': '1317126925459116032',
#     'text': '📣 UPDATE\nWe’ve been monitoring the COVID-19 pandemic and due to the recent rise in cases, we are no longer holding… https://t.co/Wgr93OrO06',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Wgr93OrO06',
#        'expanded_url': 'https://twitter.com/i/web/status/1317126925459116032',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 975476482700136449,
#      'id_str': '975476482700136449',
#      'name': 'P.A.X.A.',
#      'screen_name': 'P_A_X_A',
#      'location': 'Chicago, IL',
#      'description': 'Our mission at Parents Against Child Sex Abuse is to help parents save their children from sexual abuse through prevention, uncovering and healing. A 501c3 NP.',
#      'url': 'https://t.co/4tbfFv8PVs',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/4tbfFv8PVs',
#          'expanded_url': 'http://www.paxa.online',
#          'display_url': 'paxa.online',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 47,
#      'friends_count': 155,
#      'listed_count': 1,
#      'created_at': 'Sun Mar 18 20:58:11 +0000 2018',
#      'favourites_count': 332,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 223,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1254166427029946370/EGcxNRCf_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1254166427029946370/EGcxNRCf_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/975476482700136449/1585761652',
#      'profile_link_color': 'FFE700',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Nov 01 19:21:50 +0000 2020',
#    'id': 1322982199671558147,
#    'id_str': '1322982199671558147',
#    'text': 'I wonder where #metoo and all the rest of the feminist movement are at now? This would be in most places considered… https://t.co/ey00nnRovt',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'metoo', 'indices': [15, 21]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/ey00nnRovt',
#       'expanded_url': 'https://twitter.com/i/web/status/1322982199671558147',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1151509129,
#     'id_str': '1151509129',
#     'name': 'chris',
#     'screen_name': 'Gato_chris1',
#     'location': '',
#     'description': "🇩🇰🇰🇷 \nI won't respond to my own tweets cuz Twitter is not the place to have a proper conversation.",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 92,
#     'friends_count': 276,
#     'listed_count': 2,
#     'created_at': 'Tue Feb 05 17:27:19 +0000 2013',
#     'favourites_count': 9488,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3889,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'EBEBEB',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3212377457/31d097a393feada5dde940bd845ee9a8_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3212377457/31d097a393feada5dde940bd845ee9a8_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1151509129/1460215779',
#     'profile_link_color': '990000',
#     'profile_sidebar_border_color': 'DFDFDF',
#     'profile_sidebar_fill_color': 'F3F3F3',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1322903928711843842,
#    'quoted_status_id_str': '1322903928711843842',
#    'quoted_status': {'created_at': 'Sun Nov 01 14:10:49 +0000 2020',
#     'id': 1322903928711843842,
#     'id_str': '1322903928711843842',
#     'text': 'Creepy Joe! https://t.co/m95n425uX8',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1322903534875136000,
#        'id_str': '1322903534875136000',
#        'indices': [12, 35],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1322903534875136000/pu/img/87iuZ90wCz3QCKm-.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1322903534875136000/pu/img/87iuZ90wCz3QCKm-.jpg',
#        'url': 'https://t.co/m95n425uX8',
#        'display_url': 'pic.twitter.com/m95n425uX8',
#        'expanded_url': 'https://twitter.com/BreitbartNews/status/1322903928711843842/video/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 720, 'h': 720, 'resize': 'fit'},
#         'large': {'w': 720, 'h': 720, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1322903534875136000,
#        'id_str': '1322903534875136000',
#        'indices': [12, 35],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1322903534875136000/pu/img/87iuZ90wCz3QCKm-.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1322903534875136000/pu/img/87iuZ90wCz3QCKm-.jpg',
#        'url': 'https://t.co/m95n425uX8',
#        'display_url': 'pic.twitter.com/m95n425uX8',
#        'expanded_url': 'https://twitter.com/BreitbartNews/status/1322903928711843842/video/1',
#        'type': 'video',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 720, 'h': 720, 'resize': 'fit'},
#         'large': {'w': 720, 'h': 720, 'resize': 'fit'}},
#        'video_info': {'aspect_ratio': [1, 1],
#         'duration_millis': 122990,
#         'variants': [{'bitrate': 432000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1322903534875136000/pu/vid/320x320/LgcrzedYl0Hpy_kV.mp4?tag=10'},
#          {'bitrate': 1280000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1322903534875136000/pu/vid/720x720/yz_LPB2pXPwlqivZ.mp4?tag=10'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1322903534875136000/pu/vid/480x480/xOHiswWBYn61qfuL.mp4?tag=10'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/1322903534875136000/pu/pl/dGecVQiy4MbxZdtq.m3u8?tag=10'}]},
#        'additional_media_info': {'monetizable': False}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 457984599,
#      'id_str': '457984599',
#      'name': 'Breitbart News',
#      'screen_name': 'BreitbartNews',
#      'location': '',
#      'description': 'News, commentary, and destruction of the political/media establishment.',
#      'url': 'http://t.co/2sVbt3n6lO',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/2sVbt3n6lO',
#          'expanded_url': 'http://breitbart.com',
#          'display_url': 'breitbart.com',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1549416,
#      'friends_count': 114,
#      'listed_count': 9654,
#      'created_at': 'Sun Jan 08 01:50:52 +0000 2012',
#      'favourites_count': 949,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 136152,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '0C0D0D',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/949270171755077632/dw3M-58z_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/949270171755077632/dw3M-58z_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/457984599/1359997459',
#      'profile_link_color': 'FF5402',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 9309,
#     'favorite_count': 14161,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Nov 01 19:21:39 +0000 2020',
#    'id': 1322982151529340928,
#    'id_str': '1322982151529340928',
#    'text': '@bigolfoot #MeToo',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [11, 17]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'bigolfoot',
#       'name': 'Biggie Foots, CBG (👻in a ghost voice)🦍👣🌿🧙\u200d♂️',
#       'id': 1217403439,
#       'id_str': '1217403439',
#       'indices': [0, 10]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1322981220733591552,
#    'in_reply_to_status_id_str': '1322981220733591552',
#    'in_reply_to_user_id': 1217403439,
#    'in_reply_to_user_id_str': '1217403439',
#    'in_reply_to_screen_name': 'bigolfoot',
#    'user': {'id': 15382411,
#     'id_str': '15382411',
#     'name': 'beejereeno',
#     'screen_name': 'beejereeno',
#     'location': '',
# ...
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Nov 01 19:07:26 +0000 2020',
#    'id': 1322978575063146505,
#    'id_str': '1322978575063146505',
#    'text': 'RT @tasteofsanity: It is not Johnny Depp’s fault that Amber Heard abused and then lied to the world about him. He deserves justice, as do a…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'tasteofsanity',
#       'name': 'Dee',
#       'id': 194988081,
#       'id_str': '194988081',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 954577142574141440,
#     'id_str': '954577142574141440',
#     'name': 'Samwinchester50',
#     'screen_name': 'SamWin50',
#     'location': 'Tottenham Hotspur Stadium',
#     'description': '#COYS #ToDareIsToDo #TottenhamHotspur #THFC #Spurs',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 57,
#     'friends_count': 195,
#     'listed_count': 0,
#     'created_at': 'Sat Jan 20 04:51:40 +0000 2018',
#     'favourites_count': 10441,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6572,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1322100266179694594/cWRI17wt_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1322100266179694594/cWRI17wt_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/954577142574141440/1601416799',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Nov 01 18:44:16 +0000 2020',
#     'id': 1322972742463983617,
#     'id_str': '1322972742463983617',
#     'text': 'It is not Johnny Depp’s fault that Amber Heard abused and then lied to the world about him. He deserves justice, as… https://t.co/MrjGDoSSoT',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/MrjGDoSSoT',
#        'expanded_url': 'https://twitter.com/i/web/status/1322972742463983617',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 194988081,
#      'id_str': '194988081',
#      'name': 'Dee',
#      'screen_name': 'tasteofsanity',
#      'location': 'New Yawk',
#      'description': "Donald Trump is bad, Johnny Depp is innocent. Let's argue.",
#      'url': 'https://t.co/SGbHj9vmzv',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/SGbHj9vmzv',
#          'expanded_url': 'https://medium.com/@d.handover',
#          'display_url': 'medium.com/@d.handover',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1882,
#      'friends_count': 283,
#      'listed_count': 12,
#      'created_at': 'Sat Sep 25 14:17:07 +0000 2010',
#      'favourites_count': 24307,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 16148,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1321512258321715200/jQ3uIGDf_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1321512258321715200/jQ3uIGDf_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/194988081/1603481777',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 43,
#     'favorite_count': 144,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 43,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Nov 01 19:07:23 +0000 2020',
#    'id': 1322978561670713345,
#    'id_str': '1322978561670713345',
#    'text': '@livesmattershow Awesome a female wishing hoping for other women to be raped and killed 😡Is that part of the #MeToo movement?',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [109, 115]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'livesmattershow',
#       'name': 'Drew Hernandez',
#       'id': 1022693675250249729,
#       'id_str': '1022693675250249729',
#       'indices': [0, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1322968689269002247,
#    'in_reply_to_status_id_str': '1322968689269002247',
#    'in_reply_to_user_id': 1022693675250249729,
#    'in_reply_to_user_id_str': '1022693675250249729',
#    'in_reply_to_screen_name': 'livesmattershow',
#    'user': {'id': 147968337,
#     'id_str': '147968337',
#     'name': 'Susan Pinto Tulino',
#     'screen_name': 'missy204',
#     'location': 'Florida, USA',
#     'description': '“No Act Of Kindness, No Matter How Small, Is Ever Wasted”.....Proud American, Veteran, Retired LEO',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 168,
#     'friends_count': 356,
#     'listed_count': 0,
#     'created_at': 'Tue May 25 14:09:17 +0000 2010',
#     'favourites_count': 21817,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 689,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/751267995805032448/0Rt5rBiu_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/751267995805032448/0Rt5rBiu_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Nov 01 19:07:21 +0000 2020',
#    'id': 1322978552644591617,
#    'id_str': '1322978552644591617',
#    'text': 'A New Jersey cop sent sexually explicit texts to an 18-year-old woman hours after he arrested her...… https://t.co/Lv1PAUg8Ng',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/Lv1PAUg8Ng',
#       'expanded_url': 'https://twitter.com/i/web/status/1322978552644591617',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [102, 125]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 17988368,
#     'id_str': '17988368',
#     'name': 'JamericanSpice',
#     'screen_name': 'Jamericanspice',
#     'location': 'Louisiana',
#     'description': 'Jesus Christ Disciple, Mom, #Music lover, PR Friendly, #Giveaways, #Reviews, #Photography, #Social Media, \nhttps://t.co/SLgF5vM7lS\n$CSPapillion',
#     'url': 'https://t.co/k0YdRvsyre',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/k0YdRvsyre',
#         'expanded_url': 'https://www.instagram.com/jamericansspice/',
#         'display_url': 'instagram.com/jamericansspic…',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/SLgF5vM7lS',
#         'expanded_url': 'http://paypal.me/ColetteS',
#         'display_url': 'paypal.me/ColetteS',
#         'indices': [107, 130]}]}},
#     'protected': False,
#     'followers_count': 16883,
#     'friends_count': 10287,
#     'listed_count': 434,
#     'created_at': 'Tue Dec 09 09:48:29 +0000 2008',
#     'favourites_count': 195,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 60895,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'DEED0E',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/992438394117484544/878n4wFD_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/992438394117484544/878n4wFD_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17988368/1524277960',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '66C4F7',
#     'profile_text_color': '3D0469',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Nov 01 19:06:47 +0000 2020',
#    'id': 1322978412026191872,
#    'id_str': '1322978412026191872',
#    'text': '@ily2butplsyaar #MeToo',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [16, 22]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ily2butplsyaar',
#       'name': 'agent p',
#       'id': 1268203860620763136,
#       'id_str': '1268203860620763136',
#       'indices': [0, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1322759217632047104,
#    'in_reply_to_status_id_str': '1322759217632047104',
#    'in_reply_to_user_id': 1268203860620763136,
#    'in_reply_to_user_id_str': '1268203860620763136',
#    'in_reply_to_screen_name': 'ily2butplsyaar',
#    'user': {'id': 829370699559141377,
#     'id_str': '829370699559141377',
#     'name': "Kalpan // My name and Life both ain't got meaning.",
#     'screen_name': 'ImmmALooserrrr',
#     'location': 'Ahmedabad, India',
#     'description': '| Ever | Never | Forever | Whatever |',
#     'url': 'https://t.co/TK6oWRYISM',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/TK6oWRYISM',
#         'expanded_url': 'https://www.instagram.com/an_insane_insan/',
#         'display_url': 'instagram.com/an_insane_insa…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 333,
#     'friends_count': 385,
#     'listed_count': 0,
#     'created_at': 'Wed Feb 08 16:45:58 +0000 2017',
#     'favourites_count': 2956,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2180,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1322605994334040065/q_xfcyWi_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1322605994334040065/q_xfcyWi_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/829370699559141377/1603537571',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'}],
#  'search_metadata': {'completed_in': 0.13,
#   'max_id': 1322982589058158595,
#   'max_id_str': '1322982589058158595',
#   'next_results': '?max_id=1322978412026191871&q=%23metoo&count=50&include_entities=1',
#   'query': '%23metoo',
#   'refresh_url': '?since_id=1322982589058158595&q=%23metoo&include_entities=1',
#   'count': 50,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# Try adding a second parameter.  You can find the list here:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets

# %%
api_url ='https://api.twitter.com/1.1/search/tweets.json?q=%23metoo&count=50&lang=en'
me_too_fifty_req = requests.get(api_url, auth=auth)
me_too_fifty_req.json()
# Out:
# {'statuses': [{'created_at': 'Sat Nov 07 02:29:11 +0000 2020',
#    'id': 1324901681994199041,
#    'id_str': '1324901681994199041',
#    'text': '@lucasbet49 Sorry, not a gambler as such, HOWEVER l did put my money where my mouth was in suing someone for raping… https://t.co/zpASMvE3Qh',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'lucasbet49',
#       'name': 'Lucasbet',
#       'id': 1293727664033816576,
#       'id_str': '1293727664033816576',
#       'indices': [0, 11]}],
#     'urls': [{'url': 'https://t.co/zpASMvE3Qh',
#       'expanded_url': 'https://twitter.com/i/web/status/1324901681994199041',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1320505342166355969,
#    'in_reply_to_status_id_str': '1320505342166355969',
#    'in_reply_to_user_id': 1293727664033816576,
#    'in_reply_to_user_id_str': '1293727664033816576',
#    'in_reply_to_screen_name': 'lucasbet49',
#    'user': {'id': 935302265593667585,
#     'id_str': '935302265593667585',
#     'name': 'Marita Murphy',
#     'screen_name': 'MaritaMurphy7',
#     'location': 'Victoria, Australia',
#     'description': 'MARITA FOR JUSTICE.             https://t.co/NPd8fe8XqR.  #metoo Aged 7 fighting for justice.',
#     'url': None,
#     'entities': {'description': {'urls': [{'url': 'https://t.co/NPd8fe8XqR',
#         'expanded_url': 'http://chng.it/NkGtGccyXg',
#         'display_url': 'chng.it/NkGtGccyXg',
#         'indices': [32, 55]}]}},
#     'protected': False,
#     'followers_count': 249,
#     'friends_count': 1810,
#     'listed_count': 2,
#     'created_at': 'Tue Nov 28 00:20:12 +0000 2017',
#     'favourites_count': 1835,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3555,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1147471585722294273/4tDefcP2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1147471585722294273/4tDefcP2_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/935302265593667585/1562413779',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 07 02:29:10 +0000 2020',
#    'id': 1324901680236916738,
#    'id_str': '1324901680236916738',
#    'text': '@Keptopolarbear they ditch that #MeToo so fast, its head still spinning.',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [32, 38]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Keptopolarbear',
#       'name': 'Everyone Goes To Prison 2020',
#       'id': 960718931983028225,
#       'id_str': '960718931983028225',
#       'indices': [0, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1324899869874659328,
#    'in_reply_to_status_id_str': '1324899869874659328',
#    'in_reply_to_user_id': 960718931983028225,
#    'in_reply_to_user_id_str': '960718931983028225',
#    'in_reply_to_screen_name': 'Keptopolarbear',
#    'user': {'id': 35371381,
#     'id_str': '35371381',
#     'name': 'RGB riots start in 5....4...3 ...2... 🇭🇹',
#     'screen_name': 'distorsun',
#     'location': 'Ongjin-gun, Republic of Korea',
#     'description': 'unjust laws are meaningless laws.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 592,
#     'friends_count': 847,
#     'listed_count': 7,
#     'created_at': 'Sun Apr 26 01:57:45 +0000 2009',
#     'favourites_count': 41111,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 55556,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1319310985312800768/HJaj8_FG_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1319310985312800768/HJaj8_FG_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/35371381/1531110486',
#     'profile_link_color': 'FF691F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 07 02:28:31 +0000 2020',
#    'id': 1324901517862776832,
#    'id_str': '1324901517862776832',
#    'text': '@RealJamesWoods @aoc\n\nI stand with James Woods. If you put him on your list, #metoo.',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'metoo', 'indices': [77, 83]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'RealJamesWoods',
#       'name': 'James Woods',
#       'id': 78523300,
#       'id_str': '78523300',
#       'indices': [0, 15]},
#      {'screen_name': 'AOC',
#       'name': 'Alexandria Ocasio-Cortez',
#       'id': 138203134,
#       'id_str': '138203134',
#       'indices': [16, 20]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1324897029630222337,
#    'in_reply_to_status_id_str': '1324897029630222337',
#    'in_reply_to_user_id': 78523300,
#    'in_reply_to_user_id_str': '78523300',
#    'in_reply_to_screen_name': 'RealJamesWoods',
#    'user': {'id': 1318699673113198592,
#     'id_str': '1318699673113198592',
#     'name': 'Closed Overton Window',
#     'screen_name': '2022_future',
#     'location': '',
#     'description': 'Just here for the news. Blocking advertisers and Leftists, whom I want nothing to do with.\n#Trump2020',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 10,
#     'friends_count': 177,
#     'listed_count': 0,
#     'created_at': 'Tue Oct 20 23:46:01 +0000 2020',
#     'favourites_count': 4774,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 537,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1319634068817006592/LNKUeWUE_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1319634068817006592/LNKUeWUE_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 07 02:26:54 +0000 2020',
#    'id': 1324901109010321408,
#    'id_str': '1324901109010321408',
#    'text': 'RT @NoStatism: The #MeToo President #CreepyJoe https://t.co/S0U6Nvu4A7',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [19, 25]},
#      {'text': 'CreepyJoe', 'indices': [36, 46]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'NoStatism',
#       'name': 'Say No to Statism 🏴',
#       'id': 1019131050,
#       'id_str': '1019131050',
#       'indices': [3, 13]}],
#     'urls': [],
#     'media': [{'id': 1322903534875136000,
#       'id_str': '1322903534875136000',
#       'indices': [47, 70],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1322903534875136000/pu/img/87iuZ90wCz3QCKm-.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1322903534875136000/pu/img/87iuZ90wCz3QCKm-.jpg',
#       'url': 'https://t.co/S0U6Nvu4A7',
#       'display_url': 'pic.twitter.com/S0U6Nvu4A7',
#       'expanded_url': 'https://twitter.com/BreitbartNews/status/1322903928711843842/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 720, 'h': 720, 'resize': 'fit'},
#        'large': {'w': 720, 'h': 720, 'resize': 'fit'}},
#       'source_status_id': 1322903928711843842,
#       'source_status_id_str': '1322903928711843842',
#       'source_user_id': 457984599,
#       'source_user_id_str': '457984599'}]},
#    'extended_entities': {'media': [{'id': 1322903534875136000,
#       'id_str': '1322903534875136000',
#       'indices': [47, 70],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1322903534875136000/pu/img/87iuZ90wCz3QCKm-.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1322903534875136000/pu/img/87iuZ90wCz3QCKm-.jpg',
#       'url': 'https://t.co/S0U6Nvu4A7',
#       'display_url': 'pic.twitter.com/S0U6Nvu4A7',
#       'expanded_url': 'https://twitter.com/BreitbartNews/status/1322903928711843842/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 720, 'h': 720, 'resize': 'fit'},
#        'large': {'w': 720, 'h': 720, 'resize': 'fit'}},
#       'source_status_id': 1322903928711843842,
#       'source_status_id_str': '1322903928711843842',
#       'source_user_id': 457984599,
#       'source_user_id_str': '457984599',
#       'video_info': {'aspect_ratio': [1, 1],
#        'duration_millis': 122990,
#        'variants': [{'bitrate': 432000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1322903534875136000/pu/vid/320x320/LgcrzedYl0Hpy_kV.mp4?tag=10'},
#         {'bitrate': 1280000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1322903534875136000/pu/vid/720x720/yz_LPB2pXPwlqivZ.mp4?tag=10'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1322903534875136000/pu/vid/480x480/xOHiswWBYn61qfuL.mp4?tag=10'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1322903534875136000/pu/pl/dGecVQiy4MbxZdtq.m3u8?tag=10'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 797516322288476160,
#     'id_str': '797516322288476160',
#     'name': 'Kan',
#     'screen_name': 'kstaypositive_',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3,
#     'friends_count': 41,
#     'listed_count': 0,
#     'created_at': 'Sat Nov 12 19:08:03 +0000 2016',
#     'favourites_count': 498,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2355,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Nov 05 21:11:14 +0000 2020',
#     'id': 1324459280003665920,
#     'id_str': '1324459280003665920',
#     'text': 'The #MeToo President #CreepyJoe https://t.co/S0U6Nvu4A7',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'MeToo', 'indices': [4, 10]},
#       {'text': 'CreepyJoe', 'indices': [21, 31]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1322903534875136000,
#        'id_str': '1322903534875136000',
#        'indices': [32, 55],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1322903534875136000/pu/img/87iuZ90wCz3QCKm-.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1322903534875136000/pu/img/87iuZ90wCz3QCKm-.jpg',
#        'url': 'https://t.co/S0U6Nvu4A7',
#        'display_url': 'pic.twitter.com/S0U6Nvu4A7',
#        'expanded_url': 'https://twitter.com/BreitbartNews/status/1322903928711843842/video/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 720, 'h': 720, 'resize': 'fit'},
#         'large': {'w': 720, 'h': 720, 'resize': 'fit'}},
#        'source_status_id': 1322903928711843842,
#        'source_status_id_str': '1322903928711843842',
#        'source_user_id': 457984599,
#        'source_user_id_str': '457984599'}]},
#     'extended_entities': {'media': [{'id': 1322903534875136000,
#        'id_str': '1322903534875136000',
#        'indices': [32, 55],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1322903534875136000/pu/img/87iuZ90wCz3QCKm-.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1322903534875136000/pu/img/87iuZ90wCz3QCKm-.jpg',
#        'url': 'https://t.co/S0U6Nvu4A7',
#        'display_url': 'pic.twitter.com/S0U6Nvu4A7',
#        'expanded_url': 'https://twitter.com/BreitbartNews/status/1322903928711843842/video/1',
#        'type': 'video',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 720, 'h': 720, 'resize': 'fit'},
#         'large': {'w': 720, 'h': 720, 'resize': 'fit'}},
#        'source_status_id': 1322903928711843842,
#        'source_status_id_str': '1322903928711843842',
#        'source_user_id': 457984599,
#        'source_user_id_str': '457984599',
#        'video_info': {'aspect_ratio': [1, 1],
#         'duration_millis': 122990,
#         'variants': [{'bitrate': 432000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1322903534875136000/pu/vid/320x320/LgcrzedYl0Hpy_kV.mp4?tag=10'},
#          {'bitrate': 1280000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1322903534875136000/pu/vid/720x720/yz_LPB2pXPwlqivZ.mp4?tag=10'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1322903534875136000/pu/vid/480x480/xOHiswWBYn61qfuL.mp4?tag=10'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/1322903534875136000/pu/pl/dGecVQiy4MbxZdtq.m3u8?tag=10'}]},
#        'additional_media_info': {'monetizable': False}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1019131050,
#      'id_str': '1019131050',
#      'name': 'Say No to Statism 🏴',
#      'screen_name': 'NoStatism',
#      'location': '',
#      'description': '#Freedom is cool & #Statists suck. #selfownership #voluntaryism #anarchism #agorism #libertarianism #libertarian #liberty #BTFSTTG',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 20408,
#      'friends_count': 17104,
#      'listed_count': 152,
#      'created_at': 'Tue Dec 18 06:24:28 +0000 2012',
#      'favourites_count': 38994,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 2858,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '656565',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1267883948245483520/aRJl_3Nf_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1267883948245483520/aRJl_3Nf_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1019131050/1591123371',
#      'profile_link_color': 'FCC200',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 38,
#     'favorite_count': 97,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 38,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': True,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 07 02:26:34 +0000 2020',
#    'id': 1324901025329926145,
#    'id_str': '1324901025329926145',
#    'text': 'Trump started the #MeToo movement and Biden killed it.',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [18, 24]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1176229132017045506,
#     'id_str': '1176229132017045506',
#     'name': 'Gaia Eternal 🕉 🕊',
#     'screen_name': 'Gaia_Eternal',
#     'location': '',
#     'description': "I'm a novelist, religious scholar and political activist. we/us. My first book, Fate’s Peak, is available at https://t.co/D4w6xrezr9",
#     'url': 'https://t.co/wHKCdQdkCJ',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/wHKCdQdkCJ',
#         'expanded_url': 'http://www.fatespeak.com',
#         'display_url': 'fatespeak.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/D4w6xrezr9',
#         'expanded_url': 'https://tinyurl.com/ue6xaao',
#         'display_url': 'tinyurl.com/ue6xaao',
#         'indices': [109, 132]}]}},
#     'protected': False,
#     'followers_count': 662,
#     'friends_count': 979,
#     'listed_count': 10,
#     'created_at': 'Mon Sep 23 20:17:59 +0000 2019',
#     'favourites_count': 8130,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 40788,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1240751552559828992/n-bGGJmH_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1240751552559828992/n-bGGJmH_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1176229132017045506/1587166476',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 07 02:26:28 +0000 2020',
#    'id': 1324900998532509697,
#    'id_str': '1324900998532509697',
#    'text': 'RT @CaryRyan14: Police culture is rape culture. #MeToo #timesup',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [48, 54]},
#      {'text': 'timesup', 'indices': [55, 63]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'CaryRyan14',
#       'name': 'Cary Ryan 🏳️\u200d🌈🇨🇦',
#       'id': 1032787831528349696,
#       'id_str': '1032787831528349696',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 732920945946595328,
#     'id_str': '732920945946595328',
#     'name': 'TheGoodLawyer',
#     'screen_name': 'NotURSycophant',
#     'location': '',
#     'description': 'Protesting “ISMS”! Watch Global News: Black Crown lawyer launches lawsuit against government, unions about systemi... https://t.co/yBk4GZ0Fu7 via @YouTube',
#     'url': None,
#     'entities': {'description': {'urls': [{'url': 'https://t.co/yBk4GZ0Fu7',
#         'expanded_url': 'http://youtu.be/qtyIfCtdHLQ',
#         'display_url': 'youtu.be/qtyIfCtdHLQ',
#         'indices': [118, 141]}]}},
#     'protected': False,
#     'followers_count': 610,
#     'friends_count': 1561,
#     'listed_count': 3,
#     'created_at': 'Wed May 18 13:09:05 +0000 2016',
#     'favourites_count': 12484,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 10428,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1308433919008747520/0GbHvIrX_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308433919008747520/0GbHvIrX_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/732920945946595328/1600788413',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Nov 07 00:10:17 +0000 2020',
#     'id': 1324866729206558720,
#     'id_str': '1324866729206558720',
#     'text': 'Police culture is rape culture. #MeToo #timesup https://t.co/oii9pu68tL',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'MeToo', 'indices': [32, 38]},
#       {'text': 'timesup', 'indices': [39, 47]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/oii9pu68tL',
#        'expanded_url': 'https://twitter.com/shesrideordie/status/1324853837090480128',
#        'display_url': 'twitter.com/shesrideordie/…',
#        'indices': [48, 71]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1032787831528349696,
#      'id_str': '1032787831528349696',
#      'name': 'Cary Ryan 🏳️\u200d🌈🇨🇦',
#      'screen_name': 'CaryRyan14',
#      'location': 'Halifax, Nova Scotia',
#      'description': 'Mother, Survivor, Changemaker, Social Worker, Researcher, Former police officer, PTSD 🏳️\u200d🌈',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 655,
#      'friends_count': 2468,
#      'listed_count': 1,
#      'created_at': 'Fri Aug 24 00:33:02 +0000 2018',
#      'favourites_count': 3878,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 3326,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1311600433983631365/RfHs7Edq_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1311600433983631365/RfHs7Edq_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1032787831528349696/1603375956',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1324853837090480128,
#     'quoted_status_id_str': '1324853837090480128',
#     'quoted_status': {'created_at': 'Fri Nov 06 23:19:04 +0000 2020',
#      'id': 1324853837090480128,
#      'id_str': '1324853837090480128',
#      'text': '"It\'s  outrageous," he said, and a "slap in the face"...\nWhen she accused Porter of sexually inappropriate behaviou… https://t.co/tCQGfkxin1',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/tCQGfkxin1',
#         'expanded_url': 'https://twitter.com/i/web/status/1324853837090480128',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 867473093844926464,
#       'id_str': '867473093844926464',
#       'name': 'Angie Rivers',
#       'screen_name': 'shesrideordie',
#       'location': 'Ontario, Canada',
#       'description': 'Shunned Waterloo police officer fighting for equality. Unapologetic Feminist, BIPOC & LGBTQ2S ally. tweets r mine not WRPS. Nice in person. #tarnishedbadge',
#       'url': 'https://t.co/oXjh0kazU2',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/oXjh0kazU2',
#           'expanded_url': 'https://www.nwlea.com/',
#           'display_url': 'nwlea.com',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 1569,
#       'friends_count': 641,
#       'listed_count': 4,
#       'created_at': 'Wed May 24 20:11:17 +0000 2017',
#       'favourites_count': 23723,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 9003,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F5F8FA',
#       'profile_background_image_url': None,
#       'profile_background_image_url_https': None,
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/932670393021751305/eGZvJFjz_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/932670393021751305/eGZvJFjz_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/867473093844926464/1599494907',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': False,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 10,
#      'favorite_count': 27,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 3,
#     'favorite_count': 8,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1324853837090480128,
#    'quoted_status_id_str': '1324853837090480128',
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 07 02:20:13 +0000 2020',
#    'id': 1324899428038176768,
#    'id_str': '1324899428038176768',
#    'text': 'RT @NoRestrictions: NOW AVAILABLE on Vimeo: https://t.co/PoHTzR5RF1 "Our goal is to raise the profile of child trafficking with a message o…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'NoRestrictions',
#       'name': 'No Restrictions Studios',
#       'id': 15524948,
#       'id_str': '15524948',
#       'indices': [3, 18]}],
#     'urls': [{'url': 'https://t.co/PoHTzR5RF1',
#       'expanded_url': 'https://bit.ly/2NaYI36',
#       'display_url': 'bit.ly/2NaYI36',
#       'indices': [44, 67]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 15897499,
#     'id_str': '15897499',
#     'name': 'Candacee',
#     'screen_name': 'Candacee',
#     'location': 'Spanish Springs, NV',
#     'description': 'Independent Stylist',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1405,
#     'friends_count': 3084,
#     'listed_count': 106,
#     'created_at': 'Mon Aug 18 22:49:40 +0000 2008',
#     'favourites_count': 10470,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 44584,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme6/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme6/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3358684131/48f0572d43e04cc56074007d480c06a2_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3358684131/48f0572d43e04cc56074007d480c06a2_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15897499/1512846232',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Jul 08 23:31:56 +0000 2018',
#     'id': 1016102617045323776,
#     'id_str': '1016102617045323776',
#     'text': 'NOW AVAILABLE on Vimeo: https://t.co/PoHTzR5RF1 "Our goal is to raise the profile of child trafficking with a messa… https://t.co/0vvSpguG6B',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/PoHTzR5RF1',
#        'expanded_url': 'https://bit.ly/2NaYI36',
#        'display_url': 'bit.ly/2NaYI36',
#        'indices': [24, 47]},
#       {'url': 'https://t.co/0vvSpguG6B',
#        'expanded_url': 'https://twitter.com/i/web/status/1016102617045323776',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://ads.twitter.com" rel="nofollow">Twitter Ads</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 15524948,
#      'id_str': '15524948',
#      'name': 'No Restrictions Studios',
#      'screen_name': 'NoRestrictions',
#      'location': 'Los Angeles, CA',
#      'description': 'We create authentic, bold films 🎥 with real-life stories of survival in the face of uncertainty. #EndHumanTrafficking',
#      'url': 'https://t.co/h00zQ7YNSe',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/h00zQ7YNSe',
#          'expanded_url': 'https://linktr.ee/norestrictions',
#          'display_url': 'linktr.ee/norestrictions',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 12047,
#      'friends_count': 383,
#      'listed_count': 359,
#      'created_at': 'Tue Jul 22 02:30:55 +0000 2008',
#      'favourites_count': 16972,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 37677,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/524620379000557568/FPlESmsv_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/524620379000557568/FPlESmsv_normal.jpeg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15524948/1575001832',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 117,
#     'favorite_count': 111,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'scopes': {'followers': False},
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 117,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 07 02:20:04 +0000 2020',
#    'id': 1324899390012743681,
#    'id_str': '1324899390012743681',
#    'text': '#MeToo \n\nDid I use that right?  I heard the liberals abandoned that movement.... https://t.co/8XunopsLEh',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [0, 6]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/8XunopsLEh',
#       'expanded_url': 'https://twitter.com/RealJamesWoods/status/1324897029630222337',
#       'display_url': 'twitter.com/RealJamesWoods…',
#       'indices': [81, 104]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1316522456258146305,
#     'id_str': '1316522456258146305',
#     'name': '🇺🇸ParatrooperX🇺🇸',
#     'screen_name': 'ParatrooperX',
#     'location': 'Texas',
#     'description': 'Conservative, Army Veteran, Paratrooper, III Percenter, Grappler, BJJ Practitioner, Fighter, Father, Coach #1A #2A #ΜΟΛΩΝΛΑΒΕ #MAGA #KAG #BanSharia #BanIslam',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1478,
#     'friends_count': 1740,
#     'listed_count': 0,
#     'created_at': 'Wed Oct 14 23:33:15 +0000 2020',
#     'favourites_count': 1341,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2390,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1316552322735108096/BHbwHghu_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1316552322735108096/BHbwHghu_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1316522456258146305/1602719579',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1324897029630222337,
#    'quoted_status_id_str': '1324897029630222337',
#    'quoted_status': {'created_at': 'Sat Nov 07 02:10:41 +0000 2020',
#     'id': 1324897029630222337,
#     'id_str': '1324897029630222337',
#     'text': 'Are you literally making lists? I understand you’re an ignorant nitwit  who’s never had a passing acquaintance with… https://t.co/1PdsveOaYB',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/1PdsveOaYB',
#        'expanded_url': 'https://twitter.com/i/web/status/1324897029630222337',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 78523300,
#      'id_str': '78523300',
#      'name': 'James Woods',
#      'screen_name': 'RealJamesWoods',
#      'location': '',
#      'description': 'This is the ONLY verified Twitter account for James Woods. ALL others are fake. I am on NO other social media (except a private Instagram). They’re ALL fake.',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2726490,
#      'friends_count': 5227,
#      'listed_count': 9664,
#      'created_at': 'Wed Sep 30 05:31:28 +0000 2009',
#      'favourites_count': 13941,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 35660,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/796482667340382211/CoV8077b_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/796482667340382211/CoV8077b_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/78523300/1603295247',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1324807776510595078,
#     'quoted_status_id_str': '1324807776510595078',
#     'retweet_count': 6566,
#     'favorite_count': 22015,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 07 02:19:24 +0000 2020',
#    'id': 1324899220441206784,
#    'id_str': '1324899220441206784',
#    'text': '• "How can a book about something so bad be so damn good? Read Kellcey, and find out for yourself". #metoo… https://t.co/2ernz30Xqf',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'metoo', 'indices': [100, 106]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/2ernz30Xqf',
#       'expanded_url': 'https://twitter.com/i/web/status/1324899220441206784',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [108, 131]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://askdavid.com" rel="nofollow">AskDavid.com Services</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 250309546,
#     'id_str': '250309546',
#     'name': 'Book Promotion #ad',
#     'screen_name': 'book_tribe',
#     'location': 'Here, There and Everywhere',
#     'description': 'Authors, Writers - Get Promotion For Your Books. Readers find great new books to read.\r\nhttp://t.co/ZGs4k2mupm',
#     'url': 'http://t.co/Keael1i1mV',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/Keael1i1mV',
#         'expanded_url': 'http://askDavid.com',
#         'display_url': 'askDavid.com',
#         'indices': [0, 22]}]},
#      'description': {'urls': [{'url': 'http://t.co/ZGs4k2mupm',
#         'expanded_url': 'http://askdavid.com/book-promotion',
#         'display_url': 'askdavid.com/book-promotion',
#         'indices': [88, 110]}]}},
#     'protected': False,
#     'followers_count': 57059,
#     'friends_count': 38768,
#     'listed_count': 1643,
#     'created_at': 'Thu Feb 10 21:01:39 +0000 2011',
#     'favourites_count': 305,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 392275,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/605116406724706304/3zmRL_LG_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/605116406724706304/3zmRL_LG_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/250309546/1402513767',
#     'profile_link_color': '009999',
# ...
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 20412802,
#     'id_str': '20412802',
#     'name': 'Carolyn Maher',
#     'screen_name': 'carolynannmaher',
#     'location': 'Nashville, TN',
#     'description': 'passionate about the experience of life, especially those as a customer/consumer  - digitization is changing everything - all views are mine',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 97,
#     'friends_count': 531,
#     'listed_count': 3,
#     'created_at': 'Mon Feb 09 03:26:58 +0000 2009',
#     'favourites_count': 4332,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 632,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/664845550156693504/LJS1EOD1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/664845550156693504/LJS1EOD1_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Nov 07 01:36:13 +0000 2020',
#    'id': 1324888355256102913,
#    'id_str': '1324888355256102913',
#    'text': 'RT @ifetoola: Sharing a rape experience of mine #MeToo https://t.co/WGYUvNgIwK',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [48, 54]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ifetoola',
#       'name': 'Ife',
#       'id': 1014274775399780353,
#       'id_str': '1014274775399780353',
#       'indices': [3, 12]}],
#     'urls': [],
#     'media': [{'id': 1324626409638236160,
#       'id_str': '1324626409638236160',
#       'indices': [55, 78],
#       'media_url': 'http://pbs.twimg.com/media/EmIEs46WkAAYiVS.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EmIEs46WkAAYiVS.jpg',
#       'url': 'https://t.co/WGYUvNgIwK',
#       'display_url': 'pic.twitter.com/WGYUvNgIwK',
#       'expanded_url': 'https://twitter.com/ifetoola/status/1324626421151653888/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 1152, 'h': 2048, 'resize': 'fit'}},
#       'source_status_id': 1324626421151653888,
#       'source_status_id_str': '1324626421151653888',
#       'source_user_id': 1014274775399780353,
#       'source_user_id_str': '1014274775399780353'}]},
#    'extended_entities': {'media': [{'id': 1324626409638236160,
#       'id_str': '1324626409638236160',
#       'indices': [55, 78],
#       'media_url': 'http://pbs.twimg.com/media/EmIEs46WkAAYiVS.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EmIEs46WkAAYiVS.jpg',
#       'url': 'https://t.co/WGYUvNgIwK',
#       'display_url': 'pic.twitter.com/WGYUvNgIwK',
#       'expanded_url': 'https://twitter.com/ifetoola/status/1324626421151653888/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 1152, 'h': 2048, 'resize': 'fit'}},
#       'source_status_id': 1324626421151653888,
#       'source_status_id_str': '1324626421151653888',
#       'source_user_id': 1014274775399780353,
#       'source_user_id_str': '1014274775399780353'},
#      {'id': 1324626410099662848,
#       'id_str': '1324626410099662848',
#       'indices': [55, 78],
#       'media_url': 'http://pbs.twimg.com/media/EmIEs6oXYAA47mY.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EmIEs6oXYAA47mY.jpg',
#       'url': 'https://t.co/WGYUvNgIwK',
#       'display_url': 'pic.twitter.com/WGYUvNgIwK',
#       'expanded_url': 'https://twitter.com/ifetoola/status/1324626421151653888/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 1152, 'h': 2048, 'resize': 'fit'},
#        'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}},
#       'source_status_id': 1324626421151653888,
#       'source_status_id_str': '1324626421151653888',
#       'source_user_id': 1014274775399780353,
#       'source_user_id_str': '1014274775399780353'},
#      {'id': 1324626409629880320,
#       'id_str': '1324626409629880320',
#       'indices': [55, 78],
#       'media_url': 'http://pbs.twimg.com/media/EmIEs44XEAAan8v.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EmIEs44XEAAan8v.jpg',
#       'url': 'https://t.co/WGYUvNgIwK',
#       'display_url': 'pic.twitter.com/WGYUvNgIwK',
#       'expanded_url': 'https://twitter.com/ifetoola/status/1324626421151653888/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 1152, 'h': 2048, 'resize': 'fit'}},
#       'source_status_id': 1324626421151653888,
#       'source_status_id_str': '1324626421151653888',
#       'source_user_id': 1014274775399780353,
#       'source_user_id_str': '1014274775399780353'},
#      {'id': 1324626409638211586,
#       'id_str': '1324626409638211586',
#       'indices': [55, 78],
#       'media_url': 'http://pbs.twimg.com/media/EmIEs46WMAIKYvj.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EmIEs46WMAIKYvj.jpg',
#       'url': 'https://t.co/WGYUvNgIwK',
#       'display_url': 'pic.twitter.com/WGYUvNgIwK',
#       'expanded_url': 'https://twitter.com/ifetoola/status/1324626421151653888/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#        'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 1152, 'h': 2048, 'resize': 'fit'}},
#       'source_status_id': 1324626421151653888,
#       'source_status_id_str': '1324626421151653888',
#       'source_user_id': 1014274775399780353,
#       'source_user_id_str': '1014274775399780353'}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 927510193059004417,
#     'id_str': '927510193059004417',
#     'name': 'VA',
#     'screen_name': '1nxssa',
#     'location': 'ends 🇬🇧',
#     'description': '21',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 408,
#     'friends_count': 286,
#     'listed_count': 0,
#     'created_at': 'Mon Nov 06 12:17:17 +0000 2017',
#     'favourites_count': 45392,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 11653,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1288675426106318849/vuFgf59b_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1288675426106318849/vuFgf59b_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/927510193059004417/1602593656',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Nov 06 08:15:23 +0000 2020',
#     'id': 1324626421151653888,
#     'id_str': '1324626421151653888',
#     'text': 'Sharing a rape experience of mine #MeToo https://t.co/WGYUvNgIwK',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'MeToo', 'indices': [34, 40]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1324626409638236160,
#        'id_str': '1324626409638236160',
#        'indices': [41, 64],
#        'media_url': 'http://pbs.twimg.com/media/EmIEs46WkAAYiVS.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EmIEs46WkAAYiVS.jpg',
#        'url': 'https://t.co/WGYUvNgIwK',
#        'display_url': 'pic.twitter.com/WGYUvNgIwK',
#        'expanded_url': 'https://twitter.com/ifetoola/status/1324626421151653888/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#         'large': {'w': 1152, 'h': 2048, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1324626409638236160,
#        'id_str': '1324626409638236160',
#        'indices': [41, 64],
#        'media_url': 'http://pbs.twimg.com/media/EmIEs46WkAAYiVS.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EmIEs46WkAAYiVS.jpg',
#        'url': 'https://t.co/WGYUvNgIwK',
#        'display_url': 'pic.twitter.com/WGYUvNgIwK',
#        'expanded_url': 'https://twitter.com/ifetoola/status/1324626421151653888/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#         'large': {'w': 1152, 'h': 2048, 'resize': 'fit'}}},
#       {'id': 1324626410099662848,
#        'id_str': '1324626410099662848',
#        'indices': [41, 64],
#        'media_url': 'http://pbs.twimg.com/media/EmIEs6oXYAA47mY.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EmIEs6oXYAA47mY.jpg',
#        'url': 'https://t.co/WGYUvNgIwK',
#        'display_url': 'pic.twitter.com/WGYUvNgIwK',
#        'expanded_url': 'https://twitter.com/ifetoola/status/1324626421151653888/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#         'large': {'w': 1152, 'h': 2048, 'resize': 'fit'},
#         'medium': {'w': 675, 'h': 1200, 'resize': 'fit'}}},
#       {'id': 1324626409629880320,
#        'id_str': '1324626409629880320',
#        'indices': [41, 64],
#        'media_url': 'http://pbs.twimg.com/media/EmIEs44XEAAan8v.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EmIEs44XEAAan8v.jpg',
#        'url': 'https://t.co/WGYUvNgIwK',
#        'display_url': 'pic.twitter.com/WGYUvNgIwK',
#        'expanded_url': 'https://twitter.com/ifetoola/status/1324626421151653888/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 1152, 'h': 2048, 'resize': 'fit'}}},
#       {'id': 1324626409638211586,
#        'id_str': '1324626409638211586',
#        'indices': [41, 64],
#        'media_url': 'http://pbs.twimg.com/media/EmIEs46WMAIKYvj.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EmIEs46WMAIKYvj.jpg',
#        'url': 'https://t.co/WGYUvNgIwK',
#        'display_url': 'pic.twitter.com/WGYUvNgIwK',
#        'expanded_url': 'https://twitter.com/ifetoola/status/1324626421151653888/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#         'small': {'w': 383, 'h': 680, 'resize': 'fit'},
#         'large': {'w': 1152, 'h': 2048, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1014274775399780353,
#      'id_str': '1014274775399780353',
#      'name': 'Ife',
#      'screen_name': 'ifetoola',
#      'location': 'London, England',
#      'description': '',
#      'url': 'https://t.co/UUVl73B1Mk',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/UUVl73B1Mk',
#          'expanded_url': 'https://www.instagram.com/ife.eo',
#          'display_url': 'instagram.com/ife.eo',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 116,
#      'friends_count': 106,
#      'listed_count': 0,
#      'created_at': 'Tue Jul 03 22:28:45 +0000 2018',
#      'favourites_count': 2578,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 272,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1324627015698386944/fWcBluQ6_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1324627015698386944/fWcBluQ6_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 171,
#     'favorite_count': 161,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 171,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.198,
#   'max_id': 1324901681994199041,
#   'max_id_str': '1324901681994199041',
#   'next_results': '?max_id=1324888355256102912&q=%23metoo&lang=en&count=50&include_entities=1',
#   'query': '%23metoo',
#   'refresh_url': '?since_id=1324901681994199041&q=%23metoo&lang=en&include_entities=1',
#   'count': 50,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# ## Section 3: Searching Users

# %% [markdown]
# The last section of the API you'll need to get the hang of before you're let loose is the users API, which allows you to search for users and get their followers, friends, etc, as opposed to tweets which fit a particular criteria.  This part is pretty similar to the advanced lab in class 3, so if you saw how that worked then you shouldn't need much instruction.
#
# But if you're seeing this with fresh eyes, you'll want to spend 15-20 minutes to make sure you understand this part.
#
# Official documentation can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/overview
#
# So, as an example, if you want to get a list of someone's followers, you use the base url `https://api.twitter.com/1.1/followers/list.json` and then enter your query string to get a list of that person's followers.
#
# List of parameters to use can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference/get-followers-list
#
# One possible parameter to use is `screen_name`, so if you wanted to get a list of someone's followers based on their screen name (the handle that begins with an @), then you would set up your API call to look something like:
#
# `https://api.twitter.com/1.1/followers/list.json?screen_name=persons_screenname`
#
# Note that you exclude the `@`.
#
# **Your turn:** Pull in the list of General Assembly's followers.  General Assembly's handle is `@GA`.
#
# Note that this won't return the whole list of GA's users.  If you want to do that you have to use cursoring:  https://developer.twitter.com/en/docs/basics/cursoring.  This is the topic of your bonus assignment.

# %%
# your answer here
"""api_url ='https://api.twitter.com/1.1/followers/list.json?screen_name=ga'
ga_followers = requests.get(api_url, auth=auth)
ga_followers.json()"""

import pandas as pd
api_url ='https://api.twitter.com/1.1/users/lookup.json?screen_name=ga'
ga_followers = requests.get(api_url, auth=auth)
ga_followers.json()
#df = pd.DataFrame(ga_followers.json())
#keys = df.columns
#keys
# Out:
# [{'id': 170393291,
#   'id_str': '170393291',
#   'name': 'General Assembly',
#   'screen_name': 'GA',
#   'location': '',
#   'description': 'We transform careers and teams — including more than one third of the Fortune 100 — through dynamic courses in coding, data, design, and business.',
#   'url': 'https://t.co/YQeEXPxJ4H',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/YQeEXPxJ4H',
#       'expanded_url': 'http://ga.co/Twitter',
#       'display_url': 'ga.co/Twitter',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 164654,
#   'friends_count': 5393,
#   'listed_count': 3248,
#   'created_at': 'Sat Jul 24 18:19:59 +0000 2010',
#   'favourites_count': 35115,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 22807,
#   'lang': None,
#   'status': {'created_at': 'Fri Nov 06 23:26:00 +0000 2020',
#    'id': 1324855585737744387,
#    'id_str': '1324855585737744387',
#    'text': 'Take the road less travelled. 🚗 Map out a scenic, social distance friendly trip in your home state with this data-d… https://t.co/rNepIv9CBH',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/rNepIv9CBH',
#       'expanded_url': 'https://twitter.com/i/web/status/1324855585737744387',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FFFFFF',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1318271172216324097/O7Xaryg2_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318271172216324097/O7Xaryg2_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170393291/1480618900',
#   'profile_link_color': 'DE2233',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'FFFFFF',
#   'profile_text_color': '000000',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'}]

# %% [markdown]
# ## Section 4: Functions

# %% [markdown]
# This section details the functions you have to write and turn in as part of your homework assignment.
#
# Please read the requirements carefully.
#
# **What you'll turn in:** A `.py` file with all of the functions written.  We should be able to load this into an IDE, run the file, and then call your functions to verify how and if they work. This file should also be properly commented so we can follow your line of reasoning.
#
# The functions you'll be prompted to write will be defined in the following ways:
#
#  - **name:** the name of the function
#  - **returns:** what the function should return
#  - **arguments:** arguments to include inside the function in order to specify how it should behave.
#
#  **Note:** The free API has limitations built into it, so this means from time-to-time you'll only be able to return some of the results from the API.  This is fine.  It's understood and recognized that your functions won't be able to return an entire list of someone's users or other such things, so as long as your work delivers the best it can under present circumstances you'll be in good shape.
#
#  **Other Note:** Every aspect of the API that you need to use can be found on either of these pages.
#
#  Search API:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets
#
#  Users API: https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference
#
# **Remarks About Your Final Work**
#
#  - It's okay if you get stuck somewhere.  If there's one item that you can't figure out and it doesn't quite work right, it's probably best to move on and try other things.  Again, try and explain what you were looking to do.  You'll pass if you give an honest effort.
#  - There's potentially a lot of error handling you could do to verify user input is correct, but you can leave that alone for now.  Just make sure the core purpose of the function works the way it's supposed to.
#  - While you're working on this, it's possible you may bump into your API limits.  Keep this in mind if you have a function that's working, but 45 minutes later it doesn't and you haven't changed anything.  This usually means the data you're getting back from your API calls isn't what it's supposed to be because you've exhausted your limits. We won't hold you to double checking for all of this in your functions.
#  - In the file you turn in, make sure your requests are referencing your API tokens, so that way we can run your file right away.  Ie, make sure somewhere in your script you have a variable at the top that reads `tokens = OAuth1('token1', 'token2', 'token3', 'token4')` so it can be used for your requests inside the file.

# %%
"""
step 1 - include default arguments to accept tokens
tokens = OAuth1('token1','token2','token3','token4')
function details:
    name
    returns
    arguments
"""#function details 
print(f"No user exists with the handle {name}"{name})
# Out:
#   File "<ipython-input-12-8f08c2ba35fe>", line 9
#     print(f"No user exists with the handle {name}"{name})
#                                                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##### Function 1 (Required)

# %% [markdown]
# **Name:** `find_user`
#
# **Returns:** dictionary that represents user object returned by Twitter's API
#
# **Arguments:**
#  - `screen_name`: str, required; Twitter handle to search for.  **Can include the @ symbol.  The function should check for this and remove it if necessary.**
#  - `keys`: list, optional; list that contains keys to return about user object.  If not specified, then function should return the entire user object.  **These only need to be outer keys.** If they are keys nested within another key, you don't have to account for this.
#
# **To test:** We'll test your function in the following ways:
#
#  - `find_user('@GA')`
#  - `find_user('GA')`
#  - `find_user('GA', keys=['name', 'screen_name', 'followers_count', 'friends_count'])`

# %%
auth = OAuth1('r8ZOzLMZoouq5u8iCdmNKiSMx', 'tIqgdrMHBrkMRXfBlY36cUpxDw34LygVL9hBg5A4Dl0yIQLOAb','1216043853284827136-XgLCLf15GtZZ0oIsgInUIjJT1lnPmT', 'ksKmplYg3WBqwThvTbhknJmhBYE7t43Bt0ZijmExr2Nq2')
def find_user(name,keys = ['id', 'id_str', 'name', 'screen_name', 'location', 'description', 'url',
       'entities', 'protected', 'followers_count', 'friends_count',
       'listed_count', 'created_at', 'favourites_count', 'utc_offset',
       'time_zone', 'geo_enabled', 'verified', 'statuses_count', 'lang',
       'status', 'contributors_enabled', 'is_translator',
       'is_translation_enabled', 'profile_background_color',
       'profile_background_image_url', 'profile_background_image_url_https',
       'profile_background_tile', 'profile_image_url',
       'profile_image_url_https', 'profile_banner_url', 'profile_link_color',
       'profile_sidebar_border_color', 'profile_sidebar_fill_color',
       'profile_text_color', 'profile_use_background_image',
       'has_extended_profile', 'default_profile', 'default_profile_image',
       'following', 'follow_request_sent', 'notifications', 'translator_type']):
    """
    This function finds if a user object exists for the twitter handle returned
    as a required input it accepts the user_name - a user's twitter handle
    as optional inputs it accepts user parameters by which to filter the output. These parameters are entered as a list of strings
    as output it returns a dictionary that represents the users's twitter information
    """
    
    #This line checks to see if the string begins with an @ and removes it
    name = name.strip("@").lower()
    
    #this returns the user details if the user exists or returns an empty dictionary if the user does not exist
    try:
        api_url ='https://api.twitter.com/1.1/users/lookup.json?screen_name={}'.format(name)
        user_details = requests.get(api_url, auth=auth)
        output = { key: user_details.json()[0][key] for key in keys }
        return output
    except:
        print("No user exists with the handle {}".format(name))
        return {}
        
example1 = find_user('@GA')
example2 = find_user('GA')
example3 = find_user('GA', keys=['name', 'screen_name', 'followers_count', 'friends_count'])

# %%
print(example1)
# Out:
# {'id': 170393291, 'id_str': '170393291', 'name': 'General Assembly', 'screen_name': 'GA', 'location': '', 'description': 'We transform careers and teams — including more than one third of the Fortune 100 — through dynamic courses in coding, data, design, and business.', 'url': 'https://t.co/YQeEXPxJ4H', 'entities': {'url': {'urls': [{'url': 'https://t.co/YQeEXPxJ4H', 'expanded_url': 'http://ga.co/Twitter', 'display_url': 'ga.co/Twitter', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 164653, 'friends_count': 5393, 'listed_count': 3248, 'created_at': 'Sat Jul 24 18:19:59 +0000 2010', 'favourites_count': 35115, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 22807, 'lang': None, 'status': {'created_at': 'Fri Nov 06 23:26:00 +0000 2020', 'id': 1324855585737744387, 'id_str': '1324855585737744387', 'text': 'Take the road less travelled. 🚗 Map out a scenic, social distance friendly trip in your home state with this data-d… https://t.co/rNepIv9CBH', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/rNepIv9CBH', 'expanded_url': 'https://twitter.com/i/web/status/1324855585737744387', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 2, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1318271172216324097/O7Xaryg2_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318271172216324097/O7Xaryg2_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170393291/1480618900', 'profile_link_color': 'DE2233', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'FFFFFF', 'profile_text_color': '000000', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}

# %%
print(example2)
# Out:
# {'id': 170393291, 'id_str': '170393291', 'name': 'General Assembly', 'screen_name': 'GA', 'location': '', 'description': 'We transform careers and teams — including more than one third of the Fortune 100 — through dynamic courses in coding, data, design, and business.', 'url': 'https://t.co/YQeEXPxJ4H', 'entities': {'url': {'urls': [{'url': 'https://t.co/YQeEXPxJ4H', 'expanded_url': 'http://ga.co/Twitter', 'display_url': 'ga.co/Twitter', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 164653, 'friends_count': 5393, 'listed_count': 3248, 'created_at': 'Sat Jul 24 18:19:59 +0000 2010', 'favourites_count': 35115, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 22807, 'lang': None, 'status': {'created_at': 'Fri Nov 06 23:26:00 +0000 2020', 'id': 1324855585737744387, 'id_str': '1324855585737744387', 'text': 'Take the road less travelled. 🚗 Map out a scenic, social distance friendly trip in your home state with this data-d… https://t.co/rNepIv9CBH', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/rNepIv9CBH', 'expanded_url': 'https://twitter.com/i/web/status/1324855585737744387', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 2, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1318271172216324097/O7Xaryg2_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318271172216324097/O7Xaryg2_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170393291/1480618900', 'profile_link_color': 'DE2233', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'FFFFFF', 'profile_text_color': '000000', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}

# %%
print(example3)
# Out:
# {'name': 'General Assembly', 'screen_name': 'GA', 'followers_count': 164653, 'friends_count': 5393}

# %% [markdown]
# ##### Function 2 (Required)

# %% [markdown]
# **Name:** `find_hashtag`
#
# **Returns:** list of data objects that contain information about each tweet that matches the hashtag provided as input.
#
# **Arguments:**
#  - `hashtag`: str, required; text to use as a hashtag search.
#  - `count`: int, optional; number of results to return
#  - `search_type`: str, optional; type of results to return.  should accept 3 different values:
#    - `mixed`:   return mix of most recent and most popular results
#    - `recent`:  return most recent results
#    - `popular`: return most popular results
#
# **Note:** User should **not** have to actually use the `#` character for the `hashtag` argument.  The function should check to see if it's there, and if not, add it in for them.
#
# **To Test:**  We'll check your function in the following ways:
#  - `find_hashtag('DataScience')`
#  - `find_hashtag('#DataScience')`
#  - `find_hashtag('#DataScience', count=100)`, and double check the length of the `statuses` key to make sure it contains the right amount of results.  **Note:** Due to the version of the API we're using, the number of results returned will **not** necessarily match the value passed into the `count` parameter.  So if you specify 50 and it only returns 45, you are likely still doing it correctly.
#  - `find_hashtag('#DataScience', search_type='recent/mixed/popular')`

# %%
auth = OAuth1('r8ZOzLMZoouq5u8iCdmNKiSMx', 'tIqgdrMHBrkMRXfBlY36cUpxDw34LygVL9hBg5A4Dl0yIQLOAb','1216043853284827136-XgLCLf15GtZZ0oIsgInUIjJT1lnPmT', 'ksKmplYg3WBqwThvTbhknJmhBYE7t43Bt0ZijmExr2Nq2')
def find_hashtag(hashtag, count = 20, search_type = 'mixed'):
    """
    This function finds related tweets that are tagged with a specific hashtag
    as a required input it accepts the hashtag with or without the #
    as one of the optional inputs it accepts the count of tweets required to be returned 
    as another optional input it accepts the search type as either recent, mixed, or popular
    as output it returns a list of data objects containing information about the tweets returned
    """
    
    #This line checks to see if the string begins with a # and removes it
    half_hash = hashtag.strip("#").lower()
    hashtag = '%23'+hashtag.strip("#").lower()
    
    #this returns the user details if the user exists or returns an empty dictionary if the user does not exist
    try:
        api_url ='https://api.twitter.com/1.1/search/tweets.json?q={}&count={}&result_type={}'.format(hashtag,count,search_type)
        selected_tweets = requests.get(api_url, auth=auth)
        # i'm not sure what a list of data objects here refers to and so I'm choosing to return what I think is most appropriate
        return selected_tweets.json()['statuses']
        #alternative solutions include the two options below
        #return selected_tweets.json()['search_metadata']
        #return [selected_tweets.json()]
        
    except:
        print("There was an error associated with your input")
        return []
example1 = find_hashtag('DataScience')
example2 = find_hashtag('#DataScience')
example3 = find_hashtag('#DataScience', count=100)

# %%
example1
# Out:
# [{'created_at': 'Thu Nov 05 22:11:00 +0000 2020',
#   'id': 1324474320643629059,
#   'id_str': '1324474320643629059',
#   'text': "10-page [PDF] reference covers a semester's worth of introductory probability — The best #Probability Cheat Sheet t… https://t.co/gmlAaTGpgN",
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'Probability', 'indices': [89, 101]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/gmlAaTGpgN',
#      'expanded_url': 'https://twitter.com/i/web/status/1324474320643629059',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 534563976,
#    'id_str': '534563976',
#    'name': 'Kirk Borne',
#    'screen_name': 'KirkDBorne',
#    'location': 'Maryland, USA',
#    'description': 'Principal Data Scientist @BoozAllen. Global Speaker. Top #BigData #DataScience #AI Influencer. PhD Astrophysicist. (Views = my own) https://t.co/abP8DkYJY2 📊🔭',
#    'url': 'https://t.co/tWlmeuTlR7',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/tWlmeuTlR7',
#        'expanded_url': 'http://www.linkedin.com/in/kirkdborne',
#        'display_url': 'linkedin.com/in/kirkdborne',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/abP8DkYJY2',
#        'expanded_url': 'http://rocketdatascience.org',
#        'display_url': 'rocketdatascience.org',
#        'indices': [132, 155]}]}},
#    'protected': False,
#    'followers_count': 271153,
#    'friends_count': 9822,
#    'listed_count': 8186,
#    'created_at': 'Fri Mar 23 16:35:17 +0000 2012',
#    'favourites_count': 205552,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 127452,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/534563976/1590790599',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 286,
#   'favorite_count': 1106,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Nov 06 09:00:32 +0000 2020',
#   'id': 1324637783575552000,
#   'id_str': '1324637783575552000',
#   'text': 'Thank you Team Jio Institute for the Masterclass on #ArtificialIntelligence &amp; #DataScience (Design Thinking as a St… https://t.co/5fepOfFNw8',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'ArtificialIntelligence',
#      'indices': [52, 75]},
#     {'text': 'DataScience', 'indices': [82, 94]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/5fepOfFNw8',
#      'expanded_url': 'https://twitter.com/i/web/status/1324637783575552000',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [121, 144]}]},
#   'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 215224249,
#    'id_str': '215224249',
#    'name': 'Rohit Bansal 🇮🇳',
#    'screen_name': 'theRohitBansal',
#    'location': 'India',
#    'description': 'Story Teller: RIL|Jio|JioGenNext| Alum: Harvard|Stephens|DPS RKP|ORF|TEDx|FE|TOI|TV18|Zee|Chevening|EUVP|Tweets MINE| Purpose 🇮🇳📱🐯',
#    'url': 'https://t.co/8pL1uz2KJD',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8pL1uz2KJD',
#        'expanded_url': 'http://instagram.com/therohitbansal99',
#        'display_url': 'instagram.com/therohitbansal…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 26351,
#    'friends_count': 1509,
#    'listed_count': 166,
#    'created_at': 'Sat Nov 13 10:03:16 +0000 2010',
#    'favourites_count': 6915,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 52636,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FC0A2A',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1139950873482678272/SpdqsG9E_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1139950873482678272/SpdqsG9E_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/215224249/1592328670',
#    'profile_link_color': 'DD2E44',
#    'profile_sidebar_border_color': 'F2E195',
#    'profile_sidebar_fill_color': 'FFF7CC',
#    'profile_text_color': '0C3E53',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 98,
#   'favorite_count': 106,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Nov 06 01:38:00 +0000 2020',
#   'id': 1324526413794430976,
#   'id_str': '1324526413794430976',
#   'text': '[UPDATED Free PDF]\n#DataScience Cheat Sheet covers concepts in Statistical Learning, #MachineLearning,… https://t.co/i5cP5Fxj05',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'DataScience', 'indices': [19, 31]},
#     {'text': 'MachineLearning', 'indices': [85, 101]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/i5cP5Fxj05',
#      'expanded_url': 'https://twitter.com/i/web/status/1324526413794430976',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [104, 127]}]},
#   'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 534563976,
#    'id_str': '534563976',
#    'name': 'Kirk Borne',
#    'screen_name': 'KirkDBorne',
#    'location': 'Maryland, USA',
#    'description': 'Principal Data Scientist @BoozAllen. Global Speaker. Top #BigData #DataScience #AI Influencer. PhD Astrophysicist. (Views = my own) https://t.co/abP8DkYJY2 📊🔭',
#    'url': 'https://t.co/tWlmeuTlR7',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/tWlmeuTlR7',
#        'expanded_url': 'http://www.linkedin.com/in/kirkdborne',
#        'display_url': 'linkedin.com/in/kirkdborne',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/abP8DkYJY2',
#        'expanded_url': 'http://rocketdatascience.org',
#        'display_url': 'rocketdatascience.org',
#        'indices': [132, 155]}]}},
#    'protected': False,
#    'followers_count': 271153,
#    'friends_count': 9822,
#    'listed_count': 8186,
#    'created_at': 'Fri Mar 23 16:35:17 +0000 2012',
#    'favourites_count': 205552,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 127452,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/534563976/1590790599',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 127,
#   'favorite_count': 391,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Nov 07 04:36:54 +0000 2020',
#   'id': 1324933822765428737,
#   'id_str': '1324933822765428737',
#   'text': 'RT @SourabhSKatoch: How To Build Your Own Chatbot Using Deep Learning.\n\nhttps://t.co/dxYikLOW2c\n\n#MachineLearning #DataScience #Python #AI…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'MachineLearning', 'indices': [97, 113]},
#     {'text': 'DataScience', 'indices': [114, 126]},
#     {'text': 'Python', 'indices': [127, 134]},
#     {'text': 'AI', 'indices': [135, 138]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'SourabhSKatoch',
#      'name': 'Sourabh Singh Katoch',
#      'id': 774550615204790272,
#      'id_str': '774550615204790272',
#      'indices': [3, 18]}],
#    'urls': [{'url': 'https://t.co/dxYikLOW2c',
#      'expanded_url': 'https://towardsdatascience.com/how-to-build-your-own-chatbot-using-deep-learning-bb41f970e281',
#      'display_url': 'towardsdatascience.com/how-to-build-y…',
#      'indices': [72, 95]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 3527715379,
#    'id_str': '3527715379',
#    'name': 'Vikez',
#    'screen_name': 'Vikezmedia',
#    'location': 'San Jose, CA ',
#    'description': 'Bring you #news all over the world that would change the way you think about #life, #society, #technology, and #business.',
#    'url': 'https://t.co/zMTkN2t5Cd',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/zMTkN2t5Cd',
#        'expanded_url': 'http://www.vikez.com',
#        'display_url': 'vikez.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 5280,
#    'friends_count': 5812,
#    'listed_count': 1542,
#    'created_at': 'Fri Sep 11 14:43:57 +0000 2015',
#    'favourites_count': 78342,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 35751,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '642D8B',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/642348669564416000/hqC3m0nb_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/642348669564416000/hqC3m0nb_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3527715379/1585797581',
#    'profile_link_color': 'FF0000',
#    'profile_sidebar_border_color': '65B0DA',
#    'profile_sidebar_fill_color': '7AC3EE',
#    'profile_text_color': '3D1957',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Nov 05 08:41:00 +0000 2020',
#    'id': 1324270477448151040,
#    'id_str': '1324270477448151040',
#    'text': 'How To Build Your Own Chatbot Using Deep Learning.\n\nhttps://t.co/dxYikLOW2c\n\n#MachineLearning #DataScience #Python… https://t.co/qeIcqj4frG',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'MachineLearning', 'indices': [77, 93]},
#      {'text': 'DataScience', 'indices': [94, 106]},
#      {'text': 'Python', 'indices': [107, 114]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/dxYikLOW2c',
#       'expanded_url': 'https://towardsdatascience.com/how-to-build-your-own-chatbot-using-deep-learning-bb41f970e281',
#       'display_url': 'towardsdatascience.com/how-to-build-y…',
#       'indices': [52, 75]},
#      {'url': 'https://t.co/qeIcqj4frG',
#       'expanded_url': 'https://twitter.com/i/web/status/1324270477448151040',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 774550615204790272,
#     'id_str': '774550615204790272',
#     'name': 'Sourabh Singh Katoch',
#     'screen_name': 'SourabhSKatoch',
#     'location': 'New Delhi, India',
#     'description': 'Data Scientist | Machine Learning Engineer\n\nWrites about AI Research, Data Science, Python Programming & Development. Educator, Open Source advocate & memer.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 11269,
#     'friends_count': 11759,
#     'listed_count': 37,
#     'created_at': 'Sat Sep 10 10:10:32 +0000 2016',
#     'favourites_count': 293,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 714,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1250501846709334017/WU0jzEqi_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250501846709334017/WU0jzEqi_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 72,
#    'favorite_count': 42,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 72,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Nov 07 04:36:50 +0000 2020',
#   'id': 1324933806676086784,
#   'id_str': '1324933806676086784',
#   'text': 'RT @ProgrammerBooks: Build APIs You Won’t Hate ==&gt; https://t.co/gfl3rTYuCA\n\n#python #javascript #angular #reactjs #vuejs #perl #ruby #Cshar…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'python', 'indices': [79, 86]},
#     {'text': 'javascript', 'indices': [87, 98]},
#     {'text': 'angular', 'indices': [99, 107]},
#     {'text': 'reactjs', 'indices': [108, 116]},
#     {'text': 'vuejs', 'indices': [117, 123]},
#     {'text': 'perl', 'indices': [124, 129]},
#     {'text': 'ruby', 'indices': [130, 135]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ProgrammerBooks',
#      'name': 'Programmer Books',
#      'id': 992142356420980738,
#      'id_str': '992142356420980738',
#      'indices': [3, 19]}],
#    'urls': [{'url': 'https://t.co/gfl3rTYuCA',
#      'expanded_url': 'https://www.programmer-books.com/build-apis-you-wont-hate/',
#      'display_url': 'programmer-books.com/build-apis-you…',
#      'indices': [54, 77]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://about.me/siddharth_bisht" rel="nofollow">friday_the_bot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1278273884903505921,
#    'id_str': '1278273884903505921',
#    'name': 'Friday',
#    'screen_name': 'friday_Js_bot',
#    'location': '',
#    'description': 'I am a bot, I retweet everything on #javascript, #typescript and #NodeJs. Created by @SidDarthVader31\nDM me hello for fun,\nDM me follow to get a follow back :-)',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 892,
#    'friends_count': 37,
#    'listed_count': 29,
#    'created_at': 'Wed Jul 01 10:27:05 +0000 2020',
#    'favourites_count': 5,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 206273,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1278275454525267970/MhuXITC3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1278275454525267970/MhuXITC3_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1278273884903505921/1593599659',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Nov 07 03:29:10 +0000 2020',
#    'id': 1324916780683440128,
#    'id_str': '1324916780683440128',
#    'text': 'Build APIs You Won’t Hate ==&gt; https://t.co/gfl3rTYuCA\n\n#python #javascript #angular #reactjs #vuejs #perl #ruby… https://t.co/acARXS14lS',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'python', 'indices': [58, 65]},
#      {'text': 'javascript', 'indices': [66, 77]},
#      {'text': 'angular', 'indices': [78, 86]},
#      {'text': 'reactjs', 'indices': [87, 95]},
#      {'text': 'vuejs', 'indices': [96, 102]},
#      {'text': 'perl', 'indices': [103, 108]},
#      {'text': 'ruby', 'indices': [109, 114]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/gfl3rTYuCA',
#       'expanded_url': 'https://www.programmer-books.com/build-apis-you-wont-hate/',
#       'display_url': 'programmer-books.com/build-apis-you…',
#       'indices': [33, 56]},
#      {'url': 'https://t.co/acARXS14lS',
#       'expanded_url': 'https://twitter.com/i/web/status/1324916780683440128',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://programmer-books.com" rel="nofollow">ProgBooks</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 992142356420980738,
#     'id_str': '992142356420980738',
#     'name': 'Programmer Books',
#     'screen_name': 'ProgrammerBooks',
#     'location': 'Wordwide',
#     'description': 'Programmer-books is a great source of knowledge for software developers.  Here we share with you the best software development books to read.',
#     'url': 'https://t.co/mV6b2cwDsW',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/mV6b2cwDsW',
#         'expanded_url': 'https://programmer-books.com',
#         'display_url': 'programmer-books.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4108,
#     'friends_count': 213,
#     'listed_count': 57,
#     'created_at': 'Thu May 03 20:42:25 +0000 2018',
#     'favourites_count': 500,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 12495,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1000551981331746818/GyBjfX2V_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1000551981331746818/GyBjfX2V_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/992142356420980738/1527047384',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 15,
#    'favorite_count': 6,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 15,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Nov 07 04:36:46 +0000 2020',
#   'id': 1324933792310628353,
#   'id_str': '1324933792310628353',
#   'text': 'RT @ProgrammerBooks: Build APIs You Won’t Hate ==&gt; https://t.co/gfl3rTYuCA\n\n#python #javascript #angular #reactjs #vuejs #perl #ruby #Cshar…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'python', 'indices': [79, 86]},
#     {'text': 'javascript', 'indices': [87, 98]},
#     {'text': 'angular', 'indices': [99, 107]},
#     {'text': 'reactjs', 'indices': [108, 116]},
#     {'text': 'vuejs', 'indices': [117, 123]},
#     {'text': 'perl', 'indices': [124, 129]},
#     {'text': 'ruby', 'indices': [130, 135]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ProgrammerBooks',
#      'name': 'Programmer Books',
#      'id': 992142356420980738,
#      'id_str': '992142356420980738',
#      'indices': [3, 19]}],
#    'urls': [{'url': 'https://t.co/gfl3rTYuCA',
#      'expanded_url': 'https://www.programmer-books.com/build-apis-you-wont-hate/',
#      'display_url': 'programmer-books.com/build-apis-you…',
#      'indices': [54, 77]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://rishabhmishra.me/" rel="nofollow">React Dev autobot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 812555214024740865,
#    'id_str': '812555214024740865',
#    'name': 'React Developer',
#    'screen_name': '_reactdev',
#    'location': 'Everywhere',
#    'description': 'React, Redux and React-Native Developer',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 6550,
#    'friends_count': 90,
#    'listed_count': 133,
#    'created_at': 'Sat Dec 24 07:07:14 +0000 2016',
#    'favourites_count': 137,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 215571,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/812556678344351744/SiRnLTqx_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/812556678344351744/SiRnLTqx_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Nov 07 03:29:10 +0000 2020',
#    'id': 1324916780683440128,
#    'id_str': '1324916780683440128',
#    'text': 'Build APIs You Won’t Hate ==&gt; https://t.co/gfl3rTYuCA\n\n#python #javascript #angular #reactjs #vuejs #perl #ruby… https://t.co/acARXS14lS',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'python', 'indices': [58, 65]},
#      {'text': 'javascript', 'indices': [66, 77]},
#      {'text': 'angular', 'indices': [78, 86]},
#      {'text': 'reactjs', 'indices': [87, 95]},
#      {'text': 'vuejs', 'indices': [96, 102]},
#      {'text': 'perl', 'indices': [103, 108]},
#      {'text': 'ruby', 'indices': [109, 114]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/gfl3rTYuCA',
#       'expanded_url': 'https://www.programmer-books.com/build-apis-you-wont-hate/',
#       'display_url': 'programmer-books.com/build-apis-you…',
#       'indices': [33, 56]},
#      {'url': 'https://t.co/acARXS14lS',
#       'expanded_url': 'https://twitter.com/i/web/status/1324916780683440128',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://programmer-books.com" rel="nofollow">ProgBooks</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 992142356420980738,
#     'id_str': '992142356420980738',
#     'name': 'Programmer Books',
#     'screen_name': 'ProgrammerBooks',
#     'location': 'Wordwide',
#     'description': 'Programmer-books is a great source of knowledge for software developers.  Here we share with you the best software development books to read.',
#     'url': 'https://t.co/mV6b2cwDsW',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/mV6b2cwDsW',
#         'expanded_url': 'https://programmer-books.com',
#         'display_url': 'programmer-books.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4108,
#     'friends_count': 213,
#     'listed_count': 57,
#     'created_at': 'Thu May 03 20:42:25 +0000 2018',
#     'favourites_count': 500,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 12495,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1000551981331746818/GyBjfX2V_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1000551981331746818/GyBjfX2V_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/992142356420980738/1527047384',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 15,
#    'favorite_count': 6,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 15,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Nov 07 04:36:46 +0000 2020',
#   'id': 1324933792235212800,
#   'id_str': '1324933792235212800',
#   'text': 'RT @thisisgulshan: Top 5 #Free #MachineLearning and #DeepLearning #eBooks\nEveryone should read\n\nhttps://t.co/60q0IURqvf\n\n #fintech #AI #Art…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'Free', 'indices': [25, 30]},
#     {'text': 'MachineLearning', 'indices': [31, 47]},
#     {'text': 'DeepLearning', 'indices': [52, 65]},
#     {'text': 'eBooks', 'indices': [66, 73]},
#     {'text': 'fintech', 'indices': [122, 130]},
#     {'text': 'AI', 'indices': [131, 134]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'thisisgulshan',
#      'name': 'Gulshan Yadav',
#      'id': 2184926258,
#      'id_str': '2184926258',
#      'indices': [3, 17]}],
#    'urls': [{'url': 'https://t.co/60q0IURqvf',
#      'expanded_url': 'https://buff.ly/3mX0Lcc',
#      'display_url': 'buff.ly/3mX0Lcc',
#      'indices': [96, 119]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://rishabhmishra.me/" rel="nofollow">React Dev autobot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 812555214024740865,
#    'id_str': '812555214024740865',
#    'name': 'React Developer',
#    'screen_name': '_reactdev',
#    'location': 'Everywhere',
#    'description': 'React, Redux and React-Native Developer',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 6550,
#    'friends_count': 90,
#    'listed_count': 133,
#    'created_at': 'Sat Dec 24 07:07:14 +0000 2016',
#    'favourites_count': 137,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 215571,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/812556678344351744/SiRnLTqx_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/812556678344351744/SiRnLTqx_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Nov 07 04:00:01 +0000 2020',
#    'id': 1324924543010402305,
#    'id_str': '1324924543010402305',
#    'text': 'Top 5 #Free #MachineLearning and #DeepLearning #eBooks\nEveryone should read\n\nhttps://t.co/60q0IURqvf\n\n #fintech #AI… https://t.co/vze5ZMA4WN',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Free', 'indices': [6, 11]},
#      {'text': 'MachineLearning', 'indices': [12, 28]},
#      {'text': 'DeepLearning', 'indices': [33, 46]},
#      {'text': 'eBooks', 'indices': [47, 54]},
#      {'text': 'fintech', 'indices': [103, 111]},
#      {'text': 'AI', 'indices': [112, 115]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/60q0IURqvf',
#       'expanded_url': 'https://buff.ly/3mX0Lcc',
#       'display_url': 'buff.ly/3mX0Lcc',
#       'indices': [77, 100]},
#      {'url': 'https://t.co/vze5ZMA4WN',
#       'expanded_url': 'https://twitter.com/i/web/status/1324924543010402305',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://www.tweetcaster.com" rel="nofollow">TweetCaster for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2184926258,
#     'id_str': '2184926258',
#     'name': 'Gulshan Yadav',
#     'screen_name': 'thisisgulshan',
#     'location': 'Gurgaon, Haryana, India',
#     'description': '13+ years exp. in Automotive🚗🚜 sw & fw dev. #Embedded Systems #EdgeComputing #BigData #DataScience Data Engineering #Azure #IOT #AI #MachineLearning #Coding',
#     'url': 'https://t.co/P6hTR9Medl',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/P6hTR9Medl',
#         'expanded_url': 'http://linkedin.com/in/gulshanyadav',
#         'display_url': 'linkedin.com/in/gulshanyadav',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4779,
#     'friends_count': 4006,
#     'listed_count': 255,
#     'created_at': 'Sat Nov 09 19:35:04 +0000 2013',
#     'favourites_count': 5796,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 10924,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1321352269359542272/xMtucH6-_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1321352269359542272/xMtucH6-_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2184926258/1578132607',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 14,
#    'favorite_count': 5,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 14,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Nov 07 04:36:46 +0000 2020',
#   'id': 1324933790385532928,
#   'id_str': '1324933790385532928',
#   'text': 'RT @thisisgulshan: Top 5 #Free #MachineLearning and #DeepLearning #eBooks\nEveryone should read\n\nhttps://t.co/60q0IURqvf\n\n #fintech #AI #Art…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'Free', 'indices': [25, 30]},
#     {'text': 'MachineLearning', 'indices': [31, 47]},
#     {'text': 'DeepLearning', 'indices': [52, 65]},
#     {'text': 'eBooks', 'indices': [66, 73]},
#     {'text': 'fintech', 'indices': [122, 130]},
#     {'text': 'AI', 'indices': [131, 134]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'thisisgulshan',
#      'name': 'Gulshan Yadav',
#      'id': 2184926258,
#      'id_str': '2184926258',
#      'indices': [3, 17]}],
#    'urls': [{'url': 'https://t.co/60q0IURqvf',
#      'expanded_url': 'https://buff.ly/3mX0Lcc',
#      'display_url': 'buff.ly/3mX0Lcc',
#      'indices': [96, 119]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://nlogn.in" rel="nofollow">nlognrobot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1260062769543434240,
#    'id_str': '1260062769543434240',
#    'name': '#100DaysOfCode',
#    'screen_name': 'nlognbot',
#    'location': 'Server',
#    'description': "Hi, I'm a bot that retweets #100daysofcode     \n                 \nP.S. I was created by @NlognHQ follow them.",
#    'url': 'https://t.co/PujHDQomPA',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/PujHDQomPA',
#        'expanded_url': 'http://nlogn.in',
#        'display_url': 'nlogn.in',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4654,
#    'friends_count': 3,
#    'listed_count': 52,
#    'created_at': 'Tue May 12 04:22:53 +0000 2020',
#    'favourites_count': 807,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 391438,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1306825824104898560/F1I_GcS1_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1306825824104898560/F1I_GcS1_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1260062769543434240/1593858684',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Nov 07 04:00:01 +0000 2020',
#    'id': 1324924543010402305,
#    'id_str': '1324924543010402305',
#    'text': 'Top 5 #Free #MachineLearning and #DeepLearning #eBooks\nEveryone should read\n\nhttps://t.co/60q0IURqvf\n\n #fintech #AI… https://t.co/vze5ZMA4WN',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Free', 'indices': [6, 11]},
#      {'text': 'MachineLearning', 'indices': [12, 28]},
#      {'text': 'DeepLearning', 'indices': [33, 46]},
#      {'text': 'eBooks', 'indices': [47, 54]},
#      {'text': 'fintech', 'indices': [103, 111]},
#      {'text': 'AI', 'indices': [112, 115]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/60q0IURqvf',
#       'expanded_url': 'https://buff.ly/3mX0Lcc',
#       'display_url': 'buff.ly/3mX0Lcc',
#       'indices': [77, 100]},
#      {'url': 'https://t.co/vze5ZMA4WN',
#       'expanded_url': 'https://twitter.com/i/web/status/1324924543010402305',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://www.tweetcaster.com" rel="nofollow">TweetCaster for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2184926258,
#     'id_str': '2184926258',
#     'name': 'Gulshan Yadav',
#     'screen_name': 'thisisgulshan',
#     'location': 'Gurgaon, Haryana, India',
#     'description': '13+ years exp. in Automotive🚗🚜 sw & fw dev. #Embedded Systems #EdgeComputing #BigData #DataScience Data Engineering #Azure #IOT #AI #MachineLearning #Coding',
#     'url': 'https://t.co/P6hTR9Medl',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/P6hTR9Medl',
#         'expanded_url': 'http://linkedin.com/in/gulshanyadav',
#         'display_url': 'linkedin.com/in/gulshanyadav',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4779,
#     'friends_count': 4006,
#     'listed_count': 255,
#     'created_at': 'Sat Nov 09 19:35:04 +0000 2013',
#     'favourites_count': 5796,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 10924,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1321352269359542272/xMtucH6-_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1321352269359542272/xMtucH6-_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2184926258/1578132607',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 14,
#    'favorite_count': 5,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 14,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Nov 07 04:36:46 +0000 2020',
#   'id': 1324933790347747330,
#   'id_str': '1324933790347747330',
#   'text': 'RT @thisisgulshan: Top 5 #Free #MachineLearning and #DeepLearning #eBooks\nEveryone should read\n\nhttps://t.co/60q0IURqvf\n\n #fintech #AI #Art…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'Free', 'indices': [25, 30]},
#     {'text': 'MachineLearning', 'indices': [31, 47]},
#     {'text': 'DeepLearning', 'indices': [52, 65]},
#     {'text': 'eBooks', 'indices': [66, 73]},
#     {'text': 'fintech', 'indices': [122, 130]},
#     {'text': 'AI', 'indices': [131, 134]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'thisisgulshan',
#      'name': 'Gulshan Yadav',
#      'id': 2184926258,
#      'id_str': '2184926258',
#      'indices': [3, 17]}],
#    'urls': [{'url': 'https://t.co/60q0IURqvf',
#      'expanded_url': 'https://buff.ly/3mX0Lcc',
#      'display_url': 'buff.ly/3mX0Lcc',
#      'indices': [96, 119]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://occlude.netlify.app/" rel="nofollow">OccludejsBot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1275056773443973124,
#    'id_str': '1275056773443973124',
#    'name': 'Jessica shoonover',
#    'screen_name': 'Women_who_code',
#    'location': 'bootcamp',
#    'description': '24 🧬 ~ Javascript ❤️ ~ Mern Stack Developer ~ Next JS 🦄 ~ @nytimes ~ Books 📚 + coffee ☕',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1102,
#    'friends_count': 24,
#    'listed_count': 25,
#    'created_at': 'Mon Jun 22 13:23:34 +0000 2020',
#    'favourites_count': 333,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 131865,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1319806256513646592/S1f4A7_A_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1319806256513646592/S1f4A7_A_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1275056773443973124/1603501540',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Nov 07 04:00:01 +0000 2020',
#    'id': 1324924543010402305,
#    'id_str': '1324924543010402305',
#    'text': 'Top 5 #Free #MachineLearning and #DeepLearning #eBooks\nEveryone should read\n\nhttps://t.co/60q0IURqvf\n\n #fintech #AI… https://t.co/vze5ZMA4WN',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Free', 'indices': [6, 11]},
#      {'text': 'MachineLearning', 'indices': [12, 28]},
#      {'text': 'DeepLearning', 'indices': [33, 46]},
#      {'text': 'eBooks', 'indices': [47, 54]},
# ...
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Nov 07 04:24:48 +0000 2020',
#    'id': 1324930777788817408,
#    'id_str': '1324930777788817408',
#    'text': 'We all felt like this at some point 🤣 \n#Coding #100DaysOfCode #programming #code #Python #javascript #5G #webinar… https://t.co/f6IePj6XYR',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Coding', 'indices': [39, 46]},
#      {'text': '100DaysOfCode', 'indices': [47, 61]},
#      {'text': 'programming', 'indices': [62, 74]},
#      {'text': 'code', 'indices': [75, 80]},
#      {'text': 'Python', 'indices': [81, 88]},
#      {'text': 'javascript', 'indices': [89, 100]},
#      {'text': '5G', 'indices': [101, 104]},
#      {'text': 'webinar', 'indices': [105, 113]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/f6IePj6XYR',
#       'expanded_url': 'https://twitter.com/i/web/status/1324930777788817408',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [115, 138]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1269557770337976320,
#     'id_str': '1269557770337976320',
#     'name': '𝑵𝑰𝑻𝑰𝑵 🎭',
#     'screen_name': '_Nitin__Rawat_',
#     'location': 'Earth 🌎',
#     'description': "ɪ'ᴍ ꜱᴇᴠᴇʀᴇʟʏ ᴏᴠᴇʀʀᴀᴛᴇᴅ...ɪ'ᴍ ᴊᴜꜱᴛ ᴀʙᴏᴠᴇ ᴀ ʜᴀᴄᴋ",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 178,
#     'friends_count': 83,
#     'listed_count': 0,
#     'created_at': 'Sun Jun 07 09:12:31 +0000 2020',
#     'favourites_count': 5998,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 214,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1316438833932562432/cZxabczy_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1316438833932562432/cZxabczy_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1269557770337976320/1602699482',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 24,
#    'favorite_count': 10,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 24,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Nov 07 04:36:34 +0000 2020',
#   'id': 1324933742704685056,
#   'id_str': '1324933742704685056',
#   'text': 'RT @_Nitin__Rawat_: We all felt like this at some point 🤣 \n#Coding #100DaysOfCode #programming #code #Python #javascript #5G #webinar #gami…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'Coding', 'indices': [59, 66]},
#     {'text': '100DaysOfCode', 'indices': [67, 81]},
#     {'text': 'programming', 'indices': [82, 94]},
#     {'text': 'code', 'indices': [95, 100]},
#     {'text': 'Python', 'indices': [101, 108]},
#     {'text': 'javascript', 'indices': [109, 120]},
#     {'text': '5G', 'indices': [121, 124]},
#     {'text': 'webinar', 'indices': [125, 133]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': '_Nitin__Rawat_',
#      'name': '𝑵𝑰𝑻𝑰𝑵 🎭',
#      'id': 1269557770337976320,
#      'id_str': '1269557770337976320',
#      'indices': [3, 18]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://twitter.com/codedailybot" rel="nofollow">codedailybot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1204128767251230720,
#    'id_str': '1204128767251230720',
#    'name': '#100daysOfCode',
#    'screen_name': 'codedailybot',
#    'location': '#codedaily',
#    'description': 'follow me. #100daysOfCode  #coding  #hourofcode or code related\nmade with ❤️ + node.js by @yunkidev',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 5300,
#    'friends_count': 1,
#    'listed_count': 62,
#    'created_at': 'Mon Dec 09 20:01:02 +0000 2019',
#    'favourites_count': 256,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 638925,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1204131757534171136/Hdf5uixg_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1204131757534171136/Hdf5uixg_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1204128767251230720/1575923213',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Nov 07 04:24:48 +0000 2020',
#    'id': 1324930777788817408,
#    'id_str': '1324930777788817408',
#    'text': 'We all felt like this at some point 🤣 \n#Coding #100DaysOfCode #programming #code #Python #javascript #5G #webinar… https://t.co/f6IePj6XYR',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Coding', 'indices': [39, 46]},
#      {'text': '100DaysOfCode', 'indices': [47, 61]},
#      {'text': 'programming', 'indices': [62, 74]},
#      {'text': 'code', 'indices': [75, 80]},
#      {'text': 'Python', 'indices': [81, 88]},
#      {'text': 'javascript', 'indices': [89, 100]},
#      {'text': '5G', 'indices': [101, 104]},
#      {'text': 'webinar', 'indices': [105, 113]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/f6IePj6XYR',
#       'expanded_url': 'https://twitter.com/i/web/status/1324930777788817408',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [115, 138]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1269557770337976320,
#     'id_str': '1269557770337976320',
#     'name': '𝑵𝑰𝑻𝑰𝑵 🎭',
#     'screen_name': '_Nitin__Rawat_',
#     'location': 'Earth 🌎',
#     'description': "ɪ'ᴍ ꜱᴇᴠᴇʀᴇʟʏ ᴏᴠᴇʀʀᴀᴛᴇᴅ...ɪ'ᴍ ᴊᴜꜱᴛ ᴀʙᴏᴠᴇ ᴀ ʜᴀᴄᴋ",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 178,
#     'friends_count': 83,
#     'listed_count': 0,
#     'created_at': 'Sun Jun 07 09:12:31 +0000 2020',
#     'favourites_count': 5998,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 214,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1316438833932562432/cZxabczy_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1316438833932562432/cZxabczy_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1269557770337976320/1602699482',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 24,
#    'favorite_count': 10,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 24,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sat Nov 07 04:36:29 +0000 2020',
#   'id': 1324933717907841025,
#   'id_str': '1324933717907841025',
#   'text': "RT @SourabhSKatoch: Programmer's life in a nutshell. Who else relates? 😂\n\n#100DaysOfCode #MachineLearning #Python #programming #IoT #flutte…",
#   'truncated': False,
#   'entities': {'hashtags': [{'text': '100DaysOfCode', 'indices': [74, 88]},
#     {'text': 'MachineLearning', 'indices': [89, 105]},
#     {'text': 'Python', 'indices': [106, 113]},
#     {'text': 'programming', 'indices': [114, 126]},
#     {'text': 'IoT', 'indices': [127, 131]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'SourabhSKatoch',
#      'name': 'Sourabh Singh Katoch',
#      'id': 774550615204790272,
#      'id_str': '774550615204790272',
#      'indices': [3, 18]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 746651472142557184,
#    'id_str': '746651472142557184',
#    'name': '暴走オカン',
#    'screen_name': 'OorNo_',
#    'location': '',
#    'description': 'オスメスのT3Ng-α',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 374,
#    'friends_count': 1018,
#    'listed_count': 6,
#    'created_at': 'Sat Jun 25 10:29:17 +0000 2016',
#    'favourites_count': 50109,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 47423,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1319144446168944640/VeoiOOBS_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1319144446168944640/VeoiOOBS_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/746651472142557184/1593850712',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Nov 05 21:06:31 +0000 2020',
#    'id': 1324458092763832320,
#    'id_str': '1324458092763832320',
#    'text': "Programmer's life in a nutshell. Who else relates? 😂\n\n#100DaysOfCode #MachineLearning #Python #programming #IoT… https://t.co/TrBjrzGiPR",
#    'truncated': True,
#    'entities': {'hashtags': [{'text': '100DaysOfCode', 'indices': [54, 68]},
#      {'text': 'MachineLearning', 'indices': [69, 85]},
#      {'text': 'Python', 'indices': [86, 93]},
#      {'text': 'programming', 'indices': [94, 106]},
#      {'text': 'IoT', 'indices': [107, 111]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/TrBjrzGiPR',
#       'expanded_url': 'https://twitter.com/i/web/status/1324458092763832320',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [113, 136]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 774550615204790272,
#     'id_str': '774550615204790272',
#     'name': 'Sourabh Singh Katoch',
#     'screen_name': 'SourabhSKatoch',
#     'location': 'New Delhi, India',
#     'description': 'Data Scientist | Machine Learning Engineer\n\nWrites about AI Research, Data Science, Python Programming & Development. Educator, Open Source advocate & memer.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 11269,
#     'friends_count': 11759,
#     'listed_count': 37,
#     'created_at': 'Sat Sep 10 10:10:32 +0000 2016',
#     'favourites_count': 293,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 714,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1250501846709334017/WU0jzEqi_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250501846709334017/WU0jzEqi_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 314,
#    'favorite_count': 833,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 314,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'}]

# %%
example2
# Out:
# [{'statuses': [{'created_at': 'Thu Nov 05 22:11:00 +0000 2020',
#     'id': 1324474320643629059,
#     'id_str': '1324474320643629059',
#     'text': "10-page [PDF] reference covers a semester's worth of introductory probability — The best #Probability Cheat Sheet t… https://t.co/gmlAaTGpgN",
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Probability', 'indices': [89, 101]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/gmlAaTGpgN',
#        'expanded_url': 'https://twitter.com/i/web/status/1324474320643629059',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 534563976,
#      'id_str': '534563976',
#      'name': 'Kirk Borne',
#      'screen_name': 'KirkDBorne',
#      'location': 'Maryland, USA',
#      'description': 'Principal Data Scientist @BoozAllen. Global Speaker. Top #BigData #DataScience #AI Influencer. PhD Astrophysicist. (Views = my own) https://t.co/abP8DkYJY2 📊🔭',
#      'url': 'https://t.co/tWlmeuTlR7',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/tWlmeuTlR7',
#          'expanded_url': 'http://www.linkedin.com/in/kirkdborne',
#          'display_url': 'linkedin.com/in/kirkdborne',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/abP8DkYJY2',
#          'expanded_url': 'http://rocketdatascience.org',
#          'display_url': 'rocketdatascience.org',
#          'indices': [132, 155]}]}},
#      'protected': False,
#      'followers_count': 271146,
#      'friends_count': 9822,
#      'listed_count': 8186,
#      'created_at': 'Fri Mar 23 16:35:17 +0000 2012',
#      'favourites_count': 205552,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 127450,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/534563976/1590790599',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 286,
#     'favorite_count': 1104,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    {'created_at': 'Fri Nov 06 09:00:32 +0000 2020',
#     'id': 1324637783575552000,
#     'id_str': '1324637783575552000',
#     'text': 'Thank you Team Jio Institute for the Masterclass on #ArtificialIntelligence &amp; #DataScience (Design Thinking as a St… https://t.co/5fepOfFNw8',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'ArtificialIntelligence',
#        'indices': [52, 75]},
#       {'text': 'DataScience', 'indices': [82, 94]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/5fepOfFNw8',
#        'expanded_url': 'https://twitter.com/i/web/status/1324637783575552000',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [121, 144]}]},
#     'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 215224249,
#      'id_str': '215224249',
#      'name': 'Rohit Bansal 🇮🇳',
#      'screen_name': 'theRohitBansal',
#      'location': 'India',
#      'description': 'Story Teller: RIL|Jio|JioGenNext| Alum: Harvard|Stephens|DPS RKP|ORF|TEDx|FE|TOI|TV18|Zee|Chevening|EUVP|Tweets MINE| Purpose 🇮🇳📱🐯',
#      'url': 'https://t.co/8pL1uz2KJD',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/8pL1uz2KJD',
#          'expanded_url': 'http://instagram.com/therohitbansal99',
#          'display_url': 'instagram.com/therohitbansal…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 26351,
#      'friends_count': 1509,
#      'listed_count': 166,
#      'created_at': 'Sat Nov 13 10:03:16 +0000 2010',
#      'favourites_count': 6915,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 52636,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FC0A2A',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1139950873482678272/SpdqsG9E_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1139950873482678272/SpdqsG9E_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/215224249/1592328670',
#      'profile_link_color': 'DD2E44',
#      'profile_sidebar_border_color': 'F2E195',
#      'profile_sidebar_fill_color': 'FFF7CC',
#      'profile_text_color': '0C3E53',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 100,
#     'favorite_count': 107,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    {'created_at': 'Fri Nov 06 01:38:00 +0000 2020',
#     'id': 1324526413794430976,
#     'id_str': '1324526413794430976',
#     'text': '[UPDATED Free PDF]\n#DataScience Cheat Sheet covers concepts in Statistical Learning, #MachineLearning,… https://t.co/i5cP5Fxj05',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DataScience', 'indices': [19, 31]},
#       {'text': 'MachineLearning', 'indices': [85, 101]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/i5cP5Fxj05',
#        'expanded_url': 'https://twitter.com/i/web/status/1324526413794430976',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [104, 127]}]},
#     'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 534563976,
#      'id_str': '534563976',
#      'name': 'Kirk Borne',
#      'screen_name': 'KirkDBorne',
#      'location': 'Maryland, USA',
#      'description': 'Principal Data Scientist @BoozAllen. Global Speaker. Top #BigData #DataScience #AI Influencer. PhD Astrophysicist. (Views = my own) https://t.co/abP8DkYJY2 📊🔭',
#      'url': 'https://t.co/tWlmeuTlR7',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/tWlmeuTlR7',
#          'expanded_url': 'http://www.linkedin.com/in/kirkdborne',
#          'display_url': 'linkedin.com/in/kirkdborne',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/abP8DkYJY2',
#          'expanded_url': 'http://rocketdatascience.org',
#          'display_url': 'rocketdatascience.org',
#          'indices': [132, 155]}]}},
#      'protected': False,
#      'followers_count': 271146,
#      'friends_count': 9822,
#      'listed_count': 8186,
#      'created_at': 'Fri Mar 23 16:35:17 +0000 2012',
#      'favourites_count': 205552,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 127450,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/534563976/1590790599',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 127,
#     'favorite_count': 391,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    {'created_at': 'Sat Nov 07 04:16:05 +0000 2020',
#     'id': 1324928585577029632,
#     'id_str': '1324928585577029632',
#     'text': 'RT @SourabhSKatoch: 5 Practical tips for data aggregation in pandas.\n\nhttps://t.co/VSwHAyZdkM\n\n#Python #MachineLearning #AI #100DaysOfCode…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [95, 102]},
#       {'text': 'MachineLearning', 'indices': [103, 119]},
#       {'text': 'AI', 'indices': [120, 123]},
#       {'text': '100DaysOfCode', 'indices': [124, 138]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'SourabhSKatoch',
#        'name': 'Sourabh Singh Katoch',
#        'id': 774550615204790272,
#        'id_str': '774550615204790272',
#        'indices': [3, 18]}],
#      'urls': [{'url': 'https://t.co/VSwHAyZdkM',
#        'expanded_url': 'https://towardsdatascience.com/5-tips-for-data-aggregation-in-pandas-7eaa8476dc75',
#        'display_url': 'towardsdatascience.com/5-tips-for-dat…',
#        'indices': [70, 93]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.me/siddharth_bisht" rel="nofollow">friday_the_bot</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1278273884903505921,
#      'id_str': '1278273884903505921',
#      'name': 'Friday',
#      'screen_name': 'friday_Js_bot',
#      'location': '',
#      'description': 'I am a bot, I retweet everything on #javascript, #typescript and #NodeJs. Created by @SidDarthVader31\nDM me hello for fun,\nDM me follow to get a follow back :-)',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 891,
#      'friends_count': 37,
#      'listed_count': 30,
#      'created_at': 'Wed Jul 01 10:27:05 +0000 2020',
#      'favourites_count': 5,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 206174,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1278275454525267970/MhuXITC3_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1278275454525267970/MhuXITC3_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1278273884903505921/1593599659',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Nov 02 08:41:00 +0000 2020',
#      'id': 1323183313914261505,
#      'id_str': '1323183313914261505',
#      'text': '5 Practical tips for data aggregation in pandas.\n\nhttps://t.co/VSwHAyZdkM\n\n#Python #MachineLearning #AI… https://t.co/Jhu1CcBVyW',
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'Python', 'indices': [75, 82]},
#        {'text': 'MachineLearning', 'indices': [83, 99]},
#        {'text': 'AI', 'indices': [100, 103]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/VSwHAyZdkM',
#         'expanded_url': 'https://towardsdatascience.com/5-tips-for-data-aggregation-in-pandas-7eaa8476dc75',
#         'display_url': 'towardsdatascience.com/5-tips-for-dat…',
#         'indices': [50, 73]},
#        {'url': 'https://t.co/Jhu1CcBVyW',
#         'expanded_url': 'https://twitter.com/i/web/status/1323183313914261505',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [105, 128]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 774550615204790272,
#       'id_str': '774550615204790272',
#       'name': 'Sourabh Singh Katoch',
#       'screen_name': 'SourabhSKatoch',
#       'location': 'New Delhi, India',
#       'description': 'Data Scientist | Machine Learning Engineer\n\nWrites about AI Research, Data Science, Python Programming & Development. Educator, Open Source advocate & memer.',
#       'url': None,
#       'entities': {'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 11272,
#       'friends_count': 11759,
#       'listed_count': 37,
#       'created_at': 'Sat Sep 10 10:10:32 +0000 2016',
#       'favourites_count': 293,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 714,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F5F8FA',
#       'profile_background_image_url': None,
#       'profile_background_image_url_https': None,
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1250501846709334017/WU0jzEqi_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250501846709334017/WU0jzEqi_normal.jpg',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': True,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 129,
#      'favorite_count': 52,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 129,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    {'created_at': 'Sat Nov 07 04:16:05 +0000 2020',
#     'id': 1324928585308758017,
#     'id_str': '1324928585308758017',
#     'text': 'RT @SourabhSKatoch: 5 Practical tips for data aggregation in pandas.\n\nhttps://t.co/VSwHAyZdkM\n\n#Python #MachineLearning #AI #100DaysOfCode…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [95, 102]},
#       {'text': 'MachineLearning', 'indices': [103, 119]},
#       {'text': 'AI', 'indices': [120, 123]},
#       {'text': '100DaysOfCode', 'indices': [124, 138]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'SourabhSKatoch',
#        'name': 'Sourabh Singh Katoch',
#        'id': 774550615204790272,
#        'id_str': '774550615204790272',
#        'indices': [3, 18]}],
#      'urls': [{'url': 'https://t.co/VSwHAyZdkM',
#        'expanded_url': 'https://towardsdatascience.com/5-tips-for-data-aggregation-in-pandas-7eaa8476dc75',
#        'display_url': 'towardsdatascience.com/5-tips-for-dat…',
#        'indices': [70, 93]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://nlogn.in" rel="nofollow">nlognrobot</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1260062769543434240,
#      'id_str': '1260062769543434240',
#      'name': '#100DaysOfCode',
#      'screen_name': 'nlognbot',
#      'location': 'Server',
#      'description': "Hi, I'm a bot that retweets #100daysofcode     \n                 \nP.S. I was created by @NlognHQ follow them.",
#      'url': 'https://t.co/PujHDQomPA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/PujHDQomPA',
#          'expanded_url': 'http://nlogn.in',
#          'display_url': 'nlogn.in',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4654,
#      'friends_count': 3,
#      'listed_count': 52,
#      'created_at': 'Tue May 12 04:22:53 +0000 2020',
#      'favourites_count': 807,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 391397,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1306825824104898560/F1I_GcS1_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1306825824104898560/F1I_GcS1_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1260062769543434240/1593858684',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Nov 02 08:41:00 +0000 2020',
#      'id': 1323183313914261505,
#      'id_str': '1323183313914261505',
#      'text': '5 Practical tips for data aggregation in pandas.\n\nhttps://t.co/VSwHAyZdkM\n\n#Python #MachineLearning #AI… https://t.co/Jhu1CcBVyW',
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'Python', 'indices': [75, 82]},
#        {'text': 'MachineLearning', 'indices': [83, 99]},
#        {'text': 'AI', 'indices': [100, 103]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/VSwHAyZdkM',
#         'expanded_url': 'https://towardsdatascience.com/5-tips-for-data-aggregation-in-pandas-7eaa8476dc75',
#         'display_url': 'towardsdatascience.com/5-tips-for-dat…',
#         'indices': [50, 73]},
#        {'url': 'https://t.co/Jhu1CcBVyW',
#         'expanded_url': 'https://twitter.com/i/web/status/1323183313914261505',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [105, 128]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 774550615204790272,
#       'id_str': '774550615204790272',
#       'name': 'Sourabh Singh Katoch',
#       'screen_name': 'SourabhSKatoch',
#       'location': 'New Delhi, India',
#       'description': 'Data Scientist | Machine Learning Engineer\n\nWrites about AI Research, Data Science, Python Programming & Development. Educator, Open Source advocate & memer.',
#       'url': None,
#       'entities': {'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 11272,
#       'friends_count': 11759,
#       'listed_count': 37,
#       'created_at': 'Sat Sep 10 10:10:32 +0000 2016',
#       'favourites_count': 293,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 714,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F5F8FA',
#       'profile_background_image_url': None,
#       'profile_background_image_url_https': None,
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1250501846709334017/WU0jzEqi_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250501846709334017/WU0jzEqi_normal.jpg',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': True,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 129,
#      'favorite_count': 52,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 129,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    {'created_at': 'Sat Nov 07 04:15:59 +0000 2020',
#     'id': 1324928562575470592,
#     'id_str': '1324928562575470592',
#     'text': 'RT @SourabhSKatoch: 5 Practical tips for data aggregation in pandas.\n\nhttps://t.co/VSwHAyZdkM\n\n#Python #MachineLearning #AI #100DaysOfCode…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [95, 102]},
#       {'text': 'MachineLearning', 'indices': [103, 119]},
#       {'text': 'AI', 'indices': [120, 123]},
#       {'text': '100DaysOfCode', 'indices': [124, 138]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'SourabhSKatoch',
#        'name': 'Sourabh Singh Katoch',
#        'id': 774550615204790272,
#        'id_str': '774550615204790272',
#        'indices': [3, 18]}],
#      'urls': [{'url': 'https://t.co/VSwHAyZdkM',
#        'expanded_url': 'https://towardsdatascience.com/5-tips-for-data-aggregation-in-pandas-7eaa8476dc75',
#        'display_url': 'towardsdatascience.com/5-tips-for-dat…',
#        'indices': [70, 93]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1214387835181993984,
#      'id_str': '1214387835181993984',
#      'name': 'PyxBot',
#      'screen_name': 'codex_bot',
#      'location': '',
#      'description': 'Tweet with #python \nCreator id @_TripathiJi',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 44,
#      'friends_count': 2,
#      'listed_count': 3,
#      'created_at': 'Tue Jan 07 03:26:46 +0000 2020',
#      'favourites_count': 112,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 2138,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1322384191477096449/93Vt5Zkr_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1322384191477096449/93Vt5Zkr_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Nov 02 08:41:00 +0000 2020',
#      'id': 1323183313914261505,
#      'id_str': '1323183313914261505',
#      'text': '5 Practical tips for data aggregation in pandas.\n\nhttps://t.co/VSwHAyZdkM\n\n#Python #MachineLearning #AI… https://t.co/Jhu1CcBVyW',
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'Python', 'indices': [75, 82]},
#        {'text': 'MachineLearning', 'indices': [83, 99]},
#        {'text': 'AI', 'indices': [100, 103]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/VSwHAyZdkM',
#         'expanded_url': 'https://towardsdatascience.com/5-tips-for-data-aggregation-in-pandas-7eaa8476dc75',
#         'display_url': 'towardsdatascience.com/5-tips-for-dat…',
#         'indices': [50, 73]},
#        {'url': 'https://t.co/Jhu1CcBVyW',
#         'expanded_url': 'https://twitter.com/i/web/status/1323183313914261505',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [105, 128]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 774550615204790272,
#       'id_str': '774550615204790272',
#       'name': 'Sourabh Singh Katoch',
#       'screen_name': 'SourabhSKatoch',
#       'location': 'New Delhi, India',
#       'description': 'Data Scientist | Machine Learning Engineer\n\nWrites about AI Research, Data Science, Python Programming & Development. Educator, Open Source advocate & memer.',
#       'url': None,
#       'entities': {'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 11272,
#       'friends_count': 11759,
#       'listed_count': 37,
#       'created_at': 'Sat Sep 10 10:10:32 +0000 2016',
#       'favourites_count': 293,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 714,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F5F8FA',
#       'profile_background_image_url': None,
#       'profile_background_image_url_https': None,
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1250501846709334017/WU0jzEqi_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250501846709334017/WU0jzEqi_normal.jpg',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': True,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 129,
#      'favorite_count': 52,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 129,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    {'created_at': 'Sat Nov 07 04:15:54 +0000 2020',
#     'id': 1324928539003678720,
#     'id_str': '1324928539003678720',
#     'text': 'RT @javinpaul: 6 Best Python Books for Data Science and Machine Learning in 2021\n\n#Python #dataScience #machinelearning #books https://t.co…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [82, 89]},
#       {'text': 'dataScience', 'indices': [90, 102]},
#       {'text': 'machinelearning', 'indices': [103, 119]},
#       {'text': 'books', 'indices': [120, 126]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'javinpaul',
#        'name': 'javinpaul',
#        'id': 206645598,
#        'id_str': '206645598',
#        'indices': [3, 13]}],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 990619007639224321,
#      'id_str': '990619007639224321',
#      'name': 'F.',
#      'screen_name': 'utyman',
#      'location': 'Buenos Aires, Argentina',
#      'description': '',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 72,
#      'friends_count': 966,
#      'listed_count': 0,
#      'created_at': 'Sun Apr 29 15:49:11 +0000 2018',
#      'favourites_count': 2247,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 2527,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1213886152807190528/BzXMePU8_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1213886152807190528/BzXMePU8_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/990619007639224321/1578248106',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Fri Nov 06 15:14:40 +0000 2020',
#      'id': 1324731935915061250,
#      'id_str': '1324731935915061250',
#      'text': '6 Best Python Books for Data Science and Machine Learning in 2021\n\n#Python #dataScience #machinelearning #books https://t.co/u7wxFSYmF2',
#      'truncated': False,
#      'entities': {'hashtags': [{'text': 'Python', 'indices': [67, 74]},
#        {'text': 'dataScience', 'indices': [75, 87]},
#        {'text': 'machinelearning', 'indices': [88, 104]},
#        {'text': 'books', 'indices': [105, 111]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/u7wxFSYmF2',
#         'expanded_url': 'https://lnkd.in/gqSUNcF',
#         'display_url': 'lnkd.in/gqSUNcF',
#         'indices': [112, 135]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 206645598,
#       'id_str': '206645598',
#       'name': 'javinpaul',
#       'screen_name': 'javinpaul',
#       'location': 'New York, USA',
#       'description': 'Java Programmer and blogger, write at @javarevisited @Medium @Hackernoon @DzoneInc @ https://t.co/O6fEbEDQrZ about #Java #Programming, #Spring #algorithms #courses #books',
#       'url': 'https://t.co/tRpvhBWMLw',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/tRpvhBWMLw',
#           'expanded_url': 'http://javarevisited.blogspot.com',
#           'display_url': 'javarevisited.blogspot.com',
#           'indices': [0, 23]}]},
#        'description': {'urls': [{'url': 'https://t.co/O6fEbEDQrZ',
#           'expanded_url': 'http://java67.com',
#           'display_url': 'java67.com',
#           'indices': [85, 108]}]}},
#       'protected': False,
#       'followers_count': 26112,
#       'friends_count': 7875,
#       'listed_count': 734,
#       'created_at': 'Sat Oct 23 12:04:02 +0000 2010',
#       'favourites_count': 12597,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 41131,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': '642D8B',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#       'profile_background_tile': True,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1114805556370231296/TJSKV7LD_normal.png',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1114805556370231296/TJSKV7LD_normal.png',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/206645598/1554625443',
#       'profile_link_color': '19CF86',
#       'profile_sidebar_border_color': 'FFFFFF',
#       'profile_sidebar_fill_color': '7AC3EE',
#       'profile_text_color': '3D1957',
#       'profile_use_background_image': True,
#       'has_extended_profile': True,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 12,
#      'favorite_count': 9,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 12,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    {'created_at': 'Sat Nov 07 04:15:49 +0000 2020',
#     'id': 1324928517453217792,
#     'id_str': '1324928517453217792',
#     'text': 'RT @gp_pulipaka: Solving a Few AI Problems with Python: Part 1. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT #Python #R…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [64, 72]},
#       {'text': 'Analytics', 'indices': [73, 83]},
#       {'text': 'DataScience', 'indices': [84, 96]},
#       {'text': 'AI', 'indices': [97, 100]},
#       {'text': 'MachineLearning', 'indices': [101, 117]},
#       {'text': 'IoT', 'indices': [118, 122]},
#       {'text': 'IIoT', 'indices': [123, 128]},
#       {'text': 'Python', 'indices': [129, 136]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'gp_pulipaka',
#        'name': 'Dr. Ganapathi Pulipaka',
#        'id': 4263007693,
#        'id_str': '4263007693',
#        'indices': [3, 15]}],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1196532080730992640,
#      'id_str': '1196532080730992640',
#      'name': 'Jesse Larson',
#      'screen_name': 'EVinlund',
#      'location': 'vinlund, terra1, 🌟',
#      'description': '🔰Terranaut Commander.       \n🌌 Hyperspace Commerce  📖explorer manifest 👽🇨🇦🙊☠️ Jesse Larson, Bad human EleonifVinland .. LevEdelsteinU .. Stroika magazine',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 38,
#      'friends_count': 182,
#      'listed_count': 0,
#      'created_at': 'Mon Nov 18 20:54:23 +0000 2019',
#      'favourites_count': 7097,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 6720,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1291881759932477441/fyZ7XMN1_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1291881759932477441/fyZ7XMN1_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1196532080730992640/1596842728',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sat Nov 07 02:52:04 +0000 2020',
#      'id': 1324907443776851969,
#      'id_str': '1324907443776851969',
#      'text': 'Solving a Few AI Problems with Python: Part 1. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT… https://t.co/FLC6mNBZsq',
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'BigData', 'indices': [47, 55]},
#        {'text': 'Analytics', 'indices': [56, 66]},
#        {'text': 'DataScience', 'indices': [67, 79]},
#        {'text': 'AI', 'indices': [80, 83]},
#        {'text': 'MachineLearning', 'indices': [84, 100]},
#        {'text': 'IoT', 'indices': [101, 105]},
#        {'text': 'IIoT', 'indices': [106, 111]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/FLC6mNBZsq',
#         'expanded_url': 'https://twitter.com/i/web/status/1324907443776851969',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [113, 136]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 4263007693,
#       'id_str': '4263007693',
#       'name': 'Dr. Ganapathi Pulipaka',
#       'screen_name': 'gp_pulipaka',
#       'location': 'Redondo Beach, CA',
#       'description': 'Chief #AI #HPC Scientist | #Speaker | PostDoc CS, PhD | Bestselling #Author | 18.4M V | Top #BigData #DataScience #MachineLearning #IIoT Influencer @Onalytica',
#       'url': 'https://t.co/eYyaJsEcfw',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/eYyaJsEcfw',
#           'expanded_url': 'http://www.gppulipaka.org',
#           'display_url': 'gppulipaka.org',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 101866,
#       'friends_count': 25851,
#       'listed_count': 3510,
#       'created_at': 'Tue Nov 17 02:19:09 +0000 2015',
#       'favourites_count': 9,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'verified': False,
#       'statuses_count': 58791,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': '000000',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4263007693/1604252016',
#       'profile_link_color': 'DD2E44',
#       'profile_sidebar_border_color': '000000',
#       'profile_sidebar_fill_color': '000000',
#       'profile_text_color': '000000',
#       'profile_use_background_image': False,
#       'has_extended_profile': True,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 37,
#      'favorite_count': 41,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 37,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    {'created_at': 'Sat Nov 07 04:15:47 +0000 2020',
#     'id': 1324928509676974081,
#     'id_str': '1324928509676974081',
#     'text': 'RT @DD_NaNa_: Agile Data Science 2.0: Building Full-Stack Data Analytics Applications with Spark https://t.co/Fd0UFAsVK4 #DataScience #Agile',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'DataScience', 'indices': [121, 133]},
#       {'text': 'Agile', 'indices': [134, 140]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'DD_NaNa_',
#        'name': 'nana🦄',
#        'id': 2782310810,
#        'id_str': '2782310810',
#        'indices': [3, 12]}],
#      'urls': [{'url': 'https://t.co/Fd0UFAsVK4',
#        'expanded_url': 'https://amzn.to/2kZnh6f',
#        'display_url': 'amzn.to/2kZnh6f',
#        'indices': [97, 120]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://twitter.com/bungobot1" rel="nofollow">AIBungoBot</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1246850580191907840,
#      'id_str': '1246850580191907840',
#      'name': 'like and retweet Bot',
#      'screen_name': 'bungobot1',
#      'location': 'In your book',
#      'description': "Created by @ArchieSakai\n\nI like and retweet your tweet, if you follow me.\nHowever, sometimes I can't do it all because of the api request limit.",
#      'url': 'https://t.co/rO8R4H2IrC',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/rO8R4H2IrC',
#          'expanded_url': 'https://soarhap.com/',
#          'display_url': 'soarhap.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 195,
#      'friends_count': 1,
#      'listed_count': 5,
#      'created_at': 'Sun Apr 05 17:22:06 +0000 2020',
#      'favourites_count': 64796,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 65379,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1246850684932124672/0dcXfai7_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1246850684932124672/0dcXfai7_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1246850580191907840/1586107440',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sat Nov 07 04:07:24 +0000 2020',
#      'id': 1324926402349555714,
#      'id_str': '1324926402349555714',
#      'text': 'Agile Data Science 2.0: Building Full-Stack Data Analytics Applications with Spark https://t.co/Fd0UFAsVK4 #DataScience #Agile',
#      'truncated': False,
#      'entities': {'hashtags': [{'text': 'DataScience', 'indices': [107, 119]},
#        {'text': 'Agile', 'indices': [120, 126]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/Fd0UFAsVK4',
# ...
#       'url': 'https://t.co/eYyaJsEcfw',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/eYyaJsEcfw',
#           'expanded_url': 'http://www.gppulipaka.org',
#           'display_url': 'gppulipaka.org',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 101866,
#       'friends_count': 25851,
#       'listed_count': 3510,
#       'created_at': 'Tue Nov 17 02:19:09 +0000 2015',
#       'favourites_count': 9,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'verified': False,
#       'statuses_count': 58791,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': '000000',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4263007693/1604252016',
#       'profile_link_color': 'DD2E44',
#       'profile_sidebar_border_color': '000000',
#       'profile_sidebar_fill_color': '000000',
#       'profile_text_color': '000000',
#       'profile_use_background_image': False,
#       'has_extended_profile': True,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 61,
#      'favorite_count': 39,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 61,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    {'created_at': 'Sat Nov 07 04:15:04 +0000 2020',
#     'id': 1324928329703698433,
#     'id_str': '1324928329703698433',
#     'text': 'RT @AMAnalytic: Setting Better OKRs Getting Better Results\n#artificialintelligence #AI #machinelearning #ML #datascience #bigdata #analytic…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'artificialintelligence',
#        'indices': [59, 82]},
#       {'text': 'AI', 'indices': [83, 86]},
#       {'text': 'machinelearning', 'indices': [87, 103]},
#       {'text': 'ML', 'indices': [104, 107]},
#       {'text': 'datascience', 'indices': [108, 120]},
#       {'text': 'bigdata', 'indices': [121, 129]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'AMAnalytic',
#        'name': 'Analytics-AM',
#        'id': 1319665167609847813,
#        'id_str': '1319665167609847813',
#        'indices': [3, 14]}],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://curiousluke.com" rel="nofollow">RTML</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1064108650271309826,
#      'id_str': '1064108650271309826',
#      'name': 'Curious Luke',
#      'screen_name': 'TheCuriousLuke',
#      'location': 'Switzerland',
#      'description': 'Luke identifies himself as a: #ACLS #Masterstudent @zhaw ¦ #Biotechnologist ¦ former #Chemical #Labtechnician 👨\u200d🔬 ¦ #Human',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 5557,
#      'friends_count': 260,
#      'listed_count': 155,
#      'created_at': 'Sun Nov 18 10:50:47 +0000 2018',
#      'favourites_count': 82,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 252135,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1146772070547841024/u1aKb70M_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1146772070547841024/u1aKb70M_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1064108650271309826/1542538859',
#      'profile_link_color': '00D620',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sat Nov 07 04:13:50 +0000 2020',
#      'id': 1324928021455900673,
#      'id_str': '1324928021455900673',
#      'text': 'Setting Better OKRs Getting Better Results\n#artificialintelligence #AI #machinelearning #ML #datascience #bigdata… https://t.co/Z40fKgpyby',
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'artificialintelligence',
#         'indices': [43, 66]},
#        {'text': 'AI', 'indices': [67, 70]},
#        {'text': 'machinelearning', 'indices': [71, 87]},
#        {'text': 'ML', 'indices': [88, 91]},
#        {'text': 'datascience', 'indices': [92, 104]},
#        {'text': 'bigdata', 'indices': [105, 113]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/Z40fKgpyby',
#         'expanded_url': 'https://twitter.com/i/web/status/1324928021455900673',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [115, 138]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 1319665167609847813,
#       'id_str': '1319665167609847813',
#       'name': 'Analytics-AM',
#       'screen_name': 'AMAnalytic',
#       'location': '',
#       'description': '',
#       'url': None,
#       'entities': {'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 19,
#       'friends_count': 207,
#       'listed_count': 0,
#       'created_at': 'Fri Oct 23 15:41:17 +0000 2020',
#       'favourites_count': 0,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 35,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F5F8FA',
#       'profile_background_image_url': None,
#       'profile_background_image_url_https': None,
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1320812076206534656/s5Ptn5un_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1320812076206534656/s5Ptn5un_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1319665167609847813/1603467774',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': True,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 2,
#      'favorite_count': 0,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    {'created_at': 'Sat Nov 07 04:15:03 +0000 2020',
#     'id': 1324928327518482432,
#     'id_str': '1324928327518482432',
#     'text': 'RT @gp_pulipaka: Baidu Apollo Releases Massive Self-driving Dataset. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT #Pyth…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [69, 77]},
#       {'text': 'Analytics', 'indices': [78, 88]},
#       {'text': 'DataScience', 'indices': [89, 101]},
#       {'text': 'AI', 'indices': [102, 105]},
#       {'text': 'MachineLearning', 'indices': [106, 122]},
#       {'text': 'IoT', 'indices': [123, 127]},
#       {'text': 'IIoT', 'indices': [128, 133]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'gp_pulipaka',
#        'name': 'Dr. Ganapathi Pulipaka',
#        'id': 4263007693,
#        'id_str': '4263007693',
#        'indices': [3, 15]}],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 968746494462394369,
#      'id_str': '968746494462394369',
#      'name': 'Epistimologist',
#      'screen_name': 'aikida3k',
#      'location': '',
#      'description': '',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 40,
#      'friends_count': 337,
#      'listed_count': 0,
#      'created_at': 'Wed Feb 28 07:15:37 +0000 2018',
#      'favourites_count': 4852,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 1622,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1109629559245336576/ec8m4XBE_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1109629559245336576/ec8m4XBE_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/968746494462394369/1520232203',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sat Nov 07 03:35:15 +0000 2020',
#      'id': 1324918309708574727,
#      'id_str': '1324918309708574727',
#      'text': 'Baidu Apollo Releases Massive Self-driving Dataset. #BigData #Analytics #DataScience #AI #MachineLearning #IoT… https://t.co/eAjSSG2W6E',
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'BigData', 'indices': [52, 60]},
#        {'text': 'Analytics', 'indices': [61, 71]},
#        {'text': 'DataScience', 'indices': [72, 84]},
#        {'text': 'AI', 'indices': [85, 88]},
#        {'text': 'MachineLearning', 'indices': [89, 105]},
#        {'text': 'IoT', 'indices': [106, 110]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/eAjSSG2W6E',
#         'expanded_url': 'https://twitter.com/i/web/status/1324918309708574727',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [112, 135]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 4263007693,
#       'id_str': '4263007693',
#       'name': 'Dr. Ganapathi Pulipaka',
#       'screen_name': 'gp_pulipaka',
#       'location': 'Redondo Beach, CA',
#       'description': 'Chief #AI #HPC Scientist | #Speaker | PostDoc CS, PhD | Bestselling #Author | 18.4M V | Top #BigData #DataScience #MachineLearning #IIoT Influencer @Onalytica',
#       'url': 'https://t.co/eYyaJsEcfw',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/eYyaJsEcfw',
#           'expanded_url': 'http://www.gppulipaka.org',
#           'display_url': 'gppulipaka.org',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 101866,
#       'friends_count': 25851,
#       'listed_count': 3510,
#       'created_at': 'Tue Nov 17 02:19:09 +0000 2015',
#       'favourites_count': 9,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'verified': False,
#       'statuses_count': 58791,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': '000000',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4263007693/1604252016',
#       'profile_link_color': 'DD2E44',
#       'profile_sidebar_border_color': '000000',
#       'profile_sidebar_fill_color': '000000',
#       'profile_text_color': '000000',
#       'profile_use_background_image': False,
#       'has_extended_profile': True,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 35,
#      'favorite_count': 21,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 35,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'}],
#   'search_metadata': {'completed_in': 0.095,
#    'max_id': 1324928585577029632,
#    'max_id_str': '1324928585577029632',
#    'next_results': '?max_id=1324474320643629058&q=%23datascience&count=20&include_entities=1&result_type=mixed',
#    'query': '%23datascience',
#    'refresh_url': '?since_id=1324928585577029632&q=%23datascience&result_type=mixed&include_entities=1',
#    'count': 20,
#    'since_id': 0,
#    'since_id_str': '0'}}]

# %%
example3
# Out:
# [{'statuses': [{'created_at': 'Thu Nov 05 22:11:00 +0000 2020',
#     'id': 1324474320643629059,
#     'id_str': '1324474320643629059',
#     'text': "10-page [PDF] reference covers a semester's worth of introductory probability — The best #Probability Cheat Sheet t… https://t.co/gmlAaTGpgN",
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Probability', 'indices': [89, 101]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/gmlAaTGpgN',
#        'expanded_url': 'https://twitter.com/i/web/status/1324474320643629059',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 534563976,
#      'id_str': '534563976',
#      'name': 'Kirk Borne',
#      'screen_name': 'KirkDBorne',
#      'location': 'Maryland, USA',
#      'description': 'Principal Data Scientist @BoozAllen. Global Speaker. Top #BigData #DataScience #AI Influencer. PhD Astrophysicist. (Views = my own) https://t.co/abP8DkYJY2 📊🔭',
#      'url': 'https://t.co/tWlmeuTlR7',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/tWlmeuTlR7',
#          'expanded_url': 'http://www.linkedin.com/in/kirkdborne',
#          'display_url': 'linkedin.com/in/kirkdborne',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/abP8DkYJY2',
#          'expanded_url': 'http://rocketdatascience.org',
#          'display_url': 'rocketdatascience.org',
#          'indices': [132, 155]}]}},
#      'protected': False,
#      'followers_count': 271146,
#      'friends_count': 9822,
#      'listed_count': 8186,
#      'created_at': 'Fri Mar 23 16:35:17 +0000 2012',
#      'favourites_count': 205552,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 127450,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/534563976/1590790599',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 286,
#     'favorite_count': 1104,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    {'created_at': 'Fri Nov 06 09:00:32 +0000 2020',
#     'id': 1324637783575552000,
#     'id_str': '1324637783575552000',
#     'text': 'Thank you Team Jio Institute for the Masterclass on #ArtificialIntelligence &amp; #DataScience (Design Thinking as a St… https://t.co/5fepOfFNw8',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'ArtificialIntelligence',
#        'indices': [52, 75]},
#       {'text': 'DataScience', 'indices': [82, 94]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/5fepOfFNw8',
#        'expanded_url': 'https://twitter.com/i/web/status/1324637783575552000',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [121, 144]}]},
#     'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 215224249,
#      'id_str': '215224249',
#      'name': 'Rohit Bansal 🇮🇳',
#      'screen_name': 'theRohitBansal',
#      'location': 'India',
#      'description': 'Story Teller: RIL|Jio|JioGenNext| Alum: Harvard|Stephens|DPS RKP|ORF|TEDx|FE|TOI|TV18|Zee|Chevening|EUVP|Tweets MINE| Purpose 🇮🇳📱🐯',
#      'url': 'https://t.co/8pL1uz2KJD',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/8pL1uz2KJD',
#          'expanded_url': 'http://instagram.com/therohitbansal99',
#          'display_url': 'instagram.com/therohitbansal…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 26351,
#      'friends_count': 1509,
#      'listed_count': 166,
#      'created_at': 'Sat Nov 13 10:03:16 +0000 2010',
#      'favourites_count': 6915,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 52636,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FC0A2A',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1139950873482678272/SpdqsG9E_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1139950873482678272/SpdqsG9E_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/215224249/1592328670',
#      'profile_link_color': 'DD2E44',
#      'profile_sidebar_border_color': 'F2E195',
#      'profile_sidebar_fill_color': 'FFF7CC',
#      'profile_text_color': '0C3E53',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 100,
#     'favorite_count': 107,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    {'created_at': 'Fri Nov 06 01:38:00 +0000 2020',
#     'id': 1324526413794430976,
#     'id_str': '1324526413794430976',
#     'text': '[UPDATED Free PDF]\n#DataScience Cheat Sheet covers concepts in Statistical Learning, #MachineLearning,… https://t.co/i5cP5Fxj05',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DataScience', 'indices': [19, 31]},
#       {'text': 'MachineLearning', 'indices': [85, 101]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/i5cP5Fxj05',
#        'expanded_url': 'https://twitter.com/i/web/status/1324526413794430976',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [104, 127]}]},
#     'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 534563976,
#      'id_str': '534563976',
#      'name': 'Kirk Borne',
#      'screen_name': 'KirkDBorne',
#      'location': 'Maryland, USA',
#      'description': 'Principal Data Scientist @BoozAllen. Global Speaker. Top #BigData #DataScience #AI Influencer. PhD Astrophysicist. (Views = my own) https://t.co/abP8DkYJY2 📊🔭',
#      'url': 'https://t.co/tWlmeuTlR7',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/tWlmeuTlR7',
#          'expanded_url': 'http://www.linkedin.com/in/kirkdborne',
#          'display_url': 'linkedin.com/in/kirkdborne',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/abP8DkYJY2',
#          'expanded_url': 'http://rocketdatascience.org',
#          'display_url': 'rocketdatascience.org',
#          'indices': [132, 155]}]}},
#      'protected': False,
#      'followers_count': 271146,
#      'friends_count': 9822,
#      'listed_count': 8186,
#      'created_at': 'Fri Mar 23 16:35:17 +0000 2012',
#      'favourites_count': 205552,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 127450,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/534563976/1590790599',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 127,
#     'favorite_count': 391,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    {'created_at': 'Sat Nov 07 04:16:05 +0000 2020',
#     'id': 1324928585577029632,
#     'id_str': '1324928585577029632',
#     'text': 'RT @SourabhSKatoch: 5 Practical tips for data aggregation in pandas.\n\nhttps://t.co/VSwHAyZdkM\n\n#Python #MachineLearning #AI #100DaysOfCode…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [95, 102]},
#       {'text': 'MachineLearning', 'indices': [103, 119]},
#       {'text': 'AI', 'indices': [120, 123]},
#       {'text': '100DaysOfCode', 'indices': [124, 138]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'SourabhSKatoch',
#        'name': 'Sourabh Singh Katoch',
#        'id': 774550615204790272,
#        'id_str': '774550615204790272',
#        'indices': [3, 18]}],
#      'urls': [{'url': 'https://t.co/VSwHAyZdkM',
#        'expanded_url': 'https://towardsdatascience.com/5-tips-for-data-aggregation-in-pandas-7eaa8476dc75',
#        'display_url': 'towardsdatascience.com/5-tips-for-dat…',
#        'indices': [70, 93]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.me/siddharth_bisht" rel="nofollow">friday_the_bot</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1278273884903505921,
#      'id_str': '1278273884903505921',
#      'name': 'Friday',
#      'screen_name': 'friday_Js_bot',
#      'location': '',
#      'description': 'I am a bot, I retweet everything on #javascript, #typescript and #NodeJs. Created by @SidDarthVader31\nDM me hello for fun,\nDM me follow to get a follow back :-)',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 891,
#      'friends_count': 37,
#      'listed_count': 30,
#      'created_at': 'Wed Jul 01 10:27:05 +0000 2020',
#      'favourites_count': 5,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 206174,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1278275454525267970/MhuXITC3_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1278275454525267970/MhuXITC3_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1278273884903505921/1593599659',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Nov 02 08:41:00 +0000 2020',
#      'id': 1323183313914261505,
#      'id_str': '1323183313914261505',
#      'text': '5 Practical tips for data aggregation in pandas.\n\nhttps://t.co/VSwHAyZdkM\n\n#Python #MachineLearning #AI… https://t.co/Jhu1CcBVyW',
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'Python', 'indices': [75, 82]},
#        {'text': 'MachineLearning', 'indices': [83, 99]},
#        {'text': 'AI', 'indices': [100, 103]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/VSwHAyZdkM',
#         'expanded_url': 'https://towardsdatascience.com/5-tips-for-data-aggregation-in-pandas-7eaa8476dc75',
#         'display_url': 'towardsdatascience.com/5-tips-for-dat…',
#         'indices': [50, 73]},
#        {'url': 'https://t.co/Jhu1CcBVyW',
#         'expanded_url': 'https://twitter.com/i/web/status/1323183313914261505',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [105, 128]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 774550615204790272,
#       'id_str': '774550615204790272',
#       'name': 'Sourabh Singh Katoch',
#       'screen_name': 'SourabhSKatoch',
#       'location': 'New Delhi, India',
#       'description': 'Data Scientist | Machine Learning Engineer\n\nWrites about AI Research, Data Science, Python Programming & Development. Educator, Open Source advocate & memer.',
#       'url': None,
#       'entities': {'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 11272,
#       'friends_count': 11759,
#       'listed_count': 37,
#       'created_at': 'Sat Sep 10 10:10:32 +0000 2016',
#       'favourites_count': 293,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 714,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F5F8FA',
#       'profile_background_image_url': None,
#       'profile_background_image_url_https': None,
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1250501846709334017/WU0jzEqi_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250501846709334017/WU0jzEqi_normal.jpg',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': True,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 129,
#      'favorite_count': 52,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 129,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    {'created_at': 'Sat Nov 07 04:16:05 +0000 2020',
#     'id': 1324928585308758017,
#     'id_str': '1324928585308758017',
#     'text': 'RT @SourabhSKatoch: 5 Practical tips for data aggregation in pandas.\n\nhttps://t.co/VSwHAyZdkM\n\n#Python #MachineLearning #AI #100DaysOfCode…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [95, 102]},
#       {'text': 'MachineLearning', 'indices': [103, 119]},
#       {'text': 'AI', 'indices': [120, 123]},
#       {'text': '100DaysOfCode', 'indices': [124, 138]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'SourabhSKatoch',
#        'name': 'Sourabh Singh Katoch',
#        'id': 774550615204790272,
#        'id_str': '774550615204790272',
#        'indices': [3, 18]}],
#      'urls': [{'url': 'https://t.co/VSwHAyZdkM',
#        'expanded_url': 'https://towardsdatascience.com/5-tips-for-data-aggregation-in-pandas-7eaa8476dc75',
#        'display_url': 'towardsdatascience.com/5-tips-for-dat…',
#        'indices': [70, 93]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://nlogn.in" rel="nofollow">nlognrobot</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1260062769543434240,
#      'id_str': '1260062769543434240',
#      'name': '#100DaysOfCode',
#      'screen_name': 'nlognbot',
#      'location': 'Server',
#      'description': "Hi, I'm a bot that retweets #100daysofcode     \n                 \nP.S. I was created by @NlognHQ follow them.",
#      'url': 'https://t.co/PujHDQomPA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/PujHDQomPA',
#          'expanded_url': 'http://nlogn.in',
#          'display_url': 'nlogn.in',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4654,
#      'friends_count': 3,
#      'listed_count': 52,
#      'created_at': 'Tue May 12 04:22:53 +0000 2020',
#      'favourites_count': 807,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 391397,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1306825824104898560/F1I_GcS1_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1306825824104898560/F1I_GcS1_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1260062769543434240/1593858684',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Nov 02 08:41:00 +0000 2020',
#      'id': 1323183313914261505,
#      'id_str': '1323183313914261505',
#      'text': '5 Practical tips for data aggregation in pandas.\n\nhttps://t.co/VSwHAyZdkM\n\n#Python #MachineLearning #AI… https://t.co/Jhu1CcBVyW',
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'Python', 'indices': [75, 82]},
#        {'text': 'MachineLearning', 'indices': [83, 99]},
#        {'text': 'AI', 'indices': [100, 103]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/VSwHAyZdkM',
#         'expanded_url': 'https://towardsdatascience.com/5-tips-for-data-aggregation-in-pandas-7eaa8476dc75',
#         'display_url': 'towardsdatascience.com/5-tips-for-dat…',
#         'indices': [50, 73]},
#        {'url': 'https://t.co/Jhu1CcBVyW',
#         'expanded_url': 'https://twitter.com/i/web/status/1323183313914261505',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [105, 128]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 774550615204790272,
#       'id_str': '774550615204790272',
#       'name': 'Sourabh Singh Katoch',
#       'screen_name': 'SourabhSKatoch',
#       'location': 'New Delhi, India',
#       'description': 'Data Scientist | Machine Learning Engineer\n\nWrites about AI Research, Data Science, Python Programming & Development. Educator, Open Source advocate & memer.',
#       'url': None,
#       'entities': {'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 11272,
#       'friends_count': 11759,
#       'listed_count': 37,
#       'created_at': 'Sat Sep 10 10:10:32 +0000 2016',
#       'favourites_count': 293,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 714,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F5F8FA',
#       'profile_background_image_url': None,
#       'profile_background_image_url_https': None,
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1250501846709334017/WU0jzEqi_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250501846709334017/WU0jzEqi_normal.jpg',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': True,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 129,
#      'favorite_count': 52,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 129,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    {'created_at': 'Sat Nov 07 04:15:59 +0000 2020',
#     'id': 1324928562575470592,
#     'id_str': '1324928562575470592',
#     'text': 'RT @SourabhSKatoch: 5 Practical tips for data aggregation in pandas.\n\nhttps://t.co/VSwHAyZdkM\n\n#Python #MachineLearning #AI #100DaysOfCode…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [95, 102]},
#       {'text': 'MachineLearning', 'indices': [103, 119]},
#       {'text': 'AI', 'indices': [120, 123]},
#       {'text': '100DaysOfCode', 'indices': [124, 138]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'SourabhSKatoch',
#        'name': 'Sourabh Singh Katoch',
#        'id': 774550615204790272,
#        'id_str': '774550615204790272',
#        'indices': [3, 18]}],
#      'urls': [{'url': 'https://t.co/VSwHAyZdkM',
#        'expanded_url': 'https://towardsdatascience.com/5-tips-for-data-aggregation-in-pandas-7eaa8476dc75',
#        'display_url': 'towardsdatascience.com/5-tips-for-dat…',
#        'indices': [70, 93]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1214387835181993984,
#      'id_str': '1214387835181993984',
#      'name': 'PyxBot',
#      'screen_name': 'codex_bot',
#      'location': '',
#      'description': 'Tweet with #python \nCreator id @_TripathiJi',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 44,
#      'friends_count': 2,
#      'listed_count': 3,
#      'created_at': 'Tue Jan 07 03:26:46 +0000 2020',
#      'favourites_count': 112,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 2138,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1322384191477096449/93Vt5Zkr_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1322384191477096449/93Vt5Zkr_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Mon Nov 02 08:41:00 +0000 2020',
#      'id': 1323183313914261505,
#      'id_str': '1323183313914261505',
#      'text': '5 Practical tips for data aggregation in pandas.\n\nhttps://t.co/VSwHAyZdkM\n\n#Python #MachineLearning #AI… https://t.co/Jhu1CcBVyW',
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'Python', 'indices': [75, 82]},
#        {'text': 'MachineLearning', 'indices': [83, 99]},
#        {'text': 'AI', 'indices': [100, 103]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/VSwHAyZdkM',
#         'expanded_url': 'https://towardsdatascience.com/5-tips-for-data-aggregation-in-pandas-7eaa8476dc75',
#         'display_url': 'towardsdatascience.com/5-tips-for-dat…',
#         'indices': [50, 73]},
#        {'url': 'https://t.co/Jhu1CcBVyW',
#         'expanded_url': 'https://twitter.com/i/web/status/1323183313914261505',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [105, 128]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 774550615204790272,
#       'id_str': '774550615204790272',
#       'name': 'Sourabh Singh Katoch',
#       'screen_name': 'SourabhSKatoch',
#       'location': 'New Delhi, India',
#       'description': 'Data Scientist | Machine Learning Engineer\n\nWrites about AI Research, Data Science, Python Programming & Development. Educator, Open Source advocate & memer.',
#       'url': None,
#       'entities': {'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 11272,
#       'friends_count': 11759,
#       'listed_count': 37,
#       'created_at': 'Sat Sep 10 10:10:32 +0000 2016',
#       'favourites_count': 293,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 714,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F5F8FA',
#       'profile_background_image_url': None,
#       'profile_background_image_url_https': None,
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1250501846709334017/WU0jzEqi_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250501846709334017/WU0jzEqi_normal.jpg',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': True,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 129,
#      'favorite_count': 52,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 129,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    {'created_at': 'Sat Nov 07 04:15:54 +0000 2020',
#     'id': 1324928539003678720,
#     'id_str': '1324928539003678720',
#     'text': 'RT @javinpaul: 6 Best Python Books for Data Science and Machine Learning in 2021\n\n#Python #dataScience #machinelearning #books https://t.co…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'Python', 'indices': [82, 89]},
#       {'text': 'dataScience', 'indices': [90, 102]},
#       {'text': 'machinelearning', 'indices': [103, 119]},
#       {'text': 'books', 'indices': [120, 126]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'javinpaul',
#        'name': 'javinpaul',
#        'id': 206645598,
#        'id_str': '206645598',
#        'indices': [3, 13]}],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 990619007639224321,
#      'id_str': '990619007639224321',
#      'name': 'F.',
#      'screen_name': 'utyman',
#      'location': 'Buenos Aires, Argentina',
#      'description': '',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 72,
#      'friends_count': 966,
#      'listed_count': 0,
#      'created_at': 'Sun Apr 29 15:49:11 +0000 2018',
#      'favourites_count': 2247,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 2527,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1213886152807190528/BzXMePU8_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1213886152807190528/BzXMePU8_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/990619007639224321/1578248106',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Fri Nov 06 15:14:40 +0000 2020',
#      'id': 1324731935915061250,
#      'id_str': '1324731935915061250',
#      'text': '6 Best Python Books for Data Science and Machine Learning in 2021\n\n#Python #dataScience #machinelearning #books https://t.co/u7wxFSYmF2',
#      'truncated': False,
#      'entities': {'hashtags': [{'text': 'Python', 'indices': [67, 74]},
#        {'text': 'dataScience', 'indices': [75, 87]},
#        {'text': 'machinelearning', 'indices': [88, 104]},
#        {'text': 'books', 'indices': [105, 111]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/u7wxFSYmF2',
#         'expanded_url': 'https://lnkd.in/gqSUNcF',
#         'display_url': 'lnkd.in/gqSUNcF',
#         'indices': [112, 135]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 206645598,
#       'id_str': '206645598',
#       'name': 'javinpaul',
#       'screen_name': 'javinpaul',
#       'location': 'New York, USA',
#       'description': 'Java Programmer and blogger, write at @javarevisited @Medium @Hackernoon @DzoneInc @ https://t.co/O6fEbEDQrZ about #Java #Programming, #Spring #algorithms #courses #books',
#       'url': 'https://t.co/tRpvhBWMLw',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/tRpvhBWMLw',
#           'expanded_url': 'http://javarevisited.blogspot.com',
#           'display_url': 'javarevisited.blogspot.com',
#           'indices': [0, 23]}]},
#        'description': {'urls': [{'url': 'https://t.co/O6fEbEDQrZ',
#           'expanded_url': 'http://java67.com',
#           'display_url': 'java67.com',
#           'indices': [85, 108]}]}},
#       'protected': False,
#       'followers_count': 26112,
#       'friends_count': 7875,
#       'listed_count': 734,
#       'created_at': 'Sat Oct 23 12:04:02 +0000 2010',
#       'favourites_count': 12597,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 41131,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': '642D8B',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#       'profile_background_tile': True,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1114805556370231296/TJSKV7LD_normal.png',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1114805556370231296/TJSKV7LD_normal.png',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/206645598/1554625443',
#       'profile_link_color': '19CF86',
#       'profile_sidebar_border_color': 'FFFFFF',
#       'profile_sidebar_fill_color': '7AC3EE',
#       'profile_text_color': '3D1957',
#       'profile_use_background_image': True,
#       'has_extended_profile': True,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 12,
#      'favorite_count': 9,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 12,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    {'created_at': 'Sat Nov 07 04:15:49 +0000 2020',
#     'id': 1324928517453217792,
#     'id_str': '1324928517453217792',
#     'text': 'RT @gp_pulipaka: Solving a Few AI Problems with Python: Part 1. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT #Python #R…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [64, 72]},
#       {'text': 'Analytics', 'indices': [73, 83]},
#       {'text': 'DataScience', 'indices': [84, 96]},
#       {'text': 'AI', 'indices': [97, 100]},
#       {'text': 'MachineLearning', 'indices': [101, 117]},
#       {'text': 'IoT', 'indices': [118, 122]},
#       {'text': 'IIoT', 'indices': [123, 128]},
#       {'text': 'Python', 'indices': [129, 136]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'gp_pulipaka',
#        'name': 'Dr. Ganapathi Pulipaka',
#        'id': 4263007693,
#        'id_str': '4263007693',
#        'indices': [3, 15]}],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1196532080730992640,
#      'id_str': '1196532080730992640',
#      'name': 'Jesse Larson',
#      'screen_name': 'EVinlund',
#      'location': 'vinlund, terra1, 🌟',
#      'description': '🔰Terranaut Commander.       \n🌌 Hyperspace Commerce  📖explorer manifest 👽🇨🇦🙊☠️ Jesse Larson, Bad human EleonifVinland .. LevEdelsteinU .. Stroika magazine',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 38,
#      'friends_count': 182,
#      'listed_count': 0,
#      'created_at': 'Mon Nov 18 20:54:23 +0000 2019',
#      'favourites_count': 7097,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 6720,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1291881759932477441/fyZ7XMN1_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1291881759932477441/fyZ7XMN1_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1196532080730992640/1596842728',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sat Nov 07 02:52:04 +0000 2020',
#      'id': 1324907443776851969,
#      'id_str': '1324907443776851969',
#      'text': 'Solving a Few AI Problems with Python: Part 1. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT… https://t.co/FLC6mNBZsq',
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'BigData', 'indices': [47, 55]},
#        {'text': 'Analytics', 'indices': [56, 66]},
#        {'text': 'DataScience', 'indices': [67, 79]},
#        {'text': 'AI', 'indices': [80, 83]},
#        {'text': 'MachineLearning', 'indices': [84, 100]},
#        {'text': 'IoT', 'indices': [101, 105]},
#        {'text': 'IIoT', 'indices': [106, 111]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/FLC6mNBZsq',
#         'expanded_url': 'https://twitter.com/i/web/status/1324907443776851969',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [113, 136]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 4263007693,
#       'id_str': '4263007693',
#       'name': 'Dr. Ganapathi Pulipaka',
#       'screen_name': 'gp_pulipaka',
#       'location': 'Redondo Beach, CA',
#       'description': 'Chief #AI #HPC Scientist | #Speaker | PostDoc CS, PhD | Bestselling #Author | 18.4M V | Top #BigData #DataScience #MachineLearning #IIoT Influencer @Onalytica',
#       'url': 'https://t.co/eYyaJsEcfw',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/eYyaJsEcfw',
#           'expanded_url': 'http://www.gppulipaka.org',
#           'display_url': 'gppulipaka.org',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 101866,
#       'friends_count': 25851,
#       'listed_count': 3510,
#       'created_at': 'Tue Nov 17 02:19:09 +0000 2015',
#       'favourites_count': 9,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'verified': False,
#       'statuses_count': 58791,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': '000000',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4263007693/1604252016',
#       'profile_link_color': 'DD2E44',
#       'profile_sidebar_border_color': '000000',
#       'profile_sidebar_fill_color': '000000',
#       'profile_text_color': '000000',
#       'profile_use_background_image': False,
#       'has_extended_profile': True,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 37,
#      'favorite_count': 41,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 37,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    {'created_at': 'Sat Nov 07 04:15:47 +0000 2020',
#     'id': 1324928509676974081,
#     'id_str': '1324928509676974081',
#     'text': 'RT @DD_NaNa_: Agile Data Science 2.0: Building Full-Stack Data Analytics Applications with Spark https://t.co/Fd0UFAsVK4 #DataScience #Agile',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'DataScience', 'indices': [121, 133]},
#       {'text': 'Agile', 'indices': [134, 140]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'DD_NaNa_',
#        'name': 'nana🦄',
#        'id': 2782310810,
#        'id_str': '2782310810',
#        'indices': [3, 12]}],
#      'urls': [{'url': 'https://t.co/Fd0UFAsVK4',
#        'expanded_url': 'https://amzn.to/2kZnh6f',
#        'display_url': 'amzn.to/2kZnh6f',
#        'indices': [97, 120]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://twitter.com/bungobot1" rel="nofollow">AIBungoBot</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1246850580191907840,
#      'id_str': '1246850580191907840',
#      'name': 'like and retweet Bot',
#      'screen_name': 'bungobot1',
#      'location': 'In your book',
#      'description': "Created by @ArchieSakai\n\nI like and retweet your tweet, if you follow me.\nHowever, sometimes I can't do it all because of the api request limit.",
#      'url': 'https://t.co/rO8R4H2IrC',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/rO8R4H2IrC',
#          'expanded_url': 'https://soarhap.com/',
#          'display_url': 'soarhap.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 195,
#      'friends_count': 1,
#      'listed_count': 5,
#      'created_at': 'Sun Apr 05 17:22:06 +0000 2020',
#      'favourites_count': 64796,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 65379,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1246850684932124672/0dcXfai7_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1246850684932124672/0dcXfai7_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1246850580191907840/1586107440',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sat Nov 07 04:07:24 +0000 2020',
#      'id': 1324926402349555714,
#      'id_str': '1324926402349555714',
#      'text': 'Agile Data Science 2.0: Building Full-Stack Data Analytics Applications with Spark https://t.co/Fd0UFAsVK4 #DataScience #Agile',
#      'truncated': False,
#      'entities': {'hashtags': [{'text': 'DataScience', 'indices': [107, 119]},
#        {'text': 'Agile', 'indices': [120, 126]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/Fd0UFAsVK4',
# ...
#       'profile_background_color': '9AE4E8',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme3/bg.gif',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme3/bg.gif',
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1097498307155369984/Xppu96OZ_normal.png',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1097498307155369984/Xppu96OZ_normal.png',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/316939729/1550499030',
#       'profile_link_color': '0084B4',
#       'profile_sidebar_border_color': 'D3D2CF',
#       'profile_sidebar_fill_color': 'E3E2DE',
#       'profile_text_color': '634047',
#       'profile_use_background_image': True,
#       'has_extended_profile': True,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 33,
#      'favorite_count': 15,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 33,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    {'created_at': 'Sat Nov 07 04:11:38 +0000 2020',
#     'id': 1324927467199590401,
#     'id_str': '1324927467199590401',
#     'text': 'RT @thisisgulshan: 5 Must-Have Data Science Skills That You Should Learn.\n\nhttps://t.co/IO9gbS9JLE\n\n#MachineLearning #DataScience #Python #…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'MachineLearning',
#        'indices': [100, 116]},
#       {'text': 'DataScience', 'indices': [117, 129]},
#       {'text': 'Python', 'indices': [130, 137]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'thisisgulshan',
#        'name': 'Gulshan Yadav',
#        'id': 2184926258,
#        'id_str': '2184926258',
#        'indices': [3, 17]}],
#      'urls': [{'url': 'https://t.co/IO9gbS9JLE',
#        'expanded_url': 'https://statanalytica.com/blog/data-science-skills',
#        'display_url': 'statanalytica.com/blog/data-scie…',
#        'indices': [75, 98]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://write.as/the-secret-junior-developer/" rel="nofollow">TheSecretJuniorDev</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1271182596559511554,
#      'id_str': '1271182596559511554',
#      'name': 'The Secret Junior Developer',
#      'screen_name': 'TheSecretJunio1',
#      'location': '',
#      'description': 'The secret Junior Dev in all of us. The Dev who wants to get better, who wants to learn and wants to help others...',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1061,
#      'friends_count': 66,
#      'listed_count': 17,
#      'created_at': 'Thu Jun 11 20:48:53 +0000 2020',
#      'favourites_count': 31,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 194859,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1281192258667188226/DcxncxpU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1281192258667188226/DcxncxpU_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1271182596559511554/1592772251',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sat Nov 07 04:08:21 +0000 2020',
#      'id': 1324926639885611013,
#      'id_str': '1324926639885611013',
#      'text': '5 Must-Have Data Science Skills That You Should Learn.\n\nhttps://t.co/IO9gbS9JLE\n\n#MachineLearning #DataScience… https://t.co/zH9SONMQf4',
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'MachineLearning',
#         'indices': [81, 97]},
#        {'text': 'DataScience', 'indices': [98, 110]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/IO9gbS9JLE',
#         'expanded_url': 'https://statanalytica.com/blog/data-science-skills',
#         'display_url': 'statanalytica.com/blog/data-scie…',
#         'indices': [56, 79]},
#        {'url': 'https://t.co/zH9SONMQf4',
#         'expanded_url': 'https://twitter.com/i/web/status/1324926639885611013',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [112, 135]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="http://www.tweetcaster.com" rel="nofollow">TweetCaster for Android</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 2184926258,
#       'id_str': '2184926258',
#       'name': 'Gulshan Yadav',
#       'screen_name': 'thisisgulshan',
#       'location': 'Gurgaon, Haryana, India',
#       'description': '13+ years exp. in Automotive🚗🚜 sw & fw dev. #Embedded Systems #EdgeComputing #BigData #DataScience Data Engineering #Azure #IOT #AI #MachineLearning #Coding',
#       'url': 'https://t.co/P6hTR9Medl',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/P6hTR9Medl',
#           'expanded_url': 'http://linkedin.com/in/gulshanyadav',
#           'display_url': 'linkedin.com/in/gulshanyadav',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 4779,
#       'friends_count': 4006,
#       'listed_count': 255,
#       'created_at': 'Sat Nov 09 19:35:04 +0000 2013',
#       'favourites_count': 5796,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'verified': False,
#       'statuses_count': 10924,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'C0DEED',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1321352269359542272/xMtucH6-_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1321352269359542272/xMtucH6-_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2184926258/1578132607',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': False,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 23,
#      'favorite_count': 8,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 23,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    {'created_at': 'Sat Nov 07 04:11:38 +0000 2020',
#     'id': 1324927467187023872,
#     'id_str': '1324927467187023872',
#     'text': 'RT @techopcode: 5 Must-Have Data Science Skills That You Should Learn.\n\nhttps://t.co/oCNW1Akt80\n\n#MachineLearning #DataScience #Python #AI…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'MachineLearning',
#        'indices': [97, 113]},
#       {'text': 'DataScience', 'indices': [114, 126]},
#       {'text': 'Python', 'indices': [127, 134]},
#       {'text': 'AI', 'indices': [135, 138]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'techopcode',
#        'name': '🅾️🅿️CODE💢',
#        'id': 3292530666,
#        'id_str': '3292530666',
#        'indices': [3, 14]}],
#      'urls': [{'url': 'https://t.co/oCNW1Akt80',
#        'expanded_url': 'https://statanalytica.com/blog/data-science-skills',
#        'display_url': 'statanalytica.com/blog/data-scie…',
#        'indices': [72, 95]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://write.as/the-secret-junior-developer/" rel="nofollow">TheSecretJuniorDev</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1271182596559511554,
#      'id_str': '1271182596559511554',
#      'name': 'The Secret Junior Developer',
#      'screen_name': 'TheSecretJunio1',
#      'location': '',
#      'description': 'The secret Junior Dev in all of us. The Dev who wants to get better, who wants to learn and wants to help others...',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1061,
#      'friends_count': 66,
#      'listed_count': 17,
#      'created_at': 'Thu Jun 11 20:48:53 +0000 2020',
#      'favourites_count': 31,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 194859,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1281192258667188226/DcxncxpU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1281192258667188226/DcxncxpU_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1271182596559511554/1592772251',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sat Nov 07 04:08:22 +0000 2020',
#      'id': 1324926641890492417,
#      'id_str': '1324926641890492417',
#      'text': '5 Must-Have Data Science Skills That You Should Learn.\n\nhttps://t.co/oCNW1Akt80\n\n#MachineLearning #DataScience… https://t.co/MH9cHhlBkO',
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'MachineLearning',
#         'indices': [81, 97]},
#        {'text': 'DataScience', 'indices': [98, 110]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/oCNW1Akt80',
#         'expanded_url': 'https://statanalytica.com/blog/data-science-skills',
#         'display_url': 'statanalytica.com/blog/data-scie…',
#         'indices': [56, 79]},
#        {'url': 'https://t.co/MH9cHhlBkO',
#         'expanded_url': 'https://twitter.com/i/web/status/1324926641890492417',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [112, 135]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="http://www.tweetcaster.com" rel="nofollow">TweetCaster for Android</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 3292530666,
#       'id_str': '3292530666',
#       'name': '🅾️🅿️CODE💢',
#       'screen_name': 'techopcode',
#       'location': 'India',
#       'description': '#ArtificialIntelligence #MachineLearning #DeepLearning\n#NeuralNetworks #Tech #IOT #EmbeddedSystems #Programming #Cybersecurity #Automotive #IIOT #InfoSec #Linux',
#       'url': 'https://t.co/wFWLy8021P',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/wFWLy8021P',
#           'expanded_url': 'https://www.youtube.com/channel/UCDvUFitqlXV84ZzabFCNsLg',
#           'display_url': 'youtube.com/channel/UCDvUF…',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 10475,
#       'friends_count': 9178,
#       'listed_count': 896,
#       'created_at': 'Sat Jul 25 12:12:44 +0000 2015',
#       'favourites_count': 9563,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'verified': False,
#       'statuses_count': 21161,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'C0DEED',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1306930385448701954/2Id5yJKD_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1306930385448701954/2Id5yJKD_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3292530666/1575359639',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': False,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 29,
#      'favorite_count': 16,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 29,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'}],
#   'search_metadata': {'completed_in': 0.153,
#    'max_id': 1324928585577029632,
#    'max_id_str': '1324928585577029632',
#    'next_results': '?max_id=1324474320643629058&q=%23datascience&count=100&include_entities=1&result_type=mixed',
#    'query': '%23datascience',
#    'refresh_url': '?since_id=1324928585577029632&q=%23datascience&result_type=mixed&include_entities=1',
#    'count': 100,
#    'since_id': 0,
#    'since_id_str': '0'}}]

# %%
example4
# Out:
# [{'errors': [{'code': 32, 'message': 'Could not authenticate you.'}]}]

# %% [markdown]
# ##### Function 3 (Required)

# %% [markdown]
# **Name:** `get_followers`
#
# **Returns:** list of data objects for each of the users followers, returning values for the `name`, `followers_count`, `friends_count`, and `screen_name` key for each user.
#
# **Arguments:**
#
#  - `screen_name`: str, required; Twitter handle to search for.  **Results should not depend on user inputting the @ symbol.**
#  - `keys`: list, required;  keys to return for each user.  default value: [`name`, `followers_count`, `friends_count`, `screen_name`]; if something else is listed, values for those keys should be returned
#  - `to_df`: bool, required; default value: False; if True, return results in a dataframe.  Every value provided in the `keys` argument should be its own column, with rows populated by the corresponding values for each one for every user.
#
# **To Test:** We'll test your functions in the following ways:
#
#  - `get_followers('@GA')`
#  - `get_followers('GA')`
#  - `get_followers('GA', keys=['name', 'followers_count'])`
#  - `get_followers('GA', keys=['name', 'followers_count'], to_df=True)`
#  - `get_followers('GA', to_df=True)`

# %%
auth= OAuth1('r8ZOzLMZoouq5u8iCdmNKiSMx', 'tIqgdrMHBrkMRXfBlY36cUpxDw34LygVL9hBg5A4Dl0yIQLOAb','1216043853284827136-XgLCLf15GtZZ0oIsgInUIjJT1lnPmT', 'ksKmplYg3WBqwThvTbhknJmhBYE7t43Bt0ZijmExr2Nq2')
def get_followers(name, keys = ['name', 'followers_count', 'friends_count', 'screen_name'], to_df=False):
    """
    This function finds if a user exists for the twitter handle and details about the users' followers
    as a required input it accepts the user_name - a user's twitter handle
    as optional inputs it accepts parameters by which to filter the output. These parameters are entered as a list of strings
    as output it returns either a list of data objects on each of the users followers or a dataFrame of the same information
    """
    
    #This line checks to see if the string begins with an @ and removes it
    name = name.strip("@").lower()
    
    #this returns the user details if the user exists or returns an empty dictionary if the user does not exist
    user_data = []
    
    api_url ='https://api.twitter.com/1.1/followers/list.json?screen_name={}'.format(name)
    user_details = requests.get(api_url, auth=auth)
    users_list = user_details.json()['users']

    
    try:
        api_url ='https://api.twitter.com/1.1/followers/list.json?screen_name={}'.format(name)
        user_details = requests.get(api_url, auth=auth)
        users_list = user_details.json()['users']
        
        for user in users_list:
            output = {}
            for key in keys:
                output[key]=user[key]
            user_data.append(output)
        
        if to_df == True:
            return pd.DataFrame(user_data)
        else:
            return user_data
    except:
        print("There was an error associated with your input")
        
        if to_df == True:
            return pd.DataFrame(user_data)
        else:
            return user_data

example1 = get_followers('@GA')
example2 = get_followers('GA')
example3 = get_followers('GA', keys=['name', 'followers_count'])
example4 = get_followers('GA', keys=['name', 'followers_count'], to_df=True)
example5 =get_followers('GA', to_df=True)

# %%
example1
# Out:
# [{'name': 'Carl Koski',
#   'followers_count': 14,
#   'friends_count': 198,
#   'screen_name': 'carl_koski'},
#  {'name': 'John White',
#   'followers_count': 266523,
#   'friends_count': 175061,
#   'screen_name': 'juanblanco76'},
#  {'name': 'Hierarch Soft Tech',
#   'followers_count': 384,
#   'friends_count': 1394,
#   'screen_name': 'HierarchTech'},
#  {'name': 'Brandon R Myers',
#   'followers_count': 2,
#   'friends_count': 50,
#   'screen_name': 'Brandon50352325'},
#  {'name': 'Francisco',
#   'followers_count': 7,
#   'friends_count': 33,
#   'screen_name': '_franciscomsosa'},
#  {'name': 'Angela Crampton',
#   'followers_count': 1932,
#   'friends_count': 1024,
#   'screen_name': 'angelatravels11'},
#  {'name': 'Sumon Chandra',
#   'followers_count': 186,
#   'friends_count': 2314,
#   'screen_name': 'SumonCh58302627'},
#  {'name': 'Priscilla Solorzano',
#   'followers_count': 105,
#   'friends_count': 464,
#   'screen_name': 'MsP_Solorzano'},
#  {'name': 'Seo Young Oh',
#   'followers_count': 11,
#   'friends_count': 22,
#   'screen_name': 'syoh1010'},
#  {'name': 'Ven2021',
#   'followers_count': 2,
#   'friends_count': 128,
#   'screen_name': 'yanglutc'},
#  {'name': 'Elizabeth Kane (she/her)',
#   'followers_count': 1413,
#   'friends_count': 4300,
#   'screen_name': 'EKvisualartist'},
#  {'name': 'Andres',
#   'followers_count': 6,
#   'friends_count': 55,
#   'screen_name': 'andrrrresd'},
#  {'name': 'Citizen Consulting',
#   'followers_count': 4,
#   'friends_count': 62,
#   'screen_name': 'CSR_Citizen'},
#  {'name': 'مَنارْ | Manar',
#   'followers_count': 1011,
#   'friends_count': 378,
#   'screen_name': 'manarjahmi'},
#  {'name': 'Brad Steeves',
#   'followers_count': 6643,
#   'friends_count': 3881,
#   'screen_name': 'BradSteeves23'},
#  {'name': 'Funke Bakare',
#   'followers_count': 178,
#   'friends_count': 628,
#   'screen_name': 'funkequbrat'},
#  {'name': 'Ahlam | أحـلامـ 💫',
#   'followers_count': 125,
#   'friends_count': 220,
#   'screen_name': 'A2_alnefaie'},
#  {'name': 'Social Hoote',
#   'followers_count': 522,
#   'friends_count': 952,
#   'screen_name': 'SocialHoote'},
#  {'name': 'Podcasters Directory',
#   'followers_count': 477,
#   'friends_count': 1715,
#   'screen_name': 'PodcastersDirec'},
#  {'name': 'Daniel Bermúdez',
#   'followers_count': 27,
#   'friends_count': 134,
#   'screen_name': 'danielberpo'}]

# %%
example2
# Out:
# [{'name': 'Carl Koski',
#   'followers_count': 14,
#   'friends_count': 198,
#   'screen_name': 'carl_koski'},
#  {'name': 'John White',
#   'followers_count': 266523,
#   'friends_count': 175061,
#   'screen_name': 'juanblanco76'},
#  {'name': 'Hierarch Soft Tech',
#   'followers_count': 384,
#   'friends_count': 1394,
#   'screen_name': 'HierarchTech'},
#  {'name': 'Brandon R Myers',
#   'followers_count': 2,
#   'friends_count': 50,
#   'screen_name': 'Brandon50352325'},
#  {'name': 'Francisco',
#   'followers_count': 7,
#   'friends_count': 33,
#   'screen_name': '_franciscomsosa'},
#  {'name': 'Angela Crampton',
#   'followers_count': 1932,
#   'friends_count': 1024,
#   'screen_name': 'angelatravels11'},
#  {'name': 'Sumon Chandra',
#   'followers_count': 186,
#   'friends_count': 2314,
#   'screen_name': 'SumonCh58302627'},
#  {'name': 'Priscilla Solorzano',
#   'followers_count': 105,
#   'friends_count': 464,
#   'screen_name': 'MsP_Solorzano'},
#  {'name': 'Seo Young Oh',
#   'followers_count': 11,
#   'friends_count': 22,
#   'screen_name': 'syoh1010'},
#  {'name': 'Ven2021',
#   'followers_count': 2,
#   'friends_count': 128,
#   'screen_name': 'yanglutc'},
#  {'name': 'Elizabeth Kane (she/her)',
#   'followers_count': 1413,
#   'friends_count': 4300,
#   'screen_name': 'EKvisualartist'},
#  {'name': 'Andres',
#   'followers_count': 6,
#   'friends_count': 55,
#   'screen_name': 'andrrrresd'},
#  {'name': 'Citizen Consulting',
#   'followers_count': 4,
#   'friends_count': 62,
#   'screen_name': 'CSR_Citizen'},
#  {'name': 'مَنارْ | Manar',
#   'followers_count': 1011,
#   'friends_count': 378,
#   'screen_name': 'manarjahmi'},
#  {'name': 'Brad Steeves',
#   'followers_count': 6643,
#   'friends_count': 3881,
#   'screen_name': 'BradSteeves23'},
#  {'name': 'Funke Bakare',
#   'followers_count': 178,
#   'friends_count': 628,
#   'screen_name': 'funkequbrat'},
#  {'name': 'Ahlam | أحـلامـ 💫',
#   'followers_count': 125,
#   'friends_count': 220,
#   'screen_name': 'A2_alnefaie'},
#  {'name': 'Social Hoote',
#   'followers_count': 522,
#   'friends_count': 952,
#   'screen_name': 'SocialHoote'},
#  {'name': 'Podcasters Directory',
#   'followers_count': 477,
#   'friends_count': 1715,
#   'screen_name': 'PodcastersDirec'},
#  {'name': 'Daniel Bermúdez',
#   'followers_count': 27,
#   'friends_count': 134,
#   'screen_name': 'danielberpo'}]

# %%
example3
# Out:
# [{'name': 'Carl Koski', 'followers_count': 14},
#  {'name': 'John White', 'followers_count': 266523},
#  {'name': 'Hierarch Soft Tech', 'followers_count': 384},
#  {'name': 'Brandon R Myers', 'followers_count': 2},
#  {'name': 'Francisco', 'followers_count': 7},
#  {'name': 'Angela Crampton', 'followers_count': 1932},
#  {'name': 'Sumon Chandra', 'followers_count': 186},
#  {'name': 'Priscilla Solorzano', 'followers_count': 105},
#  {'name': 'Seo Young Oh', 'followers_count': 11},
#  {'name': 'Ven2021', 'followers_count': 2},
#  {'name': 'Elizabeth Kane (she/her)', 'followers_count': 1413},
#  {'name': 'Andres', 'followers_count': 6},
#  {'name': 'Citizen Consulting', 'followers_count': 4},
#  {'name': 'مَنارْ | Manar', 'followers_count': 1011},
#  {'name': 'Brad Steeves', 'followers_count': 6643},
#  {'name': 'Funke Bakare', 'followers_count': 178},
#  {'name': 'Ahlam | أحـلامـ 💫', 'followers_count': 125},
#  {'name': 'Social Hoote', 'followers_count': 522},
#  {'name': 'Podcasters Directory', 'followers_count': 477},
#  {'name': 'Daniel Bermúdez', 'followers_count': 27}]

# %%
example4
# Out:
#                         name  followers_count
# 0                 Carl Koski               14
# 1                 John White           266523
# 2         Hierarch Soft Tech              384
# 3            Brandon R Myers                2
# 4                  Francisco                7
# 5            Angela Crampton             1932
# 6              Sumon Chandra              186
# 7        Priscilla Solorzano              105
# 8               Seo Young Oh               11
# 9                    Ven2021                2
# 10  Elizabeth Kane (she/her)             1413
# 11                    Andres                6
# 12        Citizen Consulting                4
# 13            مَنارْ | Manar             1011
# 14              Brad Steeves             6643
# 15              Funke Bakare              178
# 16         Ahlam | أحـلامـ 💫              125
# 17              Social Hoote              522
# 18      Podcasters Directory              477
# 19           Daniel Bermúdez               27

# %%
example5
# Out:
#                         name  followers_count  friends_count      screen_name
# 0                 Carl Koski               14            198       carl_koski
# 1                 John White           266523         175061     juanblanco76
# 2         Hierarch Soft Tech              384           1394     HierarchTech
# 3            Brandon R Myers                2             50  Brandon50352325
# 4                  Francisco                7             33  _franciscomsosa
# 5            Angela Crampton             1932           1024  angelatravels11
# 6              Sumon Chandra              186           2314  SumonCh58302627
# 7        Priscilla Solorzano              105            464    MsP_Solorzano
# 8               Seo Young Oh               11             22         syoh1010
# 9                    Ven2021                2            128         yanglutc
# 10  Elizabeth Kane (she/her)             1413           4300   EKvisualartist
# 11                    Andres                6             55       andrrrresd
# 12        Citizen Consulting                4             62      CSR_Citizen
# 13            مَنارْ | Manar             1011            378       manarjahmi
# 14              Brad Steeves             6643           3881    BradSteeves23
# 15              Funke Bakare              178            628      funkequbrat
# 16         Ahlam | أحـلامـ 💫              125            220      A2_alnefaie
# 17              Social Hoote              522            952      SocialHoote
# 18      Podcasters Directory              477           1715  PodcastersDirec
# 19           Daniel Bermúdez               27            134      danielberpo

# %% [markdown]
# ##### Function 4 (Optional)

# %% [markdown]
# **Name:** `friends_of_friends`
#
# **Returns:** list of data objects for each user that two Twitter users have in common
#
# **Arguments:**
#
#  - `names`: list, required; list of two Twitter users to compare friends list with
#  - `keys`: list, optional; list of keys to return for information about each user.  Default value should be to return the entire data object.
#  - `to_df`: bool, required; default value: False; if True, returns results in a dataframe.
#
# **To Test:** We'll test your function in the following ways:
#
#  - `friends_of_friends(['Beyonce', 'MariahCarey'])`
#  - `friends_of_friends(['@Beyonce', '@MariahCarey'], to_df=True)`
#  - `friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'])`
#  - `friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'], to_df=True)`
#
# Each of these should return 3 results. (Assuming they haven't followed the same people since this was last written).
#
# **Hint:** The `id` key is the unique identifier for someone, so if you want to check if two people are the same this is the best way to do it.

# %%
auth= OAuth1('r8ZOzLMZoouq5u8iCdmNKiSMx', 'tIqgdrMHBrkMRXfBlY36cUpxDw34LygVL9hBg5A4Dl0yIQLOAb','1216043853284827136-XgLCLf15GtZZ0oIsgInUIjJT1lnPmT', 'ksKmplYg3WBqwThvTbhknJmhBYE7t43Bt0ZijmExr2Nq2')

def friends_of_friends(people, keys = ['id', 'id_str', 'name', 'screen_name', 'location'
    , 'description', 'url', 'entities', 'protected', 'followers_count', 'friends_count', 'listed_count'
    , 'created_at', 'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled', 'verified', 'statuses_count'
    , 'lang', 'status', 'contributors_enabled', 'is_translator', 'is_translation_enabled', 'profile_background_color'
    , 'profile_background_image_url', 'profile_background_image_url_https', 'profile_background_tile'
    , 'profile_image_url', 'profile_image_url_https', 'profile_banner_url', 'profile_link_color'
    , 'profile_sidebar_border_color', 'profile_sidebar_fill_color', 'profile_text_color'
    , 'profile_use_background_image', 'has_extended_profile', 'default_profile', 'default_profile_image'
    , 'following', 'live_following', 'follow_request_sent', 'notifications', 'muting', 'blocking'
    , 'blocked_by', 'translator_type']
    , to_df=False):

    """
    This function finds if friends are shared between two users
    as a required input it accepts a list of usernames 
    as optional inputs it accepts keys by which to filter the output. These parameters are entered as a list of strings
    as optional input it accepts a flag that helps decide if the returned value should be a DataFrame or a list
    as output it returns either a list of data objects on each of the users followers or a dataFrame of the same information
    """

    #This line checks to see if the names begins with an @ and removes it
    people = [name.strip("@").lower() for name in people]

    #useful lists for later
    all_user_ids = []
    all_user_data = []
    output = []

    
    #getting the list of friends for each name in the people list
    for name in people:
        api_url ='https://api.twitter.com/1.1/friends/list.json?screen_name={}'.format(name)
        user_details = requests.get(api_url, auth=auth)
        friends_list = user_details.json()['users']
        friend_ids = []
        #for each name we add the user_id into the all_user_ids list and the data into the all_user_data list
        for people in friends_list:
            friend_ids.append(people['id'])
            all_user_data.append(people)
        all_user_ids.append(friend_ids)
    
    #this helps us figure out the shared friends between the people
    shared_friends = [x for x in all_user_ids[0] if x in all_user_ids[1]]
    
    #doing this to eliminate duplicate records
    deduped_user_list = [] 
    for i in range(len(all_user_data)): 
        if all_user_data[i] not in all_user_data[i + 1:]: 
            deduped_user_list.append(all_user_data[i]) 
    all_user_data = deduped_user_list

    #this is where we select our output based on the shared friends
    for user_data in all_user_data:
        if user_data['id'] in shared_friends:
            output.append(user_data)

    if to_df == False:
        return output
    else:
        return pd.DataFrame(output)

# %%
test = user_details.json()['users']
len(shared_friends)
# Out:
# 20

# %%
shared_friends = [x for x in all_user_data[0] if x in all_user_data[1]]

# %%
user_details
# Out:
# <Response [200]>

# %%
friends_of_friends(['@ifeladipo','@ladipoore'],keys=['id', 'name'], to_df=True)
# Out:
#          id    id_str           name   screen_name                location  \
# 0  72853440  72853440            Moe    Mochievous  Washington DC | Lagos
# 1  35735895  35735895  Editi Effiòng  EditiEffiong                   Lagos
#
#                                          description                      url  \
# 0  11 | Attorney - Tech & Impact | I tweet about ...  https://t.co/l92M3p4whs
# 1        Pretend you're a genius, then act like one.  https://t.co/bxdYdfXYeC
#
#                                             entities  protected  \
# 0  {'url': {'urls': [{'url': 'https://t.co/l92M3p...      False
# 1  {'url': {'urls': [{'url': 'https://t.co/bxdYdf...      False
#
#    followers_count  ...  default_profile  default_profile_image following  \
# 0           238699  ...            False                  False      True
# 1            87950  ...            False                  False      True
#
#    live_following follow_request_sent notifications  muting  blocking  \
# 0           False               False         False   False     False
# 1           False               False         False   False     False
#
#    blocked_by translator_type
# 0       False            none
# 1       False         regular
#
# [2 rows x 47 columns]

# %% [markdown]
#  ##### Function 5 (Optional)

# %% [markdown]
# Rewrite the `friends_of_friends` function, except this time include an argument called `full_search`, which accepts a boolean value.  If set to `True`, use cursoring to cycle through the complete set of users for the users provided.
#
# The twitter API only returns a subset of users in your results to save bandwidth, so you have to cycle through multiple result sets to get all of the values.
#
# You can read more about how this works here:  https://developer.twitter.com/en/docs/basics/cursoring
#
# Basically you have to do a `while` loop to continually make a new request using the values stored in the `next_cursor` key as part of your next query string until there's nothing left to search.
#
# **Note:** We're using the free API, so we're operating under some limitations.  One of them being that you can only make 15 API calls in a 15 minute span to this portion of the API.  You can also only return up to 200 results per cursor, so this means you won't be able to completely search for everyone even if you set this up correctly.
#
# That's fine, just do what you can under the circumstances.
#
# **To Test:** To test your function, we'll run the following function calls:
#
#  - `friends_of_friends(['ezraklein', 'tylercowen'])` -- should return 4 results if you do an API call that returns 200 results
#  - `friends_of_friends(['ezraklein', 'tylercowen'], full_search=True)` -- should return 54 results if you do an API call that returns 200 results
#
# **Hint:** Chances are you will exhaust your API limits quite easily in this function depending on who you search for.  Depending on how you have things set up, this could cause error messages to arise when things are otherwise fine.  Remember in class 3 when we were getting those weird dictionaries back because our limits were used up?  We won't hold you accountable for handling this inside your function, although it could make some things easier for your own testing.
#
# Good luck!

# %%
auth= OAuth1('r8ZOzLMZoouq5u8iCdmNKiSMx', 'tIqgdrMHBrkMRXfBlY36cUpxDw34LygVL9hBg5A4Dl0yIQLOAb','1216043853284827136-XgLCLf15GtZZ0oIsgInUIjJT1lnPmT', 'ksKmplYg3WBqwThvTbhknJmhBYE7t43Bt0ZijmExr2Nq2')

def friends_of_friends(people, keys = ['id', 'id_str', 'name', 'screen_name', 'location'
    , 'description', 'url', 'entities', 'protected', 'followers_count', 'friends_count', 'listed_count'
    , 'created_at', 'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled', 'verified', 'statuses_count'
    , 'lang', 'status', 'contributors_enabled', 'is_translator', 'is_translation_enabled', 'profile_background_color'
    , 'profile_background_image_url', 'profile_background_image_url_https', 'profile_background_tile'
    , 'profile_image_url', 'profile_image_url_https', 'profile_banner_url', 'profile_link_color'
    , 'profile_sidebar_border_color', 'profile_sidebar_fill_color', 'profile_text_color'
    , 'profile_use_background_image', 'has_extended_profile', 'default_profile', 'default_profile_image'
    , 'following', 'live_following', 'follow_request_sent', 'notifications', 'muting', 'blocking'
    , 'blocked_by', 'translator_type']
    , to_df=False
    , full_search = False):

    """
    This function finds if friends are shared between two users
    as a required input it accepts a list of usernames 
    as optional inputs it accepts keys by which to filter the output. These parameters are entered as a list of strings
    as optional input it accepts a flag that helps decide if the returned value should be a DataFrame or a list
    as output it returns either a list of data objects on each of the users followers or a dataFrame of the same information
    """

    #This line checks to see if the names begins with an @ and removes it
    people = [name.strip("@").lower() for name in people]

    #useful lists for later
    all_user_ids = []
    all_user_data = []
    output = []

    if full_search == False:
        #getting the list of friends for each name in the people list
        for name in people:
            api_url ='https://api.twitter.com/1.1/friends/list.json?screen_name={}'.format(name)
            user_details = requests.get(api_url, auth=auth)
            friends_list = user_details.json()['users']
            friend_ids = []
            #for each name we add the user_id into the all_user_ids list and the data into the all_user_data list
            for people in friends_list:
                friend_ids.append(people['id'])
                all_user_data.append(people)
            all_user_ids.append(friend_ids)
    else:
        cursor = -1
        #getting the complete list of friends for each name in the people list
        for name in people:
            while cursor != 0:
                api_url ='https://api.twitter.com/1.1/friends/list.json?screen_name={}'.format(name)
                user_details = requests.get(api_url, auth=auth)
                friends_list = user_details.json()['users']
                cursor = user_details.json()['next_cursor']
                friend_ids = []
                #for each name we add the user_id into the all_user_ids list and the data into the all_user_data list
                for people in friends_list:
                    friend_ids.append(people['id'])
                    all_user_data.append(people)
            all_user_ids.append(friend_ids)
    
    #this helps us figure out the shared friends between the people
    shared_friends = [x for x in all_user_ids[0] if x in all_user_ids[1]]
    
    #doing this to eliminate duplicate records
    deduped_user_list = [] 
    for i in range(len(all_user_data)): 
        if all_user_data[i] not in all_user_data[i + 1:]: 
            deduped_user_list.append(all_user_data[i]) 
    all_user_data = deduped_user_list

    #this is where we select our output based on the shared friends
    for user_data in all_user_data:
        if user_data['id'] in shared_friends:
            output.append(user_data)

    if to_df == False:
        return output
    else:
        return pd.DataFrame(output)

# %%
friends_of_friends(['@ifeladipo','@ladipoore'],keys=['id', 'name'], to_df=True, full_search = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-240-53c18f909356> in <module>
# ----> 1 friends_of_friends(['@ifeladipo','@ladipoore'],keys=['id', 'name'], to_df=True, full_search = True)
#
# <ipython-input-239-1d1dd25d4539> in friends_of_friends(people, keys, to_df, full_search)
#      49                 api_url ='https://api.twitter.com/1.1/friends/list.json?screen_name={}'.format(name)
#      50                 user_details = requests.get(api_url, auth=auth)
# ---> 51                 friends_list = user_details.json()['users']
#      52                 cursor = user_details.json()['next_cursor']
#      53                 friend_ids = []
#
# KeyError: 'users'

# %%
friends_list
# Out:
# {'users': [{'id': 14634731,
#    'id_str': '14634731',
#    'name': 'Andy Hall',
#    'screen_name': 'andrewbhall',
#    'location': '',
#    'description': "I'm a professor who runs a research group collecting data to understand how to build a better democracy @Stanford polisci.  Tweets self-destruct after 1 month.",
#    'url': 'http://t.co/o9OesVT9h3',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/o9OesVT9h3',
#        'expanded_url': 'http://www.andrewbenjaminhall.com',
#        'display_url': 'andrewbenjaminhall.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 5232,
#    'friends_count': 1248,
#    'listed_count': 148,
#    'created_at': 'Sat May 03 04:10:02 +0000 2008',
#    'favourites_count': 1476,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 107,
#    'lang': None,
#    'status': {'created_at': 'Fri Nov 06 21:11:56 +0000 2020',
#     'id': 1324821846257139714,
#     'id_str': '1324821846257139714',
#     'text': "@ethanbdm @cstewartiii Interesting. I'm not sure, but one issue seems to be that state polls struggled. That throws… https://t.co/oC158kD1ZN",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'ethanbdm',
#        'name': 'Ethan BdM',
#        'id': 49977203,
#        'id_str': '49977203',
#        'indices': [0, 9]},
#       {'screen_name': 'cstewartiii',
#        'name': 'Charles Stewart III',
#        'id': 49328612,
#        'id_str': '49328612',
#        'indices': [10, 22]}],
#      'urls': [{'url': 'https://t.co/oC158kD1ZN',
#        'expanded_url': 'https://twitter.com/i/web/status/1324821846257139714',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': 1324821048894885890,
#     'in_reply_to_status_id_str': '1324821048894885890',
#     'in_reply_to_user_id': 49977203,
#     'in_reply_to_user_id_str': '49977203',
#     'in_reply_to_screen_name': 'ethanbdm',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000768498215/e490992fae194643ae4c26a5a1471230_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000768498215/e490992fae194643ae4c26a5a1471230_normal.jpeg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14634731/1401366725',
#    'profile_link_color': '2FC2EF',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1621674679,
#    'id_str': '1621674679',
#    'name': 'kylie brakeman',
#    'screen_name': 'deadeyebrakeman',
#    'location': 'Los Angeles, CA',
#    'description': 'writer and performer @ ucb when that existed 🦩 put me in your little show! management: Brillstein 🦩. https://t.co/TzxFWr2EGz',
#    'url': 'https://t.co/vsIi9YBMsV',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/vsIi9YBMsV',
#        'expanded_url': 'http://cameo.com/kyliebrakeman',
#        'display_url': 'cameo.com/kyliebrakeman',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/TzxFWr2EGz',
#        'expanded_url': 'http://kyliebrakeman.com',
#        'display_url': 'kyliebrakeman.com',
#        'indices': [101, 124]}]}},
#    'protected': False,
#    'followers_count': 125763,
#    'friends_count': 889,
#    'listed_count': 380,
#    'created_at': 'Fri Jul 26 00:53:43 +0000 2013',
#    'favourites_count': 89230,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 4763,
#    'lang': None,
#    'status': {'created_at': 'Sat Nov 07 07:09:38 +0000 2020',
#     'id': 1324972259899969538,
#     'id_str': '1324972259899969538',
#     'text': 'if I’m never able to own a house I guess an app is ok too https://t.co/Ur7ACBuYZW',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Ur7ACBuYZW',
#        'expanded_url': 'https://twitter.com/julianwstoller/status/1324967881767964672',
#        'display_url': 'twitter.com/julianwstoller…',
#        'indices': [58, 81]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1324967881767964672,
#     'quoted_status_id_str': '1324967881767964672',
#     'retweet_count': 3,
#     'favorite_count': 479,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1298664652121862145/ZXdU4QnJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1298664652121862145/ZXdU4QnJ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1621674679/1598489706',
#    'profile_link_color': 'FA743E',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 362111287,
#    'id_str': '362111287',
#    'name': 'Steadman™',
#    'screen_name': 'AsteadWesley',
#    'location': 'Brooklyn kinda but not really',
#    'description': 'National politics reporter at The New York Times. CNN political analyst. Real one in these streets. astead.herndon@nytimes.com',
#    'url': 'https://t.co/3B2eU7lQoL',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/3B2eU7lQoL',
#        'expanded_url': 'http://instagram.com/asteadwesley',
#        'display_url': 'instagram.com/asteadwesley',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 190393,
#    'friends_count': 1609,
#    'listed_count': 2349,
#    'created_at': 'Thu Aug 25 21:34:50 +0000 2011',
#    'favourites_count': 18122,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 54171,
#    'lang': None,
#    'status': {'created_at': 'Sat Nov 07 05:35:26 +0000 2020',
#     'id': 1324948554889256965,
#     'id_str': '1324948554889256965',
#     'text': 'The signage to exit any parking garage https://t.co/kH3gOArobP',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1324948544382521345,
#        'id_str': '1324948544382521345',
#        'indices': [39, 62],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1324948544382521345/pu/img/hTMpn4zTFy3xQEs3.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1324948544382521345/pu/img/hTMpn4zTFy3xQEs3.jpg',
#        'url': 'https://t.co/kH3gOArobP',
#        'display_url': 'pic.twitter.com/kH3gOArobP',
#        'expanded_url': 'https://twitter.com/AsteadWesley/status/1324948554889256965/video/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 480, 'h': 270, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 480, 'h': 270, 'resize': 'fit'},
#         'large': {'w': 480, 'h': 270, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1324948544382521345,
#        'id_str': '1324948544382521345',
#        'indices': [39, 62],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1324948544382521345/pu/img/hTMpn4zTFy3xQEs3.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1324948544382521345/pu/img/hTMpn4zTFy3xQEs3.jpg',
#        'url': 'https://t.co/kH3gOArobP',
#        'display_url': 'pic.twitter.com/kH3gOArobP',
#        'expanded_url': 'https://twitter.com/AsteadWesley/status/1324948554889256965/video/1',
#        'type': 'video',
#        'sizes': {'medium': {'w': 480, 'h': 270, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 480, 'h': 270, 'resize': 'fit'},
#         'large': {'w': 480, 'h': 270, 'resize': 'fit'}},
#        'video_info': {'aspect_ratio': [16, 9],
#         'duration_millis': 8233,
#         'variants': [{'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/1324948544382521345/pu/pl/nGjQ3qukAxH5QM3T.m3u8?tag=10'},
#          {'bitrate': 256000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1324948544382521345/pu/vid/480x270/pIgFz8f9M6O_0Uz7.mp4?tag=10'}]},
#        'additional_media_info': {'monetizable': False}}]},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 63,
#     'favorite_count': 849,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1069946000658362368/hmCVOcxN_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1069946000658362368/hmCVOcxN_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/362111287/1496848710',
#    'profile_link_color': '000000',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'C0DFEC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1138076821533155328,
#    'id_str': '1138076821533155328',
#    'name': 'Jamaal Bowman',
#    'screen_name': 'JamaalBowmanNY',
#    'location': 'Yonkers, NY',
#    'description': 'Congressman-elect for #NY16. Former middle school principal. Causing problems for the status quo. Fighting for jobs and education, not bombs and incarceration.',
#    'url': 'https://t.co/ix1O30H02K',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/ix1O30H02K',
#        'expanded_url': 'http://myurls.co/jamaalbowman',
#        'display_url': 'myurls.co/jamaalbowman',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 199723,
#    'friends_count': 1705,
#    'listed_count': 743,
#    'created_at': 'Mon Jun 10 13:33:53 +0000 2019',
#    'favourites_count': 5959,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 4873,
#    'lang': None,
#    'status': {'created_at': 'Fri Nov 06 21:48:29 +0000 2020',
#     'id': 1324831041647988736,
#     'id_str': '1324831041647988736',
#     'text': "Now is a time for us to listen to people and help solve their problems in a real way. That's the whole point of thi… https://t.co/33nXon23oq",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/33nXon23oq',
#        'expanded_url': 'https://twitter.com/i/web/status/1324831041647988736',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1324830701359869953,
#     'in_reply_to_status_id_str': '1324830701359869953',
#     'in_reply_to_user_id': 1138076821533155328,
#     'in_reply_to_user_id_str': '1138076821533155328',
#     'in_reply_to_screen_name': 'JamaalBowmanNY',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 46,
#     'favorite_count': 714,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1140914022822400000/VlNI_uYX_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1140914022822400000/VlNI_uYX_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1138076821533155328/1564508149',
#    'profile_link_color': '1D2E5D',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1086870883,
#    'id_str': '1086870883',
#    'name': 'Samara Klar',
#    'screen_name': 'SamaraKlar',
#    'location': 'Tucson, AZ',
#    'description': '@UArizona Political Scientist. "Independent Politics" coauthor (https://t.co/HhYqnSDzxA). @WomenAlsoKnow operative. Canadian turned Tucsonan. Family woman.',
#    'url': 'http://t.co/n0H16V6vAd',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/n0H16V6vAd',
#        'expanded_url': 'http://www.samaraklar.com',
#        'display_url': 'samaraklar.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/HhYqnSDzxA',
#        'expanded_url': 'https://tinyurl.com/KlarBook',
#        'display_url': 'tinyurl.com/KlarBook',
#        'indices': [64, 87]}]}},
#    'protected': False,
#    'followers_count': 5964,
#    'friends_count': 657,
#    'listed_count': 104,
#    'created_at': 'Sun Jan 13 18:29:32 +0000 2013',
#    'favourites_count': 10199,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 6173,
#    'lang': None,
#    'status': {'created_at': 'Sat Nov 07 04:50:12 +0000 2020',
#     'id': 1324937170042302465,
#     'id_str': '1324937170042302465',
#     'text': '@C_Wolbrecht you and i are doing our parts!',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'C_Wolbrecht',
#        'name': 'Christina Wolbrecht',
#        'id': 458962565,
#        'id_str': '458962565',
#        'indices': [0, 12]}],
#      'urls': []},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': 1324937016719663105,
#     'in_reply_to_status_id_str': '1324937016719663105',
#     'in_reply_to_user_id': 458962565,
#     'in_reply_to_user_id_str': '458962565',
#     'in_reply_to_screen_name': 'C_Wolbrecht',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1319408772037554177/CTBWczcH_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1319408772037554177/CTBWczcH_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1086870883/1594009394',
#    'profile_link_color': '89C9FA',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1635352992,
#    'id_str': '1635352992',
#    'name': 'Yanna Krupnikov',
#    'screen_name': 'ykrupnikov',
#    'location': '',
#    'description': 'Associate Professor of Political Science',
#    'url': 'https://t.co/7sulrw2Wdt',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/7sulrw2Wdt',
#        'expanded_url': 'http://www.yannakrupnikov.com',
#        'display_url': 'yannakrupnikov.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4686,
#    'friends_count': 384,
#    'listed_count': 94,
#    'created_at': 'Wed Jul 31 12:33:48 +0000 2013',
#    'favourites_count': 1047,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 150,
#    'lang': None,
#    'status': {'created_at': 'Mon Nov 02 20:42:15 +0000 2020',
#     'id': 1323364825372700672,
#     'id_str': '1323364825372700672',
#     'text': "@andyguess @sgonzalezbailon @rasmus_kleis I'm excited to read this paper!",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'andyguess',
#        'name': 'Andy Guess',
#        'id': 5933322,
#        'id_str': '5933322',
#        'indices': [0, 10]},
#       {'screen_name': 'sgonzalezbailon',
#        'name': 'Sandra González-Bailón',
#        'id': 16330659,
#        'id_str': '16330659',
#        'indices': [11, 27]},
#       {'screen_name': 'rasmus_kleis',
#        'name': 'Rasmus Kleis Nielsen',
#        'id': 1699604941,
#        'id_str': '1699604941',
#        'indices': [28, 41]}],
#      'urls': []},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': 1322986014164557826,
#     'in_reply_to_status_id_str': '1322986014164557826',
#     'in_reply_to_user_id': 5933322,
#     'in_reply_to_user_id_str': '5933322',
#     'in_reply_to_screen_name': 'andyguess',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000416524567/6e7d050434d9108bb70a18c1a0b49b45_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000416524567/6e7d050434d9108bb70a18c1a0b49b45_normal.jpeg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 61638283,
#    'id_str': '61638283',
#    'name': 'Jane Philpott',
#    'screen_name': 'janephilpott',
#    'location': 'Kingston, Ontario',
#    'description': "Personal account. Dean of the Faculty of Health Sciences at Queen's University. CEO of the Southeastern Ontario Academic Medical Organization.",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 69593,
#    'friends_count': 5871,
#    'listed_count': 730,
#    'created_at': 'Fri Jul 31 00:04:35 +0000 2009',
#    'favourites_count': 23847,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 20198,
#    'lang': None,
#    'status': {'created_at': 'Fri Nov 06 23:37:09 +0000 2020',
#     'id': 1324858388782702597,
#     'id_str': '1324858388782702597',
#     'text': 'Come work with us at @QueensUHealth. Two tenure-track positions outlined here. Join a great team committed to… https://t.co/nDP2Yev7CQ',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'QueensUHealth',
#        'name': "Queen's Faculty of Health Sciences",
#        'id': 4230733031,
#        'id_str': '4230733031',
#        'indices': [21, 35]}],
#      'urls': [{'url': 'https://t.co/nDP2Yev7CQ',
#        'expanded_url': 'https://twitter.com/i/web/status/1324858388782702597',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [111, 134]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1324825089444118528,
#     'quoted_status_id_str': '1324825089444118528',
#     'retweet_count': 10,
#     'favorite_count': 29,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'EDECE9',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme3/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme3/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1134660893516750849/Tyyqg1Zd_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1134660893516750849/Tyyqg1Zd_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/61638283/1593602645',
#    'profile_link_color': '94081A',
#    'profile_sidebar_border_color': 'D3D2CF',
#    'profile_sidebar_fill_color': 'E3E2DE',
#    'profile_text_color': '634047',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 3816062073,
#    'id_str': '3816062073',
#    'name': 'Leah Wright Rigueur',
#    'screen_name': 'LeahRigueur',
#    'location': '',
#    'description': 'Historian || Author\n\nMy Book- The Loneliness of the Black Republican: https://t.co/lOn00ouHwC\n\nNew Book- Mourning in America: Black Folks in a White House',
#    'url': 'https://t.co/R6fjQ3qH3y',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/R6fjQ3qH3y',
#        'expanded_url': 'http://www.leahrigueur.com/',
#        'display_url': 'leahrigueur.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/lOn00ouHwC',
#        'expanded_url': 'http://bit.ly/2zQMnzi',
#        'display_url': 'bit.ly/2zQMnzi',
#        'indices': [70, 93]}]}},
#    'protected': False,
#    'followers_count': 21297,
#    'friends_count': 1000,
#    'listed_count': 342,
#    'created_at': 'Tue Sep 29 16:08:18 +0000 2015',
#    'favourites_count': 18970,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 18225,
#    'lang': None,
#    'status': {'created_at': 'Fri Nov 06 22:15:15 +0000 2020',
#     'id': 1324837780644614145,
#     'id_str': '1324837780644614145',
#     'text': "RT @NPR: Biden supporters are largely crediting his jump ahead of Trump in Georgia to the voters in Clayton County — part of the state's 5t…",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'NPR',
#        'name': 'NPR',
#        'id': 5392522,
#        'id_str': '5392522',
#        'indices': [3, 7]}],
#      'urls': []},
#     'source': '<a href="http://www.echofon.com/" rel="nofollow">Echofon</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Fri Nov 06 22:14:03 +0000 2020',
#      'id': 1324837475135664128,
#      'id_str': '1324837475135664128',
#      'text': 'Biden supporters are largely crediting his jump ahead of Trump in Georgia to the voters in Clayton County — part of… https://t.co/K5ikemJPrV',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/K5ikemJPrV',
#         'expanded_url': 'https://twitter.com/i/web/status/1324837475135664128',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 465,
#      'favorite_count': 6904,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 465,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/692379060840824834/ZPgEeZXq_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/692379060840824834/ZPgEeZXq_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3816062073/1453854827',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 18137417,
#    'id_str': '18137417',
#    'name': 'Hakeem Jefferson',
#    'screen_name': 'hakeemjefferson',
#    'location': 'Palo Alto, CA',
#    'description': 'Assistant professor of political science @stanfordpolisci. Thought bubbles: Black folks, identity, politics, music, food, beer.',
#    'url': 'https://t.co/ctQVKZm7Eo',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/ctQVKZm7Eo',
#        'expanded_url': 'http://www.hakeemjefferson.com',
#        'display_url': 'hakeemjefferson.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 17264,
#    'friends_count': 2686,
#    'listed_count': 206,
#    'created_at': 'Mon Dec 15 14:43:59 +0000 2008',
#    'favourites_count': 30573,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 21031,
#    'lang': None,
#    'status': {'created_at': 'Sat Nov 07 07:08:25 +0000 2020',
#     'id': 1324971955993288704,
#     'id_str': '1324971955993288704',
#     'text': '@stevenwwebster @YouTubeTV Exactly!',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'stevenwwebster',
#        'name': 'Steven W. Webster',
#        'id': 1968778134,
#        'id_str': '1968778134',
#        'indices': [0, 15]},
#       {'screen_name': 'YouTubeTV',
#        'name': 'YouTube TV',
#        'id': 803263807489536000,
#        'id_str': '803263807489536000',
#        'indices': [16, 26]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1324837303760670721,
#     'in_reply_to_status_id_str': '1324837303760670721',
#     'in_reply_to_user_id': 1968778134,
#     'in_reply_to_user_id_str': '1968778134',
#     'in_reply_to_screen_name': 'stevenwwebster',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C6E2EE',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/876985056656592896/gVmfCeQq_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/876985056656592896/gVmfCeQq_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18137417/1566064307',
#    'profile_link_color': '1F98C7',
#    'profile_sidebar_border_color': 'C6E2EE',
#    'profile_sidebar_fill_color': 'DAECF4',
#    'profile_text_color': '663B12',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 30098259,
#    'id_str': '30098259',
#    'name': 'Jamal Raad🌲',
#    'screen_name': 'jamalraad',
#    'location': 'Seattle',
#    'description': 'Co-founder/Campaign Director @EvergreenAction. Working toward an all-out mobilization to defeat the climate crisis. @JayInslee, @SenJeffMerkley, Space Camp alum',
#    'url': 'https://t.co/uZ2tcBXxDy',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/uZ2tcBXxDy',
#        'expanded_url': 'http://evergreenaction.com',
#        'display_url': 'evergreenaction.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 6258,
#    'friends_count': 2814,
#    'listed_count': 148,
#    'created_at': 'Thu Apr 09 23:37:19 +0000 2009',
#    'favourites_count': 19341,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 31851,
#    'lang': None,
#    'status': {'created_at': 'Sat Nov 07 02:48:07 +0000 2020',
#     'id': 1324906449412108293,
#     'id_str': '1324906449412108293',
#     'text': '@michaelshure This is a good reply',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'michaelshure',
#        'name': 'Michael Shure',
#        'id': 161752401,
#        'id_str': '161752401',
#        'indices': [0, 13]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1324905427432173569,
#     'in_reply_to_status_id_str': '1324905427432173569',
#     'in_reply_to_user_id': 161752401,
#     'in_reply_to_user_id_str': '161752401',
#     'in_reply_to_screen_name': 'michaelshure',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1072245321843916801/yphphj6A_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1072245321843916801/yphphj6A_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/30098259/1519740129',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 60190930,
#    'id_str': '60190930',
#    'name': 'Isabel Wilkerson',
#    'screen_name': 'Isabelwilkerson',
#    'location': '',
#    'description': 'I write about human nature. Pulitzer Prize. Humanities Medal. Author: The Warmth of Other Suns & Caste: The Origins of Our Discontents. IG: @isabelwilkerson',
#    'url': 'https://t.co/wYgrW0bV8w',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/wYgrW0bV8w',
#        'expanded_url': 'http://www.isabelwilkerson.com',
#        'display_url': 'isabelwilkerson.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 43131,
#    'friends_count': 318,
#    'listed_count': 527,
#    'created_at': 'Sun Jul 26 00:46:01 +0000 2009',
#    'favourites_count': 3597,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 2110,
#    'lang': None,
#    'status': {'created_at': 'Fri Nov 06 18:37:39 +0000 2020',
#     'id': 1324783018280669186,
#     'id_str': '1324783018280669186',
#     'text': 'Inspiring to see a historic equilibrium in the decisive turnouts in a receiving station of the Great Migration -- P… https://t.co/BFECTY7QrI',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/BFECTY7QrI',
#        'expanded_url': 'https://twitter.com/i/web/status/1324783018280669186',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#     'in_reply_to_status_id': 1324782510262419463,
#     'in_reply_to_status_id_str': '1324782510262419463',
#     'in_reply_to_user_id': 60190930,
#     'in_reply_to_user_id_str': '60190930',
#     'in_reply_to_screen_name': 'Isabelwilkerson',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 29,
#     'favorite_count': 244,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '8B542B',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1287393918418640898/5oxZ1Uce_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1287393918418640898/5oxZ1Uce_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/60190930/1595773309',
#    'profile_link_color': '9D582E',
#    'profile_sidebar_border_color': 'D9B17E',
#    'profile_sidebar_fill_color': 'EADEAA',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 25638482,
#    'id_str': '25638482',
#    'name': 'Nicholas Carr',
#    'screen_name': 'roughtype',
#    'location': 'Mass.',
#    'description': 'Writer: The Shallows, The Glass Cage, The Big Switch, Utopia Is Creepy. Blogger: https://t.co/1bq4PQfQz5',
#    'url': 'https://t.co/TNGsXQpYLX',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/TNGsXQpYLX',
#        'expanded_url': 'http://www.nicholascarr.com',
#        'display_url': 'nicholascarr.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/1bq4PQfQz5',
#        'expanded_url': 'http://roughtype.com',
#        'display_url': 'roughtype.com',
#        'indices': [81, 104]}]}},
#    'protected': False,
#    'followers_count': 5377,
#    'friends_count': 0,
#    'listed_count': 255,
#    'created_at': 'Sat Mar 21 04:20:18 +0000 2009',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 648,
#    'lang': None,
#    'status': {'created_at': 'Sat Oct 03 18:35:14 +0000 2020',
#     'id': 1312461224248897537,
#     'id_str': '1312461224248897537',
#     'text': "@Kpaxs Here's the original post that explains the chart: https://t.co/4P9UlGptH6",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'Kpaxs',
#        'name': 'Thibaut',
#        'id': 50252770,
#        'id_str': '50252770',
#        'indices': [0, 6]}],
#      'urls': [{'url': 'https://t.co/4P9UlGptH6',
#        'expanded_url': 'http://www.roughtype.com/?p=1603',
#        'display_url': 'roughtype.com/?p=1603',
#        'indices': [57, 80]}]},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': 1312289045045796866,
#     'in_reply_to_status_id_str': '1312289045045796866',
#     'in_reply_to_user_id': 50252770,
#     'in_reply_to_user_id_str': '50252770',
#     'in_reply_to_screen_name': 'Kpaxs',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000548433331/dd2e95af473a7981af6cce04ac6758da_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000548433331/dd2e95af473a7981af6cce04ac6758da_normal.jpeg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25638482/1398539791',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 151666167,
#    'id_str': '151666167',
#    'name': 'Sara Wallace Goodman',
#    'screen_name': 'ThatSaraGoodman',
#    'location': 'Irvine, CA',
#    'description': '@UCIrvine political scientist, studying immigration & democratic citizenship. Mom. Ohioan. I am generous with my snark and delete with impunity.',
#    'url': 'https://t.co/YF5GbWj6q6',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/YF5GbWj6q6',
#        'expanded_url': 'http://faculty.sites.uci.edu/sgoodman/',
#        'display_url': 'faculty.sites.uci.edu/sgoodman/',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 5039,
#    'friends_count': 2013,
#    'listed_count': 70,
#    'created_at': 'Thu Jun 03 23:40:52 +0000 2010',
#    'favourites_count': 12092,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 4788,
#    'lang': None,
#    'status': {'created_at': 'Sat Nov 07 04:47:42 +0000 2020',
#     'id': 1324936542821863424,
#     'id_str': '1324936542821863424',
#     'text': '@emayfarris https://t.co/iNDp0fWBIi',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'emayfarris',
#        'name': 'Emily M. Farris',
#        'id': 306491708,
#        'id_str': '306491708',
#        'indices': [0, 11]}],
#      'urls': [],
#      'media': [{'id': 1324936537465778176,
#        'id_str': '1324936537465778176',
#        'indices': [12, 35],
#        'media_url': 'http://pbs.twimg.com/tweet_video_thumb/EmMewtGVcAAptVL.jpg',
#        'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/EmMewtGVcAAptVL.jpg',
#        'url': 'https://t.co/iNDp0fWBIi',
#        'display_url': 'pic.twitter.com/iNDp0fWBIi',
#        'expanded_url': 'https://twitter.com/ThatSaraGoodman/status/1324936542821863424/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 498, 'h': 374, 'resize': 'fit'},
#         'large': {'w': 498, 'h': 374, 'resize': 'fit'},
#         'small': {'w': 498, 'h': 374, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1324936537465778176,
#        'id_str': '1324936537465778176',
#        'indices': [12, 35],
#        'media_url': 'http://pbs.twimg.com/tweet_video_thumb/EmMewtGVcAAptVL.jpg',
#        'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/EmMewtGVcAAptVL.jpg',
#        'url': 'https://t.co/iNDp0fWBIi',
#        'display_url': 'pic.twitter.com/iNDp0fWBIi',
#        'expanded_url': 'https://twitter.com/ThatSaraGoodman/status/1324936542821863424/photo/1',
#        'type': 'animated_gif',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 498, 'h': 374, 'resize': 'fit'},
#         'large': {'w': 498, 'h': 374, 'resize': 'fit'},
#         'small': {'w': 498, 'h': 374, 'resize': 'fit'}},
#        'video_info': {'aspect_ratio': [249, 187],
#         'variants': [{'bitrate': 0,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/tweet_video/EmMewtGVcAAptVL.mp4'}]}}]},
#     'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#     'in_reply_to_status_id': 1324935785800462338,
#     'in_reply_to_status_id_str': '1324935785800462338',
#     'in_reply_to_user_id': 306491708,
#     'in_reply_to_user_id_str': '306491708',
#     'in_reply_to_screen_name': 'emayfarris',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'und'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/931607281849925632/5QcsfdE5_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/931607281849925632/5QcsfdE5_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/151666167/1581888991',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 626660983,
#    'id_str': '626660983',
#    'name': 'Lyman Stone 石來民',
#    'screen_name': 'lymanstoneky',
#    'location': 'Montreal, QC',
#    'description': '石來民\nLutheran. Husband. Dad. Kentuckian. Demographer.  @DemographicNTEL @FamStudies @AEI @NovakFellows doing PhD at McGill.  lymanrstone at gmail dot com',
#    'url': 'https://t.co/W3ljLGh8fn',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/W3ljLGh8fn',
#        'expanded_url': 'https://www.demographicintel.com/',
#        'display_url': 'demographicintel.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 19813,
#    'friends_count': 1536,
#    'listed_count': 456,
#    'created_at': 'Wed Jul 04 18:06:20 +0000 2012',
#    'favourites_count': 23331,
#    'utc_offset': None,
#    'time_zone': None,
# ...
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/532254561386262528/gHX_F_KC_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/532254561386262528/gHX_F_KC_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/224896427/1415734314',
#    'profile_link_color': '356B98',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 118735458,
#    'id_str': '118735458',
#    'name': 'Diana Butler Bass',
#    'screen_name': 'dianabutlerbass',
#    'location': 'Alexandria, VA',
#    'description': 'Author | Religion, spirituality, history, politics | Duke PhD | Nats fan | gardens | gratitude | Gal 3:28 | The Cottage: https://t.co/xCHVr4uejq',
#    'url': 'https://t.co/sxfzEGOdQi',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/sxfzEGOdQi',
#        'expanded_url': 'http://www.chaffeemanagement.com/dianabutlerbass',
#        'display_url': 'chaffeemanagement.com/dianabutlerbass',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/xCHVr4uejq',
#        'expanded_url': 'http://dianabutlerbass.substack.com',
#        'display_url': 'dianabutlerbass.substack.com',
#        'indices': [121, 144]}]}},
#    'protected': False,
#    'followers_count': 50732,
#    'friends_count': 1987,
#    'listed_count': 875,
#    'created_at': 'Mon Mar 01 16:05:54 +0000 2010',
#    'favourites_count': 20015,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 49003,
#    'lang': None,
#    'status': {'created_at': 'Sat Nov 07 04:12:26 +0000 2020',
#     'id': 1324927667955752960,
#     'id_str': '1324927667955752960',
#     'text': 'RT @MichaelSteele: Who saw this coming? 🤦🏾 https://t.co/MPfZr6uBW3',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'MichaelSteele',
#        'name': 'Michael Steele',
#        'id': 50317463,
#        'id_str': '50317463',
#        'indices': [3, 17]}],
#      'urls': [{'url': 'https://t.co/MPfZr6uBW3',
#        'expanded_url': 'https://www.bloomberg.com/news/articles/2020-11-07/trump-s-chief-of-staff-mark-meadows-infected-by-coronavirus?utm_medium=social&utm_content=business&cmpid=socialflow-twitter-business&utm_source=url_link&utm_campaign=socialflow-organic&__twitter_impression=true',
#        'display_url': 'bloomberg.com/news/articles/…',
#        'indices': [43, 66]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sat Nov 07 04:11:27 +0000 2020',
#      'id': 1324927420340822016,
#      'id_str': '1324927420340822016',
#      'text': 'Who saw this coming? 🤦🏾 https://t.co/MPfZr6uBW3',
#      'truncated': False,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/MPfZr6uBW3',
#         'expanded_url': 'https://www.bloomberg.com/news/articles/2020-11-07/trump-s-chief-of-staff-mark-meadows-infected-by-coronavirus?utm_medium=social&utm_content=business&cmpid=socialflow-twitter-business&utm_source=url_link&utm_campaign=socialflow-organic&__twitter_impression=true',
#         'display_url': 'bloomberg.com/news/articles/…',
#         'indices': [24, 47]}]},
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': {'id': 'dea1eac2d7ef8878',
#       'url': 'https://api.twitter.com/1.1/geo/id/dea1eac2d7ef8878.json',
#       'place_type': 'admin',
#       'name': 'Maryland',
#       'full_name': 'Maryland, USA',
#       'country_code': 'US',
#       'country': 'United States',
#       'contained_within': [],
#       'bounding_box': {'type': 'Polygon',
#        'coordinates': [[[-79.487651, 37.886607],
#          [-74.986286, 37.886607],
#          [-74.986286, 39.723622],
#          [-79.487651, 39.723622]]]},
#       'attributes': {}},
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 620,
#      'favorite_count': 6152,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 620,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1318376140596183041/OyKYm_kw_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318376140596183041/OyKYm_kw_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/118735458/1554767883',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 85615231,
#    'id_str': '85615231',
#    'name': 'Jia Lynn Yang',
#    'screen_name': 'jialynnyang',
#    'location': 'New York, NY',
#    'description': 'Deputy National Editor @nytimes. Author of ONE MIGHTY AND IRRESISTIBLE TIDE: The Epic Struggle Over American Immigration, 1924-1965, out now via @wwnorton',
#    'url': 'https://t.co/kqZ0AHPmdg',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/kqZ0AHPmdg',
#        'expanded_url': 'https://www.jialynnyang.com/',
#        'display_url': 'jialynnyang.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 13738,
#    'friends_count': 1506,
#    'listed_count': 370,
#    'created_at': 'Tue Oct 27 17:20:18 +0000 2009',
#    'favourites_count': 2754,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 3704,
#    'lang': None,
#    'status': {'created_at': 'Thu Nov 05 20:06:36 +0000 2020',
#     'id': 1324443015268700165,
#     'id_str': '1324443015268700165',
#     'text': 'RT @thankyou_bham: The coolest #ALA_Carnegie long list! Congrats to all &amp; to those in store! 🥳 @_catherinelacey @RavenLeilani @MeghaMaj @ke…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'ALA_Carnegie', 'indices': [31, 44]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'thankyou_bham',
#        'name': 'Thank You Books',
#        'id': 1073258254489317376,
#        'id_str': '1073258254489317376',
#        'indices': [3, 17]},
#       {'screen_name': '_catherinelacey',
#        'name': 'Catherine Lacey',
#        'id': 335532961,
#        'id_str': '335532961',
#        'indices': [99, 115]},
#       {'screen_name': 'RavenLeilani',
#        'name': 'Raven Leilani',
#        'id': 2786195945,
#        'id_str': '2786195945',
#        'indices': [116, 129]},
#       {'screen_name': 'MeghaMaj',
#        'name': 'Megha Majumdar',
#        'id': 2365873982,
#        'id_str': '2365873982',
#        'indices': [130, 139]}],
#      'urls': []},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Wed Oct 28 01:46:14 +0000 2020',
#      'id': 1321266997833977857,
#      'id_str': '1321266997833977857',
#      'text': 'The coolest #ALA_Carnegie long list! Congrats to all &amp; to those in store! 🥳 @_catherinelacey @RavenLeilani… https://t.co/MHaTjqgCj7',
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'ALA_Carnegie', 'indices': [12, 25]}],
#       'symbols': [],
#       'user_mentions': [{'screen_name': '_catherinelacey',
#         'name': 'Catherine Lacey',
#         'id': 335532961,
#         'id_str': '335532961',
#         'indices': [80, 96]},
#        {'screen_name': 'RavenLeilani',
#         'name': 'Raven Leilani',
#         'id': 2786195945,
#         'id_str': '2786195945',
#         'indices': [97, 110]}],
#       'urls': [{'url': 'https://t.co/MHaTjqgCj7',
#         'expanded_url': 'https://twitter.com/i/web/status/1321266997833977857',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [112, 135]}]},
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 3,
#      'favorite_count': 13,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'DBE9ED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1225230740188749825/7dZavn6D_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1225230740188749825/7dZavn6D_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/85615231/1506570673',
#    'profile_link_color': 'CC3366',
#    'profile_sidebar_border_color': 'DBE9ED',
#    'profile_sidebar_fill_color': 'E6F6F9',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1150818428212731910,
#    'id_str': '1150818428212731910',
#    'name': 'Ellora Derenoncourt',
#    'screen_name': 'EDerenoncourt',
#    'location': '',
#    'description': 'Assistant Professor @berkeleyecon & @GoldmanSchool, working on inequality, labor economics, economic history',
#    'url': 'https://t.co/uCxaVKrvE2',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/uCxaVKrvE2',
#        'expanded_url': 'http://www.elloraderenoncourt.com',
#        'display_url': 'elloraderenoncourt.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 8004,
#    'friends_count': 333,
#    'listed_count': 101,
#    'created_at': 'Mon Jul 15 17:24:29 +0000 2019',
#    'favourites_count': 2101,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 376,
#    'lang': None,
#    'status': {'created_at': 'Fri Nov 06 21:49:28 +0000 2020',
#     'id': 1324831289153789952,
#     'id_str': '1324831289153789952',
#     'text': 'RT @CoriBush: Everything I do begins with those who have the least, who’ve suffered the worst, and who have the greatest to offer.\n\nhttps:/…',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'CoriBush',
#        'name': 'Cori Bush',
#        'id': 4696552878,
#        'id_str': '4696552878',
#        'indices': [3, 12]}],
#      'urls': []},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Fri Nov 06 21:04:01 +0000 2020',
#      'id': 1324819851916025858,
#      'id_str': '1324819851916025858',
#      'text': 'Everything I do begins with those who have the least, who’ve suffered the worst, and who have the greatest to offer… https://t.co/qSJjK6DchW',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/qSJjK6DchW',
#         'expanded_url': 'https://twitter.com/i/web/status/1324819851916025858',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 683,
#      'favorite_count': 5953,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 683,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1150818740315070464/SwCn8Z28_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1150818740315070464/SwCn8Z28_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1150818428212731910/1563213158',
#    'profile_link_color': 'B43104',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'}],
#  'next_cursor': 1668149150393811712,
#  'next_cursor_str': '1668149150393811712',
#  'previous_cursor': 0,
#  'previous_cursor_str': '0',
#  'total_count': None}

# %%
friends_list.keys()
# Out:
# dict_keys(['users', 'next_cursor', 'next_cursor_str', 'previous_cursor', 'previous_cursor_str', 'total_count'])

# %%
friends_list['next_cursor']
# Out:
# 1668149150393811712
